# %%
# import pandas as pd
# import numpy as np
# import os
# import pickle
# from statsmodels.tsa.arima.model import ARIMA
# from statsmodels.tsa.stattools import adfuller
# from sklearn.metrics import mean_absolute_error
# import warnings
# warnings.filterwarnings("ignore")

# # Fungsi untuk memuat dan memproses data
# def load_and_preprocess_data(file_path):
#     data = pd.read_csv(file_path)
#     data['Date'] = pd.to_datetime(data['Date'])
#     data = data.dropna()
#     return data

# # Fungsi untuk membagi data berdasarkan waktu
# def split_data_by_time(student_data, train_days=24):
#     student_data = student_data.sort_values('Date')
#     unique_dates = student_data['Date'].unique()
#     train_dates = unique_dates[:train_days]
#     test_dates = unique_dates[train_days:]
#     train_data = student_data[student_data['Date'].isin(train_dates)]
#     test_data = student_data[student_data['Date'].isin(test_dates)]
#     return train_data, test_data

# # Fungsi untuk uji stasioneritas
# def adf_test(series):
#     result = adfuller(series.dropna())
#     return result[1] < 0.05  # True jika stasioner

# # Fungsi untuk melatih dan menyimpan model ARIMA
# def train_arima(student_data, student_id, model_dir="model/arima"):
#     train_data, test_data = split_data_by_time(student_data)
    
#     # Pastikan direktori model ada
#     os.makedirs(model_dir, exist_ok=True)
    
#     # Tuning ARIMA untuk Stress Level
#     best_mae = float('inf')
#     best_params = (1, 1, 1)
#     best_model_fit = None
    
#     if adf_test(train_data['Stress Level (GSR)']):
#         for p in range(3):
#             for d in range(2):
#                 for q in range(3):
#                     try:
#                         arima_model = ARIMA(train_data['Stress Level (GSR)'], order=(p, d, q))
#                         arima_fit = arima_model.fit()
#                         arima_pred = arima_fit.forecast(steps=len(test_data))
#                         mae = mean_absolute_error(test_data['Stress Level (GSR)'], arima_pred)
#                         if mae < best_mae:
#                             best_mae = mae
#                             best_params = (p, d, q)
#                             best_model_fit = arima_fit
#                     except:
#                         continue
    
#     # Simpan model terbaik
#     if best_model_fit:
#         model_path = os.path.join(model_dir, f"arima_student_{student_id}.pkl")
#         with open(model_path, 'wb') as f:
#             pickle.dump(best_model_fit, f)
#         print(f"ARIMA model for Student {student_id} saved to {model_path}")
    
#     return best_model_fit, best_params, best_mae

# # Fungsi utama
# def main():
#     data = load_and_preprocess_data('student_monnitoring_data.csv')
#     user_groups = data.groupby('Student ID')
    
#     # Proses hanya 5 mahasiswa sebagai contoh
#     for i, (student_id, student_data) in enumerate(user_groups):
#         if i >= 5:
#             break
#         print(f"\nTraining ARIMA for Student {student_id}")
#         model_fit, params, mae = train_arima(student_data, student_id)
#         print(f"Best ARIMA params: {params}, MAE: {mae:.4f}")

# %%
import pandas as pd
import numpy as np
import os
import pickle
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# Fungsi untuk memuat dan memproses data
def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    data['Date'] = pd.to_datetime(data['Date'])
    data = data.dropna()
    return data

# Fungsi untuk membagi data berdasarkan waktu
def split_data_by_time(student_data, train_days=24):
    student_data = student_data.sort_values('Date')
    unique_dates = student_data['Date'].unique()
    train_dates = unique_dates[:train_days]
    test_dates = unique_dates[train_days:]
    train_data = student_data[student_data['Date'].isin(train_dates)]
    test_data = student_data[student_data['Date'].isin(test_dates)]
    return train_data, test_data

# Fungsi untuk uji stasioneritas
def adf_test(series):
    result = adfuller(series.dropna())
    return result[1] < 0.05  # True jika stasioner

# Fungsi untuk menjadikan data stasioner dengan differencing maksimal 2 kali
def make_stationary(series, max_diff=2):
    diff_count = 0
    while not adf_test(series) and diff_count < max_diff:
        series = series.diff().dropna()
        diff_count += 1
    return series, diff_count

# Fungsi untuk melatih dan menyimpan model ARIMA
def train_arima(student_data, student_id, model_dir="model/arima"):
    train_data, test_data = split_data_by_time(student_data)
    
    # Pastikan direktori model ada
    os.makedirs(model_dir, exist_ok=True)

    original_train = train_data['Stress Level (GSR)'].copy()
    stationary_train, d_diff = make_stationary(original_train)

    best_mae = float('inf')
    best_rmse = float('inf')
    best_params = (1, d_diff, 1)
    best_model_fit = None
    
    for p in range(3):
        for q in range(3):
            try:
                model = ARIMA(original_train, order=(p, d_diff, q))
                model_fit = model.fit()
                forecast = model_fit.forecast(steps=len(test_data))
                mae = mean_absolute_error(test_data['Stress Level (GSR)'], forecast)
                rmse = np.sqrt(mean_squared_error(test_data['Stress Level (GSR)'], forecast))
                if mae < best_mae:
                    best_mae = mae
                    best_rmse = rmse
                    best_params = (p, d_diff, q)
                    best_model_fit = model_fit
            except:
                continue

    # Simpan model terbaik
    if best_model_fit:
        model_path = os.path.join(model_dir, f"arima_student_{student_id}.pkl")
        with open(model_path, 'wb') as f:
            pickle.dump(best_model_fit, f)
        print(f"ARIMA model for Student {student_id} saved to {model_path}")
    
    return best_model_fit, best_params, best_mae, best_rmse

# Fungsi utama
def main():
    data = load_and_preprocess_data('student_monnitoring_data.csv')
    user_groups = data.groupby('Student ID')
    
    for i, (student_id, student_data) in enumerate(user_groups):
        # if i >= 5:
        #     break
        print(f"\nTraining ARIMA for Student {student_id}")
        model_fit, params, mae, rmse = train_arima(student_data, student_id)
        print(f"Best ARIMA params: {params}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Training ARIMA for Student 1
# ARIMA model for Student 1 saved to model/arima\arima_student_1.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.2130, RMSE: 1.4649
#
# Training ARIMA for Student 2
# ARIMA model for Student 2 saved to model/arima\arima_student_2.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.2455, RMSE: 1.5445
#
# Training ARIMA for Student 3
# ARIMA model for Student 3 saved to model/arima\arima_student_3.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.0776, RMSE: 1.3100
#
# Training ARIMA for Student 4
# ARIMA model for Student 4 saved to model/arima\arima_student_4.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.6113, RMSE: 1.6737
#
# Training ARIMA for Student 5
# ARIMA model for Student 5 saved to model/arima\arima_student_5.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.6149, RMSE: 1.7167
#
# Training ARIMA for Student 6
# ARIMA model for Student 6 saved to model/arima\arima_student_6.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.1914, RMSE: 1.4196
#
# Training ARIMA for Student 7
# ARIMA model for Student 7 saved to model/arima\arima_student_7.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.7122, RMSE: 0.8814
#
# Training ARIMA for Student 8
# ARIMA model for Student 8 saved to model/arima\arima_student_8.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.6752, RMSE: 1.9904
#
# Training ARIMA for Student 9
# ARIMA model for Student 9 saved to model/arima\arima_student_9.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.2951, RMSE: 1.5193
#
# Training ARIMA for Student 10
# ARIMA model for Student 10 saved to model/arima\arima_student_10.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.8611, RMSE: 2.2581
#
# Training ARIMA for Student 11
# ARIMA model for Student 11 saved to model/arima\arima_student_11.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.0927, RMSE: 1.3715
#
# Training ARIMA for Student 12
# ARIMA model for Student 12 saved to model/arima\arima_student_12.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.2582, RMSE: 1.4454
#
# Training ARIMA for Student 13
# ARIMA model for Student 13 saved to model/arima\arima_student_13.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.9550, RMSE: 1.1622
#
# Training ARIMA for Student 14
# ARIMA model for Student 14 saved to model/arima\arima_student_14.pkl
# Best ARIMA params: (2, 1, 2), MAE: 1.1822, RMSE: 1.2458
#
# Training ARIMA for Student 15
# ARIMA model for Student 15 saved to model/arima\arima_student_15.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0529, RMSE: 1.2856
#
# Training ARIMA for Student 16
# ARIMA model for Student 16 saved to model/arima\arima_student_16.pkl
# Best ARIMA params: (1, 1, 2), MAE: 1.0395, RMSE: 1.1915
#
# Training ARIMA for Student 17
# ARIMA model for Student 17 saved to model/arima\arima_student_17.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.5846, RMSE: 0.6851
#
# Training ARIMA for Student 18
# ARIMA model for Student 18 saved to model/arima\arima_student_18.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.6962, RMSE: 0.7730
#
# Training ARIMA for Student 19
# ARIMA model for Student 19 saved to model/arima\arima_student_19.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.0313, RMSE: 1.3808
#
# Training ARIMA for Student 20
# ARIMA model for Student 20 saved to model/arima\arima_student_20.pkl
# Best ARIMA params: (1, 1, 1), MAE: 1.0673, RMSE: 1.3398
#
# Training ARIMA for Student 21
# ARIMA model for Student 21 saved to model/arima\arima_student_21.pkl
# Best ARIMA params: (2, 2, 0), MAE: 0.7127, RMSE: 0.9828
#
# Training ARIMA for Student 22
# ARIMA model for Student 22 saved to model/arima\arima_student_22.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.3517, RMSE: 1.6175
#
# Training ARIMA for Student 23
# ARIMA model for Student 23 saved to model/arima\arima_student_23.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.2962, RMSE: 1.5581
#
# Training ARIMA for Student 24
# ARIMA model for Student 24 saved to model/arima\arima_student_24.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1466, RMSE: 1.2873
#
# Training ARIMA for Student 25
# ARIMA model for Student 25 saved to model/arima\arima_student_25.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.2600, RMSE: 1.3957
#
# Training ARIMA for Student 26
# ARIMA model for Student 26 saved to model/arima\arima_student_26.pkl
# Best ARIMA params: (0, 1, 2), MAE: 1.3361, RMSE: 1.4321
#
# Training ARIMA for Student 27
# ARIMA model for Student 27 saved to model/arima\arima_student_27.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.0303, RMSE: 1.2741
#
# Training ARIMA for Student 28
# ARIMA model for Student 28 saved to model/arima\arima_student_28.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.9209, RMSE: 1.2020
#
# Training ARIMA for Student 29
# ARIMA model for Student 29 saved to model/arima\arima_student_29.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.2283, RMSE: 1.4149
#
# Training ARIMA for Student 30
# ARIMA model for Student 30 saved to model/arima\arima_student_30.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.0728, RMSE: 1.1908
#
# Training ARIMA for Student 31
# ARIMA model for Student 31 saved to model/arima\arima_student_31.pkl
# Best ARIMA params: (1, 1, 2), MAE: 1.5766, RMSE: 1.6775
#
# Training ARIMA for Student 32
# ARIMA model for Student 32 saved to model/arima\arima_student_32.pkl
# Best ARIMA params: (1, 2, 2), MAE: 0.7609, RMSE: 1.0710
#
# Training ARIMA for Student 33
# ARIMA model for Student 33 saved to model/arima\arima_student_33.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.0433, RMSE: 1.1378
#
# Training ARIMA for Student 34
# ARIMA model for Student 34 saved to model/arima\arima_student_34.pkl
# Best ARIMA params: (0, 1, 0), MAE: 0.9133, RMSE: 1.1807
#
# Training ARIMA for Student 35
# ARIMA model for Student 35 saved to model/arima\arima_student_35.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.2330, RMSE: 1.4159
#
# Training ARIMA for Student 36
# ARIMA model for Student 36 saved to model/arima\arima_student_36.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.0461, RMSE: 1.1388
#
# Training ARIMA for Student 37
# ARIMA model for Student 37 saved to model/arima\arima_student_37.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.6825, RMSE: 0.8978
#
# Training ARIMA for Student 38
# ARIMA model for Student 38 saved to model/arima\arima_student_38.pkl
# Best ARIMA params: (2, 2, 0), MAE: 0.8713, RMSE: 1.0715
#
# Training ARIMA for Student 39
# ARIMA model for Student 39 saved to model/arima\arima_student_39.pkl
# Best ARIMA params: (2, 2, 1), MAE: 0.6825, RMSE: 0.9077
#
# Training ARIMA for Student 40
# ARIMA model for Student 40 saved to model/arima\arima_student_40.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.7061, RMSE: 0.8059
#
# Training ARIMA for Student 41
# ARIMA model for Student 41 saved to model/arima\arima_student_41.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.4348, RMSE: 1.7427
#
# Training ARIMA for Student 42
# ARIMA model for Student 42 saved to model/arima\arima_student_42.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.0561, RMSE: 1.2734
#
# Training ARIMA for Student 43
# ARIMA model for Student 43 saved to model/arima\arima_student_43.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1720, RMSE: 1.2671
#
# Training ARIMA for Student 44
# ARIMA model for Student 44 saved to model/arima\arima_student_44.pkl
# Best ARIMA params: (2, 1, 0), MAE: 0.8766, RMSE: 1.0322
#
# Training ARIMA for Student 45
# ARIMA model for Student 45 saved to model/arima\arima_student_45.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.3158, RMSE: 1.4190
#
# Training ARIMA for Student 46
# ARIMA model for Student 46 saved to model/arima\arima_student_46.pkl
# Best ARIMA params: (2, 2, 1), MAE: 1.2557, RMSE: 1.3735
#
# Training ARIMA for Student 47
# ARIMA model for Student 47 saved to model/arima\arima_student_47.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.8065, RMSE: 0.8370
#
# Training ARIMA for Student 48
# ARIMA model for Student 48 saved to model/arima\arima_student_48.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.1677, RMSE: 1.2714
#
# Training ARIMA for Student 49
# ARIMA model for Student 49 saved to model/arima\arima_student_49.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.5041, RMSE: 1.6590
#
# Training ARIMA for Student 50
# ARIMA model for Student 50 saved to model/arima\arima_student_50.pkl
# Best ARIMA params: (1, 2, 0), MAE: 1.5442, RMSE: 1.7363
#
# Training ARIMA for Student 51
# ARIMA model for Student 51 saved to model/arima\arima_student_51.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1506, RMSE: 1.3059
#
# Training ARIMA for Student 52
# ARIMA model for Student 52 saved to model/arima\arima_student_52.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.9010, RMSE: 1.0292
#
# Training ARIMA for Student 53
# ARIMA model for Student 53 saved to model/arima\arima_student_53.pkl
# Best ARIMA params: (1, 2, 2), MAE: 0.9314, RMSE: 1.1434
#
# Training ARIMA for Student 54
# ARIMA model for Student 54 saved to model/arima\arima_student_54.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.8594, RMSE: 1.0205
#
# Training ARIMA for Student 55
# ARIMA model for Student 55 saved to model/arima\arima_student_55.pkl
# Best ARIMA params: (2, 1, 2), MAE: 0.6543, RMSE: 0.9078
#
# Training ARIMA for Student 56
# ARIMA model for Student 56 saved to model/arima\arima_student_56.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.0413, RMSE: 1.4434
#
# Training ARIMA for Student 57
# ARIMA model for Student 57 saved to model/arima\arima_student_57.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0661, RMSE: 1.2061
#
# Training ARIMA for Student 58
# ARIMA model for Student 58 saved to model/arima\arima_student_58.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1758, RMSE: 1.3047
#
# Training ARIMA for Student 59
# ARIMA model for Student 59 saved to model/arima\arima_student_59.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.5221, RMSE: 1.5900
#
# Training ARIMA for Student 60
# ARIMA model for Student 60 saved to model/arima\arima_student_60.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.6537, RMSE: 1.7733
#
# Training ARIMA for Student 61
# ARIMA model for Student 61 saved to model/arima\arima_student_61.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.7861, RMSE: 0.9752
#
# Training ARIMA for Student 62
# ARIMA model for Student 62 saved to model/arima\arima_student_62.pkl
# Best ARIMA params: (0, 2, 2), MAE: 0.9825, RMSE: 1.1703
#
# Training ARIMA for Student 63
# ARIMA model for Student 63 saved to model/arima\arima_student_63.pkl
# Best ARIMA params: (2, 2, 1), MAE: 1.7836, RMSE: 2.0421
#
# Training ARIMA for Student 64
# ARIMA model for Student 64 saved to model/arima\arima_student_64.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.3596, RMSE: 1.4943
#
# Training ARIMA for Student 65
# ARIMA model for Student 65 saved to model/arima\arima_student_65.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.8685, RMSE: 1.0702
#
# Training ARIMA for Student 66
# ARIMA model for Student 66 saved to model/arima\arima_student_66.pkl
# Best ARIMA params: (2, 2, 0), MAE: 0.9589, RMSE: 1.1214
#
# Training ARIMA for Student 67
# ARIMA model for Student 67 saved to model/arima\arima_student_67.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.0028, RMSE: 1.1529
#
# Training ARIMA for Student 68
# ARIMA model for Student 68 saved to model/arima\arima_student_68.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.3078, RMSE: 1.4272
#
# Training ARIMA for Student 69
# ARIMA model for Student 69 saved to model/arima\arima_student_69.pkl
# Best ARIMA params: (0, 1, 1), MAE: 1.5436, RMSE: 1.6730
#
# Training ARIMA for Student 70
# ARIMA model for Student 70 saved to model/arima\arima_student_70.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0529, RMSE: 1.2804
#
# Training ARIMA for Student 71
# ARIMA model for Student 71 saved to model/arima\arima_student_71.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1094, RMSE: 1.3398
#
# Training ARIMA for Student 72
# ARIMA model for Student 72 saved to model/arima\arima_student_72.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.1111, RMSE: 1.2105
#
# Training ARIMA for Student 73
# ARIMA model for Student 73 saved to model/arima\arima_student_73.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.3671, RMSE: 1.5130
#
# Training ARIMA for Student 74
# ARIMA model for Student 74 saved to model/arima\arima_student_74.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.4528, RMSE: 1.5249
#
# Training ARIMA for Student 75
# ARIMA model for Student 75 saved to model/arima\arima_student_75.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.8750, RMSE: 2.0817
#
# Training ARIMA for Student 76
# ARIMA model for Student 76 saved to model/arima\arima_student_76.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.6926, RMSE: 0.7648
#
# Training ARIMA for Student 77
# ARIMA model for Student 77 saved to model/arima\arima_student_77.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.7535, RMSE: 1.1108
#
# Training ARIMA for Student 78
# ARIMA model for Student 78 saved to model/arima\arima_student_78.pkl
# Best ARIMA params: (1, 1, 0), MAE: 0.6077, RMSE: 0.7663
#
# Training ARIMA for Student 79
# ARIMA model for Student 79 saved to model/arima\arima_student_79.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1100, RMSE: 1.2991
#
# Training ARIMA for Student 80
# ARIMA model for Student 80 saved to model/arima\arima_student_80.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.3514, RMSE: 1.4490
#
# Training ARIMA for Student 81
# ARIMA model for Student 81 saved to model/arima\arima_student_81.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.8087, RMSE: 1.0622
#
# Training ARIMA for Student 82
# ARIMA model for Student 82 saved to model/arima\arima_student_82.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.6080, RMSE: 1.0733
#
# Training ARIMA for Student 83
# ARIMA model for Student 83 saved to model/arima\arima_student_83.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.4112, RMSE: 1.5748
#
# Training ARIMA for Student 84
# ARIMA model for Student 84 saved to model/arima\arima_student_84.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.4730, RMSE: 0.6653
#
# Training ARIMA for Student 85
# ARIMA model for Student 85 saved to model/arima\arima_student_85.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.0065, RMSE: 1.3364
#
# Training ARIMA for Student 86
# ARIMA model for Student 86 saved to model/arima\arima_student_86.pkl
# Best ARIMA params: (1, 2, 0), MAE: 1.5693, RMSE: 1.7896
#
# Training ARIMA for Student 87
# ARIMA model for Student 87 saved to model/arima\arima_student_87.pkl
# Best ARIMA params: (2, 2, 1), MAE: 0.4550, RMSE: 0.5841
#
# Training ARIMA for Student 88
# ARIMA model for Student 88 saved to model/arima\arima_student_88.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.4504, RMSE: 1.5689
#
# Training ARIMA for Student 89
# ARIMA model for Student 89 saved to model/arima\arima_student_89.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.1990, RMSE: 1.3727
#
# Training ARIMA for Student 90
# ARIMA model for Student 90 saved to model/arima\arima_student_90.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.4051, RMSE: 1.5323
#
# Training ARIMA for Student 91
# ARIMA model for Student 91 saved to model/arima\arima_student_91.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.2441, RMSE: 1.4078
#
# Training ARIMA for Student 92
# ARIMA model for Student 92 saved to model/arima\arima_student_92.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.6980, RMSE: 1.7474
#
# Training ARIMA for Student 93
# ARIMA model for Student 93 saved to model/arima\arima_student_93.pkl
# Best ARIMA params: (0, 1, 0), MAE: 1.3550, RMSE: 1.5142
#
# Training ARIMA for Student 94
# ARIMA model for Student 94 saved to model/arima\arima_student_94.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.9407, RMSE: 1.0868
#
# Training ARIMA for Student 95
# ARIMA model for Student 95 saved to model/arima\arima_student_95.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.3275, RMSE: 1.4975
#
# Training ARIMA for Student 96
# ARIMA model for Student 96 saved to model/arima\arima_student_96.pkl
# Best ARIMA params: (0, 1, 0), MAE: 1.0883, RMSE: 1.2186
#
# Training ARIMA for Student 97
# ARIMA model for Student 97 saved to model/arima\arima_student_97.pkl
# Best ARIMA params: (2, 1, 2), MAE: 0.9825, RMSE: 1.1772
#
# Training ARIMA for Student 98
# ARIMA model for Student 98 saved to model/arima\arima_student_98.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.1495, RMSE: 1.3300
#
# Training ARIMA for Student 99
# ARIMA model for Student 99 saved to model/arima\arima_student_99.pkl
# Best ARIMA params: (0, 1, 2), MAE: 1.4799, RMSE: 1.6369
#
# Training ARIMA for Student 100
# ARIMA model for Student 100 saved to model/arima\arima_student_100.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.9033, RMSE: 0.9913
#
# Training ARIMA for Student 101
# ARIMA model for Student 101 saved to model/arima\arima_student_101.pkl
# Best ARIMA params: (2, 1, 0), MAE: 0.6882, RMSE: 0.9574
#
# Training ARIMA for Student 102
# ARIMA model for Student 102 saved to model/arima\arima_student_102.pkl
# Best ARIMA params: (0, 2, 1), MAE: 1.0286, RMSE: 1.3837
#
# Training ARIMA for Student 103
# ARIMA model for Student 103 saved to model/arima\arima_student_103.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.4193, RMSE: 1.4795
#
# Training ARIMA for Student 104
# ARIMA model for Student 104 saved to model/arima\arima_student_104.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.6044, RMSE: 0.7740
#
# Training ARIMA for Student 105
# ARIMA model for Student 105 saved to model/arima\arima_student_105.pkl
# Best ARIMA params: (2, 1, 2), MAE: 0.6635, RMSE: 0.8326
#
# Training ARIMA for Student 106
# ARIMA model for Student 106 saved to model/arima\arima_student_106.pkl
# Best ARIMA params: (0, 1, 1), MAE: 1.6187, RMSE: 1.6828
#
# Training ARIMA for Student 107
# ARIMA model for Student 107 saved to model/arima\arima_student_107.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.0382, RMSE: 1.1006
#
# Training ARIMA for Student 108
# ARIMA model for Student 108 saved to model/arima\arima_student_108.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0140, RMSE: 1.2000
#
# Training ARIMA for Student 109
# ARIMA model for Student 109 saved to model/arima\arima_student_109.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1456, RMSE: 1.3371
#
# Training ARIMA for Student 110
# ARIMA model for Student 110 saved to model/arima\arima_student_110.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.2867, RMSE: 1.5234
#
# Training ARIMA for Student 111
# ARIMA model for Student 111 saved to model/arima\arima_student_111.pkl
# Best ARIMA params: (0, 0, 2), MAE: 0.6914, RMSE: 0.8920
#
# Training ARIMA for Student 112
# ARIMA model for Student 112 saved to model/arima\arima_student_112.pkl
# Best ARIMA params: (1, 2, 0), MAE: 0.8498, RMSE: 1.1818
#
# Training ARIMA for Student 113
# ARIMA model for Student 113 saved to model/arima\arima_student_113.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1282, RMSE: 1.2780
#
# Training ARIMA for Student 114
# ARIMA model for Student 114 saved to model/arima\arima_student_114.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9517, RMSE: 1.2095
#
# Training ARIMA for Student 115
# ARIMA model for Student 115 saved to model/arima\arima_student_115.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.1657, RMSE: 1.3395
#
# Training ARIMA for Student 116
# ARIMA model for Student 116 saved to model/arima\arima_student_116.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1750, RMSE: 1.3369
#
# Training ARIMA for Student 117
# ARIMA model for Student 117 saved to model/arima\arima_student_117.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1650, RMSE: 1.3966
#
# Training ARIMA for Student 118
# ARIMA model for Student 118 saved to model/arima\arima_student_118.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.9920, RMSE: 1.1157
#
# Training ARIMA for Student 119
# ARIMA model for Student 119 saved to model/arima\arima_student_119.pkl
# Best ARIMA params: (2, 1, 2), MAE: 1.7852, RMSE: 2.0977
#
# Training ARIMA for Student 120
# ARIMA model for Student 120 saved to model/arima\arima_student_120.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.6728, RMSE: 0.8454
#
# Training ARIMA for Student 121
# ARIMA model for Student 121 saved to model/arima\arima_student_121.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.3275, RMSE: 1.6734
#
# Training ARIMA for Student 122
# ARIMA model for Student 122 saved to model/arima\arima_student_122.pkl
# Best ARIMA params: (1, 2, 2), MAE: 0.9220, RMSE: 1.2279
#
# Training ARIMA for Student 123
# ARIMA model for Student 123 saved to model/arima\arima_student_123.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.9688, RMSE: 1.1523
#
# Training ARIMA for Student 124
# ARIMA model for Student 124 saved to model/arima\arima_student_124.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.3550, RMSE: 1.6378
#
# Training ARIMA for Student 125
# ARIMA model for Student 125 saved to model/arima\arima_student_125.pkl
# Best ARIMA params: (2, 2, 2), MAE: 0.9949, RMSE: 1.0503
#
# Training ARIMA for Student 126
# ARIMA model for Student 126 saved to model/arima\arima_student_126.pkl
# Best ARIMA params: (0, 2, 0), MAE: 0.8883, RMSE: 1.2247
#
# Training ARIMA for Student 127
# ARIMA model for Student 127 saved to model/arima\arima_student_127.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.5587, RMSE: 1.7574
#
# Training ARIMA for Student 128
# ARIMA model for Student 128 saved to model/arima\arima_student_128.pkl
# Best ARIMA params: (0, 0, 2), MAE: 0.7264, RMSE: 1.0218
#
# Training ARIMA for Student 129
# ARIMA model for Student 129 saved to model/arima\arima_student_129.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.5248, RMSE: 1.6608
#
# Training ARIMA for Student 130
# ARIMA model for Student 130 saved to model/arima\arima_student_130.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.7289, RMSE: 0.9484
#
# Training ARIMA for Student 131
# ARIMA model for Student 131 saved to model/arima\arima_student_131.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.9504, RMSE: 1.1471
#
# Training ARIMA for Student 132
# ARIMA model for Student 132 saved to model/arima\arima_student_132.pkl
# Best ARIMA params: (1, 0, 1), MAE: 1.2419, RMSE: 1.4483
#
# Training ARIMA for Student 133
# ARIMA model for Student 133 saved to model/arima\arima_student_133.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.7919, RMSE: 1.8305
#
# Training ARIMA for Student 134
# ARIMA model for Student 134 saved to model/arima\arima_student_134.pkl
# Best ARIMA params: (1, 1, 0), MAE: 1.1709, RMSE: 1.4228
#
# Training ARIMA for Student 135
# ARIMA model for Student 135 saved to model/arima\arima_student_135.pkl
# Best ARIMA params: (0, 2, 2), MAE: 0.7775, RMSE: 0.9660
#
# Training ARIMA for Student 136
# ARIMA model for Student 136 saved to model/arima\arima_student_136.pkl
# Best ARIMA params: (1, 2, 2), MAE: 0.9083, RMSE: 1.0378
#
# Training ARIMA for Student 137
# ARIMA model for Student 137 saved to model/arima\arima_student_137.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.2739, RMSE: 1.3950
#
# Training ARIMA for Student 138
# ARIMA model for Student 138 saved to model/arima\arima_student_138.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.4694, RMSE: 1.6234
#
# Training ARIMA for Student 139
# ARIMA model for Student 139 saved to model/arima\arima_student_139.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.3229, RMSE: 1.5538
#
# Training ARIMA for Student 140
# ARIMA model for Student 140 saved to model/arima\arima_student_140.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9836, RMSE: 1.1244
#
# Training ARIMA for Student 141
# ARIMA model for Student 141 saved to model/arima\arima_student_141.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.7288, RMSE: 0.9197
#
# Training ARIMA for Student 142
# ARIMA model for Student 142 saved to model/arima\arima_student_142.pkl
# Best ARIMA params: (2, 2, 1), MAE: 1.4651, RMSE: 1.9569
#
# Training ARIMA for Student 143
# ARIMA model for Student 143 saved to model/arima\arima_student_143.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.0737, RMSE: 1.2785
#
# Training ARIMA for Student 144
# ARIMA model for Student 144 saved to model/arima\arima_student_144.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.7409, RMSE: 0.8637
#
# Training ARIMA for Student 145
# ARIMA model for Student 145 saved to model/arima\arima_student_145.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.2442, RMSE: 1.4169
#
# Training ARIMA for Student 146
# ARIMA model for Student 146 saved to model/arima\arima_student_146.pkl
# Best ARIMA params: (0, 1, 1), MAE: 0.7304, RMSE: 0.8181
#
# Training ARIMA for Student 147
# ARIMA model for Student 147 saved to model/arima\arima_student_147.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.0522, RMSE: 1.1833
#
# Training ARIMA for Student 148
# ARIMA model for Student 148 saved to model/arima\arima_student_148.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.2501, RMSE: 1.4062
#
# Training ARIMA for Student 149
# ARIMA model for Student 149 saved to model/arima\arima_student_149.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.8726, RMSE: 1.0979
#
# Training ARIMA for Student 150
# ARIMA model for Student 150 saved to model/arima\arima_student_150.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.5847, RMSE: 1.6865
#
# Training ARIMA for Student 151
# ARIMA model for Student 151 saved to model/arima\arima_student_151.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.6950, RMSE: 0.7867
#
# Training ARIMA for Student 152
# ARIMA model for Student 152 saved to model/arima\arima_student_152.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1859, RMSE: 1.5439
#
# Training ARIMA for Student 153
# ARIMA model for Student 153 saved to model/arima\arima_student_153.pkl
# Best ARIMA params: (2, 2, 0), MAE: 1.4127, RMSE: 1.5717
#
# Training ARIMA for Student 154
# ARIMA model for Student 154 saved to model/arima\arima_student_154.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.6630, RMSE: 0.9192
#
# Training ARIMA for Student 155
# ARIMA model for Student 155 saved to model/arima\arima_student_155.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.0595, RMSE: 1.2441
#
# Training ARIMA for Student 156
# ARIMA model for Student 156 saved to model/arima\arima_student_156.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1942, RMSE: 1.3454
#
# Training ARIMA for Student 157
# ARIMA model for Student 157 saved to model/arima\arima_student_157.pkl
# Best ARIMA params: (2, 2, 0), MAE: 0.6986, RMSE: 0.9708
#
# Training ARIMA for Student 158
# ARIMA model for Student 158 saved to model/arima\arima_student_158.pkl
# Best ARIMA params: (1, 1, 0), MAE: 1.2291, RMSE: 1.4747
#
# Training ARIMA for Student 159
# ARIMA model for Student 159 saved to model/arima\arima_student_159.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.3366, RMSE: 1.4057
#
# Training ARIMA for Student 160
# ARIMA model for Student 160 saved to model/arima\arima_student_160.pkl
# Best ARIMA params: (1, 2, 2), MAE: 0.9967, RMSE: 1.1491
#
# Training ARIMA for Student 161
# ARIMA model for Student 161 saved to model/arima\arima_student_161.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.1068, RMSE: 1.2573
#
# Training ARIMA for Student 162
# ARIMA model for Student 162 saved to model/arima\arima_student_162.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.9849, RMSE: 1.2235
#
# Training ARIMA for Student 163
# ARIMA model for Student 163 saved to model/arima\arima_student_163.pkl
# Best ARIMA params: (1, 1, 2), MAE: 0.4928, RMSE: 0.5865
#
# Training ARIMA for Student 164
# ARIMA model for Student 164 saved to model/arima\arima_student_164.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.0256, RMSE: 1.1484
#
# Training ARIMA for Student 165
# ARIMA model for Student 165 saved to model/arima\arima_student_165.pkl
# Best ARIMA params: (1, 1, 1), MAE: 0.6454, RMSE: 0.9346
#
# Training ARIMA for Student 166
# ARIMA model for Student 166 saved to model/arima\arima_student_166.pkl
# Best ARIMA params: (2, 1, 1), MAE: 1.0552, RMSE: 1.4281
#
# Training ARIMA for Student 167
# ARIMA model for Student 167 saved to model/arima\arima_student_167.pkl
# Best ARIMA params: (0, 1, 0), MAE: 0.5917, RMSE: 0.6717
#
# Training ARIMA for Student 168
# ARIMA model for Student 168 saved to model/arima\arima_student_168.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.3732, RMSE: 1.4446
#
# Training ARIMA for Student 169
# ARIMA model for Student 169 saved to model/arima\arima_student_169.pkl
# Best ARIMA params: (2, 2, 2), MAE: 1.1543, RMSE: 1.4588
#
# Training ARIMA for Student 170
# ARIMA model for Student 170 saved to model/arima\arima_student_170.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.4689, RMSE: 1.5348
#
# Training ARIMA for Student 171
# ARIMA model for Student 171 saved to model/arima\arima_student_171.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.8683, RMSE: 1.0515
#
# Training ARIMA for Student 172
# ARIMA model for Student 172 saved to model/arima\arima_student_172.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.7345, RMSE: 0.8378
#
# Training ARIMA for Student 173
# ARIMA model for Student 173 saved to model/arima\arima_student_173.pkl
# Best ARIMA params: (0, 1, 1), MAE: 1.3683, RMSE: 1.4741
#
# Training ARIMA for Student 174
# ARIMA model for Student 174 saved to model/arima\arima_student_174.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.7332, RMSE: 0.9961
#
# Training ARIMA for Student 175
# ARIMA model for Student 175 saved to model/arima\arima_student_175.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.8446, RMSE: 0.9948
#
# Training ARIMA for Student 176
# ARIMA model for Student 176 saved to model/arima\arima_student_176.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1796, RMSE: 1.4641
#
# Training ARIMA for Student 177
# ARIMA model for Student 177 saved to model/arima\arima_student_177.pkl
# Best ARIMA params: (2, 1, 0), MAE: 0.9451, RMSE: 1.1932
#
# Training ARIMA for Student 178
# ARIMA model for Student 178 saved to model/arima\arima_student_178.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.9866, RMSE: 1.1653
#
# Training ARIMA for Student 179
# ARIMA model for Student 179 saved to model/arima\arima_student_179.pkl
# Best ARIMA params: (0, 2, 0), MAE: 0.8667, RMSE: 1.0956
#
# Training ARIMA for Student 180
# ARIMA model for Student 180 saved to model/arima\arima_student_180.pkl
# Best ARIMA params: (2, 1, 2), MAE: 1.6688, RMSE: 1.7208
#
# Training ARIMA for Student 181
# ARIMA model for Student 181 saved to model/arima\arima_student_181.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.0717, RMSE: 1.3521
#
# Training ARIMA for Student 182
# ARIMA model for Student 182 saved to model/arima\arima_student_182.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.0442, RMSE: 1.2106
#
# Training ARIMA for Student 183
# ARIMA model for Student 183 saved to model/arima\arima_student_183.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1963, RMSE: 1.3397
#
# Training ARIMA for Student 184
# ARIMA model for Student 184 saved to model/arima\arima_student_184.pkl
# Best ARIMA params: (0, 2, 0), MAE: 0.8900, RMSE: 1.1145
#
# Training ARIMA for Student 185
# ARIMA model for Student 185 saved to model/arima\arima_student_185.pkl
# Best ARIMA params: (2, 2, 2), MAE: 1.3576, RMSE: 1.4500
#
# Training ARIMA for Student 186
# ARIMA model for Student 186 saved to model/arima\arima_student_186.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.5850, RMSE: 0.7263
#
# Training ARIMA for Student 187
# ARIMA model for Student 187 saved to model/arima\arima_student_187.pkl
# Best ARIMA params: (0, 2, 1), MAE: 0.8546, RMSE: 0.9384
#
# Training ARIMA for Student 188
# ARIMA model for Student 188 saved to model/arima\arima_student_188.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.6781, RMSE: 1.7979
#
# Training ARIMA for Student 189
# ARIMA model for Student 189 saved to model/arima\arima_student_189.pkl
# Best ARIMA params: (2, 1, 1), MAE: 1.0634, RMSE: 1.2375
#
# Training ARIMA for Student 190
# ARIMA model for Student 190 saved to model/arima\arima_student_190.pkl
# Best ARIMA params: (1, 2, 1), MAE: 1.3280, RMSE: 1.5310
#
# Training ARIMA for Student 191
# ARIMA model for Student 191 saved to model/arima\arima_student_191.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.0980, RMSE: 1.2228
#
# Training ARIMA for Student 192
# ARIMA model for Student 192 saved to model/arima\arima_student_192.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9103, RMSE: 1.0670
#
# Training ARIMA for Student 193
# ARIMA model for Student 193 saved to model/arima\arima_student_193.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.3986, RMSE: 0.5170
#
# Training ARIMA for Student 194
# ARIMA model for Student 194 saved to model/arima\arima_student_194.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1900, RMSE: 1.4205
#
# Training ARIMA for Student 195
# ARIMA model for Student 195 saved to model/arima\arima_student_195.pkl
# Best ARIMA params: (0, 2, 1), MAE: 0.5506, RMSE: 0.6073
#
# Training ARIMA for Student 196
# ARIMA model for Student 196 saved to model/arima\arima_student_196.pkl
# Best ARIMA params: (0, 1, 0), MAE: 1.0917, RMSE: 1.2191
#
# Training ARIMA for Student 197
# ARIMA model for Student 197 saved to model/arima\arima_student_197.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.2788, RMSE: 1.5247
#
# Training ARIMA for Student 198
# ARIMA model for Student 198 saved to model/arima\arima_student_198.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.2776, RMSE: 1.3359
#
# Training ARIMA for Student 199
# ARIMA model for Student 199 saved to model/arima\arima_student_199.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.1920, RMSE: 1.4946
#
# Training ARIMA for Student 200
# ARIMA model for Student 200 saved to model/arima\arima_student_200.pkl
# Best ARIMA params: (2, 2, 1), MAE: 0.8545, RMSE: 0.9831
#
# Training ARIMA for Student 201
# ARIMA model for Student 201 saved to model/arima\arima_student_201.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.9667, RMSE: 1.0325
#
# Training ARIMA for Student 202
# ARIMA model for Student 202 saved to model/arima\arima_student_202.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.8469, RMSE: 1.0749
#
# Training ARIMA for Student 203
# ARIMA model for Student 203 saved to model/arima\arima_student_203.pkl
# Best ARIMA params: (0, 2, 2), MAE: 0.9190, RMSE: 1.0934
#
# Training ARIMA for Student 204
# ARIMA model for Student 204 saved to model/arima\arima_student_204.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.2878, RMSE: 1.3671
#
# Training ARIMA for Student 205
# ARIMA model for Student 205 saved to model/arima\arima_student_205.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9128, RMSE: 1.2022
#
# Training ARIMA for Student 206
# ARIMA model for Student 206 saved to model/arima\arima_student_206.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.7058, RMSE: 0.8908
#
# Training ARIMA for Student 207
# ARIMA model for Student 207 saved to model/arima\arima_student_207.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.9540, RMSE: 1.0804
#
# Training ARIMA for Student 208
# ARIMA model for Student 208 saved to model/arima\arima_student_208.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.4364, RMSE: 1.5665
#
# Training ARIMA for Student 209
# ARIMA model for Student 209 saved to model/arima\arima_student_209.pkl
# Best ARIMA params: (2, 2, 1), MAE: 0.9208, RMSE: 1.3085
#
# Training ARIMA for Student 210
# ARIMA model for Student 210 saved to model/arima\arima_student_210.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.6784, RMSE: 1.7775
#
# Training ARIMA for Student 211
# ARIMA model for Student 211 saved to model/arima\arima_student_211.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.4240, RMSE: 1.5168
#
# Training ARIMA for Student 212
# ARIMA model for Student 212 saved to model/arima\arima_student_212.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.6455, RMSE: 0.8157
#
# Training ARIMA for Student 213
# ARIMA model for Student 213 saved to model/arima\arima_student_213.pkl
# Best ARIMA params: (2, 2, 1), MAE: 0.8996, RMSE: 1.1033
#
# Training ARIMA for Student 214
# ARIMA model for Student 214 saved to model/arima\arima_student_214.pkl
# Best ARIMA params: (1, 2, 1), MAE: 1.0272, RMSE: 1.2014
#
# Training ARIMA for Student 215
# ARIMA model for Student 215 saved to model/arima\arima_student_215.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.7642, RMSE: 0.9749
#
# Training ARIMA for Student 216
# ARIMA model for Student 216 saved to model/arima\arima_student_216.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.1960, RMSE: 1.3459
#
# Training ARIMA for Student 217
# ARIMA model for Student 217 saved to model/arima\arima_student_217.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.3672, RMSE: 1.4884
#
# Training ARIMA for Student 218
# ARIMA model for Student 218 saved to model/arima\arima_student_218.pkl
# Best ARIMA params: (2, 2, 0), MAE: 0.8795, RMSE: 1.0320
#
# Training ARIMA for Student 219
# ARIMA model for Student 219 saved to model/arima\arima_student_219.pkl
# Best ARIMA params: (2, 1, 1), MAE: 0.7517, RMSE: 0.9031
#
# Training ARIMA for Student 220
# ARIMA model for Student 220 saved to model/arima\arima_student_220.pkl
# Best ARIMA params: (2, 1, 1), MAE: 0.6914, RMSE: 0.8032
#
# Training ARIMA for Student 221
# ARIMA model for Student 221 saved to model/arima\arima_student_221.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9158, RMSE: 1.1551
#
# Training ARIMA for Student 222
# ARIMA model for Student 222 saved to model/arima\arima_student_222.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.0854, RMSE: 1.1524
#
# Training ARIMA for Student 223
# ARIMA model for Student 223 saved to model/arima\arima_student_223.pkl
# Best ARIMA params: (2, 2, 2), MAE: 1.0981, RMSE: 1.2206
#
# Training ARIMA for Student 224
# ARIMA model for Student 224 saved to model/arima\arima_student_224.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.0990, RMSE: 1.2301
#
# Training ARIMA for Student 225
# ARIMA model for Student 225 saved to model/arima\arima_student_225.pkl
# Best ARIMA params: (0, 1, 2), MAE: 0.8373, RMSE: 0.9712
#
# Training ARIMA for Student 226
# ARIMA model for Student 226 saved to model/arima\arima_student_226.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.1788, RMSE: 1.5183
#
# Training ARIMA for Student 227
# ARIMA model for Student 227 saved to model/arima\arima_student_227.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.8665, RMSE: 1.0584
#
# Training ARIMA for Student 228
# ARIMA model for Student 228 saved to model/arima\arima_student_228.pkl
# Best ARIMA params: (1, 0, 1), MAE: 1.0081, RMSE: 1.3130
#
# Training ARIMA for Student 229
# ARIMA model for Student 229 saved to model/arima\arima_student_229.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.8232, RMSE: 1.1204
#
# Training ARIMA for Student 230
# ARIMA model for Student 230 saved to model/arima\arima_student_230.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.6786, RMSE: 0.8061
#
# Training ARIMA for Student 231
# ARIMA model for Student 231 saved to model/arima\arima_student_231.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.8727, RMSE: 0.9404
#
# Training ARIMA for Student 232
# ARIMA model for Student 232 saved to model/arima\arima_student_232.pkl
# Best ARIMA params: (2, 2, 2), MAE: 0.7020, RMSE: 0.9312
#
# Training ARIMA for Student 233
# ARIMA model for Student 233 saved to model/arima\arima_student_233.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.7450, RMSE: 0.8186
#
# Training ARIMA for Student 234
# ARIMA model for Student 234 saved to model/arima\arima_student_234.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0815, RMSE: 1.2016
#
# Training ARIMA for Student 235
# ARIMA model for Student 235 saved to model/arima\arima_student_235.pkl
# Best ARIMA params: (0, 2, 2), MAE: 0.8242, RMSE: 0.9202
#
# Training ARIMA for Student 236
# ARIMA model for Student 236 saved to model/arima\arima_student_236.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9993, RMSE: 1.2350
#
# Training ARIMA for Student 237
# ARIMA model for Student 237 saved to model/arima\arima_student_237.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.4678, RMSE: 0.6506
#
# Training ARIMA for Student 238
# ARIMA model for Student 238 saved to model/arima\arima_student_238.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.9681, RMSE: 1.2609
#
# Training ARIMA for Student 239
# ARIMA model for Student 239 saved to model/arima\arima_student_239.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1433, RMSE: 1.2465
#
# Training ARIMA for Student 240
# ARIMA model for Student 240 saved to model/arima\arima_student_240.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.1527, RMSE: 1.4467
#
# Training ARIMA for Student 241
# ARIMA model for Student 241 saved to model/arima\arima_student_241.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.8774, RMSE: 1.0406
#
# Training ARIMA for Student 242
# ARIMA model for Student 242 saved to model/arima\arima_student_242.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.9182, RMSE: 1.2344
#
# Training ARIMA for Student 243
# ARIMA model for Student 243 saved to model/arima\arima_student_243.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.7917, RMSE: 0.9604
#
# Training ARIMA for Student 244
# ARIMA model for Student 244 saved to model/arima\arima_student_244.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.1847, RMSE: 0.2082
#
# Training ARIMA for Student 245
# ARIMA model for Student 245 saved to model/arima\arima_student_245.pkl
# Best ARIMA params: (2, 1, 2), MAE: 0.9642, RMSE: 1.1028
#
# Training ARIMA for Student 246
# ARIMA model for Student 246 saved to model/arima\arima_student_246.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.3307, RMSE: 1.6014
#
# Training ARIMA for Student 247
# ARIMA model for Student 247 saved to model/arima\arima_student_247.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.2086, RMSE: 1.2491
#
# Training ARIMA for Student 248
# ARIMA model for Student 248 saved to model/arima\arima_student_248.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.7639, RMSE: 0.9529
#
# Training ARIMA for Student 249
# ARIMA model for Student 249 saved to model/arima\arima_student_249.pkl
# Best ARIMA params: (1, 0, 1), MAE: 1.0028, RMSE: 1.1352
#
# Training ARIMA for Student 250
# ARIMA model for Student 250 saved to model/arima\arima_student_250.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.9547, RMSE: 1.2073
#
# Training ARIMA for Student 251
# ARIMA model for Student 251 saved to model/arima\arima_student_251.pkl
# Best ARIMA params: (1, 0, 1), MAE: 1.0229, RMSE: 1.2653
#
# Training ARIMA for Student 252
# ARIMA model for Student 252 saved to model/arima\arima_student_252.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.8853, RMSE: 1.0662
#
# Training ARIMA for Student 253
# ARIMA model for Student 253 saved to model/arima\arima_student_253.pkl
# Best ARIMA params: (0, 2, 1), MAE: 1.6633, RMSE: 1.9483
#
# Training ARIMA for Student 254
# ARIMA model for Student 254 saved to model/arima\arima_student_254.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.0714, RMSE: 1.2433
#
# Training ARIMA for Student 255
# ARIMA model for Student 255 saved to model/arima\arima_student_255.pkl
# Best ARIMA params: (2, 2, 2), MAE: 1.5587, RMSE: 1.6777
#
# Training ARIMA for Student 256
# ARIMA model for Student 256 saved to model/arima\arima_student_256.pkl
# Best ARIMA params: (0, 2, 1), MAE: 0.7657, RMSE: 1.2968
#
# Training ARIMA for Student 257
# ARIMA model for Student 257 saved to model/arima\arima_student_257.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.2399, RMSE: 1.3614
#
# Training ARIMA for Student 258
# ARIMA model for Student 258 saved to model/arima\arima_student_258.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.3308, RMSE: 1.4091
#
# Training ARIMA for Student 259
# ARIMA model for Student 259 saved to model/arima\arima_student_259.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.6477, RMSE: 1.6630
#
# Training ARIMA for Student 260
# ARIMA model for Student 260 saved to model/arima\arima_student_260.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.1846, RMSE: 1.3323
#
# Training ARIMA for Student 261
# ARIMA model for Student 261 saved to model/arima\arima_student_261.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.0611, RMSE: 1.2273
#
# Training ARIMA for Student 262
# ARIMA model for Student 262 saved to model/arima\arima_student_262.pkl
# Best ARIMA params: (2, 2, 2), MAE: 0.9762, RMSE: 1.2440
#
# Training ARIMA for Student 263
# ARIMA model for Student 263 saved to model/arima\arima_student_263.pkl
# Best ARIMA params: (1, 1, 0), MAE: 0.8726, RMSE: 1.0928
#
# Training ARIMA for Student 264
# ARIMA model for Student 264 saved to model/arima\arima_student_264.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.1188, RMSE: 1.1932
#
# Training ARIMA for Student 265
# ARIMA model for Student 265 saved to model/arima\arima_student_265.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.0443, RMSE: 1.2479
#
# Training ARIMA for Student 266
# ARIMA model for Student 266 saved to model/arima\arima_student_266.pkl
# Best ARIMA params: (0, 1, 0), MAE: 1.2617, RMSE: 1.3505
#
# Training ARIMA for Student 267
# ARIMA model for Student 267 saved to model/arima\arima_student_267.pkl
# Best ARIMA params: (0, 0, 2), MAE: 0.7408, RMSE: 0.8716
#
# Training ARIMA for Student 268
# ARIMA model for Student 268 saved to model/arima\arima_student_268.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0536, RMSE: 1.2542
#
# Training ARIMA for Student 269
# ARIMA model for Student 269 saved to model/arima\arima_student_269.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.9453, RMSE: 1.2275
#
# Training ARIMA for Student 270
# ARIMA model for Student 270 saved to model/arima\arima_student_270.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.4534, RMSE: 1.4907
#
# Training ARIMA for Student 271
# ARIMA model for Student 271 saved to model/arima\arima_student_271.pkl
# Best ARIMA params: (2, 1, 2), MAE: 1.3453, RMSE: 1.4728
#
# Training ARIMA for Student 272
# ARIMA model for Student 272 saved to model/arima\arima_student_272.pkl
# Best ARIMA params: (2, 2, 1), MAE: 0.6957, RMSE: 0.7898
#
# Training ARIMA for Student 273
# ARIMA model for Student 273 saved to model/arima\arima_student_273.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.4191, RMSE: 1.6595
#
# Training ARIMA for Student 274
# ARIMA model for Student 274 saved to model/arima\arima_student_274.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.8946, RMSE: 1.0709
#
# Training ARIMA for Student 275
# ARIMA model for Student 275 saved to model/arima\arima_student_275.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1102, RMSE: 1.2640
#
# Training ARIMA for Student 276
# ARIMA model for Student 276 saved to model/arima\arima_student_276.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.8650, RMSE: 1.0841
#
# Training ARIMA for Student 277
# ARIMA model for Student 277 saved to model/arima\arima_student_277.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.2914, RMSE: 1.4854
#
# Training ARIMA for Student 278
# ARIMA model for Student 278 saved to model/arima\arima_student_278.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1710, RMSE: 1.2524
#
# Training ARIMA for Student 279
# ARIMA model for Student 279 saved to model/arima\arima_student_279.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.4052, RMSE: 1.4557
#
# Training ARIMA for Student 280
# ARIMA model for Student 280 saved to model/arima\arima_student_280.pkl
# Best ARIMA params: (2, 1, 1), MAE: 1.1934, RMSE: 1.5016
#
# Training ARIMA for Student 281
# ARIMA model for Student 281 saved to model/arima\arima_student_281.pkl
# Best ARIMA params: (2, 1, 0), MAE: 1.2929, RMSE: 1.5944
#
# Training ARIMA for Student 282
# ARIMA model for Student 282 saved to model/arima\arima_student_282.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.7941, RMSE: 0.9484
#
# Training ARIMA for Student 283
# ARIMA model for Student 283 saved to model/arima\arima_student_283.pkl
# Best ARIMA params: (1, 1, 2), MAE: 1.0109, RMSE: 1.5532
#
# Training ARIMA for Student 284
# ARIMA model for Student 284 saved to model/arima\arima_student_284.pkl
# Best ARIMA params: (0, 1, 1), MAE: 1.1458, RMSE: 1.2606
#
# Training ARIMA for Student 285
# ARIMA model for Student 285 saved to model/arima\arima_student_285.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.5222, RMSE: 0.5503
#
# Training ARIMA for Student 286
# ARIMA model for Student 286 saved to model/arima\arima_student_286.pkl
# Best ARIMA params: (2, 1, 2), MAE: 1.3540, RMSE: 1.4449
#
# Training ARIMA for Student 287
# ARIMA model for Student 287 saved to model/arima\arima_student_287.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.7314, RMSE: 0.7608
#
# Training ARIMA for Student 288
# ARIMA model for Student 288 saved to model/arima\arima_student_288.pkl
# Best ARIMA params: (2, 2, 2), MAE: 1.0584, RMSE: 1.3261
#
# Training ARIMA for Student 289
# ARIMA model for Student 289 saved to model/arima\arima_student_289.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.8395, RMSE: 1.0706
#
# Training ARIMA for Student 290
# ARIMA model for Student 290 saved to model/arima\arima_student_290.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.9098, RMSE: 0.9535
#
# Training ARIMA for Student 291
# ARIMA model for Student 291 saved to model/arima\arima_student_291.pkl
# Best ARIMA params: (2, 2, 1), MAE: 1.1775, RMSE: 1.3868
#
# Training ARIMA for Student 292
# ARIMA model for Student 292 saved to model/arima\arima_student_292.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1783, RMSE: 1.3084
#
# Training ARIMA for Student 293
# ARIMA model for Student 293 saved to model/arima\arima_student_293.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.0375, RMSE: 1.3182
#
# Training ARIMA for Student 294
# ARIMA model for Student 294 saved to model/arima\arima_student_294.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.8422, RMSE: 1.3100
#
# Training ARIMA for Student 295
# ARIMA model for Student 295 saved to model/arima\arima_student_295.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.0476, RMSE: 1.2758
#
# Training ARIMA for Student 296
# ARIMA model for Student 296 saved to model/arima\arima_student_296.pkl
# Best ARIMA params: (0, 1, 0), MAE: 0.5483, RMSE: 0.6479
#
# Training ARIMA for Student 297
# ARIMA model for Student 297 saved to model/arima\arima_student_297.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.1878, RMSE: 1.4240
#
# Training ARIMA for Student 298
# ARIMA model for Student 298 saved to model/arima\arima_student_298.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.0871, RMSE: 1.2292
#
# Training ARIMA for Student 299
# ARIMA model for Student 299 saved to model/arima\arima_student_299.pkl
# Best ARIMA params: (0, 1, 2), MAE: 2.1857, RMSE: 2.2355
#
# Training ARIMA for Student 300
# ARIMA model for Student 300 saved to model/arima\arima_student_300.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.7742, RMSE: 0.8893
#
# Training ARIMA for Student 301
# ARIMA model for Student 301 saved to model/arima\arima_student_301.pkl
# Best ARIMA params: (0, 1, 2), MAE: 0.8805, RMSE: 1.1459
#
# Training ARIMA for Student 302
# ARIMA model for Student 302 saved to model/arima\arima_student_302.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.4683, RMSE: 1.5839
#
# Training ARIMA for Student 303
# ARIMA model for Student 303 saved to model/arima\arima_student_303.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.9176, RMSE: 1.1476
#
# Training ARIMA for Student 304
# ARIMA model for Student 304 saved to model/arima\arima_student_304.pkl
# ...
# Best ARIMA params: (0, 2, 2), MAE: 1.0910, RMSE: 1.3511
#
# Training ARIMA for Student 401
# ARIMA model for Student 401 saved to model/arima\arima_student_401.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.2981, RMSE: 1.4578
#
# Training ARIMA for Student 402
# ARIMA model for Student 402 saved to model/arima\arima_student_402.pkl
# Best ARIMA params: (2, 1, 1), MAE: 0.9666, RMSE: 1.1389
#
# Training ARIMA for Student 403
# ARIMA model for Student 403 saved to model/arima\arima_student_403.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.2332, RMSE: 1.4317
#
# Training ARIMA for Student 404
# ARIMA model for Student 404 saved to model/arima\arima_student_404.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.5726, RMSE: 0.7436
#
# Training ARIMA for Student 405
# ARIMA model for Student 405 saved to model/arima\arima_student_405.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.7652, RMSE: 1.8809
#
# Training ARIMA for Student 406
# ARIMA model for Student 406 saved to model/arima\arima_student_406.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.8712, RMSE: 1.1440
#
# Training ARIMA for Student 407
# ARIMA model for Student 407 saved to model/arima\arima_student_407.pkl
# Best ARIMA params: (2, 2, 2), MAE: 0.7034, RMSE: 0.9394
#
# Training ARIMA for Student 408
# ARIMA model for Student 408 saved to model/arima\arima_student_408.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.6930, RMSE: 0.9812
#
# Training ARIMA for Student 409
# ARIMA model for Student 409 saved to model/arima\arima_student_409.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1945, RMSE: 1.3514
#
# Training ARIMA for Student 410
# ARIMA model for Student 410 saved to model/arima\arima_student_410.pkl
# Best ARIMA params: (2, 2, 2), MAE: 0.9957, RMSE: 1.3485
#
# Training ARIMA for Student 411
# ARIMA model for Student 411 saved to model/arima\arima_student_411.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.0028, RMSE: 1.0741
#
# Training ARIMA for Student 412
# ARIMA model for Student 412 saved to model/arima\arima_student_412.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.1762, RMSE: 1.4877
#
# Training ARIMA for Student 413
# ARIMA model for Student 413 saved to model/arima\arima_student_413.pkl
# Best ARIMA params: (2, 2, 1), MAE: 1.2626, RMSE: 1.4898
#
# Training ARIMA for Student 414
# ARIMA model for Student 414 saved to model/arima\arima_student_414.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9404, RMSE: 1.1073
#
# Training ARIMA for Student 415
# ARIMA model for Student 415 saved to model/arima\arima_student_415.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.2369, RMSE: 1.4001
#
# Training ARIMA for Student 416
# ARIMA model for Student 416 saved to model/arima\arima_student_416.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.7822, RMSE: 1.0495
#
# Training ARIMA for Student 417
# ARIMA model for Student 417 saved to model/arima\arima_student_417.pkl
# Best ARIMA params: (2, 2, 2), MAE: 1.0535, RMSE: 1.2569
#
# Training ARIMA for Student 418
# ARIMA model for Student 418 saved to model/arima\arima_student_418.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.8971, RMSE: 1.0670
#
# Training ARIMA for Student 419
# ARIMA model for Student 419 saved to model/arima\arima_student_419.pkl
# Best ARIMA params: (0, 0, 2), MAE: 0.6949, RMSE: 0.8736
#
# Training ARIMA for Student 420
# ARIMA model for Student 420 saved to model/arima\arima_student_420.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.6778, RMSE: 0.7512
#
# Training ARIMA for Student 421
# ARIMA model for Student 421 saved to model/arima\arima_student_421.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.1514, RMSE: 1.3716
#
# Training ARIMA for Student 422
# ARIMA model for Student 422 saved to model/arima\arima_student_422.pkl
# Best ARIMA params: (0, 0, 2), MAE: 0.9073, RMSE: 1.2093
#
# Training ARIMA for Student 423
# ARIMA model for Student 423 saved to model/arima\arima_student_423.pkl
# Best ARIMA params: (2, 2, 1), MAE: 1.4550, RMSE: 1.7021
#
# Training ARIMA for Student 424
# ARIMA model for Student 424 saved to model/arima\arima_student_424.pkl
# Best ARIMA params: (2, 2, 1), MAE: 0.7086, RMSE: 0.8810
#
# Training ARIMA for Student 425
# ARIMA model for Student 425 saved to model/arima\arima_student_425.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.2905, RMSE: 1.5184
#
# Training ARIMA for Student 426
# ARIMA model for Student 426 saved to model/arima\arima_student_426.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.0154, RMSE: 1.1267
#
# Training ARIMA for Student 427
# ARIMA model for Student 427 saved to model/arima\arima_student_427.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.9825, RMSE: 1.0715
#
# Training ARIMA for Student 428
# ARIMA model for Student 428 saved to model/arima\arima_student_428.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.0608, RMSE: 1.1862
#
# Training ARIMA for Student 429
# ARIMA model for Student 429 saved to model/arima\arima_student_429.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.3794, RMSE: 1.4974
#
# Training ARIMA for Student 430
# ARIMA model for Student 430 saved to model/arima\arima_student_430.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.6067, RMSE: 1.0837
#
# Training ARIMA for Student 431
# ARIMA model for Student 431 saved to model/arima\arima_student_431.pkl
# Best ARIMA params: (1, 1, 0), MAE: 1.2363, RMSE: 1.4591
#
# Training ARIMA for Student 432
# ARIMA model for Student 432 saved to model/arima\arima_student_432.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.0289, RMSE: 1.1235
#
# Training ARIMA for Student 433
# ARIMA model for Student 433 saved to model/arima\arima_student_433.pkl
# Best ARIMA params: (0, 1, 1), MAE: 0.7667, RMSE: 0.8493
#
# Training ARIMA for Student 434
# ARIMA model for Student 434 saved to model/arima\arima_student_434.pkl
# Best ARIMA params: (0, 2, 1), MAE: 0.7245, RMSE: 1.0683
#
# Training ARIMA for Student 435
# ARIMA model for Student 435 saved to model/arima\arima_student_435.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.9986, RMSE: 1.2204
#
# Training ARIMA for Student 436
# ARIMA model for Student 436 saved to model/arima\arima_student_436.pkl
# Best ARIMA params: (2, 1, 0), MAE: 0.6018, RMSE: 0.8084
#
# Training ARIMA for Student 437
# ARIMA model for Student 437 saved to model/arima\arima_student_437.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.8632, RMSE: 1.1484
#
# Training ARIMA for Student 438
# ARIMA model for Student 438 saved to model/arima\arima_student_438.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.8776, RMSE: 1.0474
#
# Training ARIMA for Student 439
# ARIMA model for Student 439 saved to model/arima\arima_student_439.pkl
# Best ARIMA params: (0, 1, 1), MAE: 1.4368, RMSE: 1.6567
#
# Training ARIMA for Student 440
# ARIMA model for Student 440 saved to model/arima\arima_student_440.pkl
# Best ARIMA params: (2, 0, 2), MAE: 0.6337, RMSE: 0.7524
#
# Training ARIMA for Student 441
# ARIMA model for Student 441 saved to model/arima\arima_student_441.pkl
# Best ARIMA params: (1, 1, 1), MAE: 1.3209, RMSE: 1.5780
#
# Training ARIMA for Student 442
# ARIMA model for Student 442 saved to model/arima\arima_student_442.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.8150, RMSE: 0.9657
#
# Training ARIMA for Student 443
# ARIMA model for Student 443 saved to model/arima\arima_student_443.pkl
# Best ARIMA params: (1, 2, 2), MAE: 0.8526, RMSE: 1.0150
#
# Training ARIMA for Student 444
# ARIMA model for Student 444 saved to model/arima\arima_student_444.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.7710, RMSE: 1.9772
#
# Training ARIMA for Student 445
# ARIMA model for Student 445 saved to model/arima\arima_student_445.pkl
# Best ARIMA params: (0, 0, 1), MAE: 1.0653, RMSE: 1.2552
#
# Training ARIMA for Student 446
# ARIMA model for Student 446 saved to model/arima\arima_student_446.pkl
# Best ARIMA params: (1, 2, 1), MAE: 1.5258, RMSE: 2.0340
#
# Training ARIMA for Student 447
# ARIMA model for Student 447 saved to model/arima\arima_student_447.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.8559, RMSE: 1.0431
#
# Training ARIMA for Student 448
# ARIMA model for Student 448 saved to model/arima\arima_student_448.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.6140, RMSE: 1.6681
#
# Training ARIMA for Student 449
# ARIMA model for Student 449 saved to model/arima\arima_student_449.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.3499, RMSE: 1.5343
#
# Training ARIMA for Student 450
# ARIMA model for Student 450 saved to model/arima\arima_student_450.pkl
# Best ARIMA params: (1, 2, 2), MAE: 0.7739, RMSE: 1.0098
#
# Training ARIMA for Student 451
# ARIMA model for Student 451 saved to model/arima\arima_student_451.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.8919, RMSE: 1.3056
#
# Training ARIMA for Student 452
# ARIMA model for Student 452 saved to model/arima\arima_student_452.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.7798, RMSE: 1.0070
#
# Training ARIMA for Student 453
# ARIMA model for Student 453 saved to model/arima\arima_student_453.pkl
# Best ARIMA params: (0, 0, 1), MAE: 0.4978, RMSE: 0.5646
#
# Training ARIMA for Student 454
# ARIMA model for Student 454 saved to model/arima\arima_student_454.pkl
# Best ARIMA params: (0, 0, 0), MAE: 0.9517, RMSE: 1.1665
#
# Training ARIMA for Student 455
# ARIMA model for Student 455 saved to model/arima\arima_student_455.pkl
# Best ARIMA params: (0, 2, 2), MAE: 1.0563, RMSE: 1.4640
#
# Training ARIMA for Student 456
# ARIMA model for Student 456 saved to model/arima\arima_student_456.pkl
# Best ARIMA params: (0, 1, 1), MAE: 1.0829, RMSE: 1.1906
#
# Training ARIMA for Student 457
# ARIMA model for Student 457 saved to model/arima\arima_student_457.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0182, RMSE: 1.2323
#
# Training ARIMA for Student 458
# ARIMA model for Student 458 saved to model/arima\arima_student_458.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1350, RMSE: 1.1933
#
# Training ARIMA for Student 459
# ARIMA model for Student 459 saved to model/arima\arima_student_459.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.5151, RMSE: 1.7278
#
# Training ARIMA for Student 460
# ARIMA model for Student 460 saved to model/arima\arima_student_460.pkl
# Best ARIMA params: (2, 2, 0), MAE: 0.7456, RMSE: 0.8387
#
# Training ARIMA for Student 461
# ARIMA model for Student 461 saved to model/arima\arima_student_461.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.0016, RMSE: 1.1388
#
# Training ARIMA for Student 462
# ARIMA model for Student 462 saved to model/arima\arima_student_462.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.1781, RMSE: 1.3524
#
# Training ARIMA for Student 463
# ARIMA model for Student 463 saved to model/arima\arima_student_463.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.4417, RMSE: 1.6499
#
# Training ARIMA for Student 464
# ARIMA model for Student 464 saved to model/arima\arima_student_464.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.9971, RMSE: 1.1776
#
# Training ARIMA for Student 465
# ARIMA model for Student 465 saved to model/arima\arima_student_465.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.7741, RMSE: 0.9321
#
# Training ARIMA for Student 466
# ARIMA model for Student 466 saved to model/arima\arima_student_466.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.1738, RMSE: 1.4113
#
# Training ARIMA for Student 467
# ARIMA model for Student 467 saved to model/arima\arima_student_467.pkl
# Best ARIMA params: (1, 0, 1), MAE: 1.0923, RMSE: 1.4861
#
# Training ARIMA for Student 468
# ARIMA model for Student 468 saved to model/arima\arima_student_468.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.8483, RMSE: 1.1275
#
# Training ARIMA for Student 469
# ARIMA model for Student 469 saved to model/arima\arima_student_469.pkl
# Best ARIMA params: (1, 0, 0), MAE: 1.3468, RMSE: 1.4808
#
# Training ARIMA for Student 470
# ARIMA model for Student 470 saved to model/arima\arima_student_470.pkl
# Best ARIMA params: (0, 1, 0), MAE: 1.1967, RMSE: 1.4063
#
# Training ARIMA for Student 471
# ARIMA model for Student 471 saved to model/arima\arima_student_471.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.7697, RMSE: 0.9069
#
# Training ARIMA for Student 472
# ARIMA model for Student 472 saved to model/arima\arima_student_472.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.0579, RMSE: 1.2190
#
# Training ARIMA for Student 473
# ARIMA model for Student 473 saved to model/arima\arima_student_473.pkl
# Best ARIMA params: (1, 1, 2), MAE: 0.8974, RMSE: 1.0044
#
# Training ARIMA for Student 474
# ARIMA model for Student 474 saved to model/arima\arima_student_474.pkl
# Best ARIMA params: (2, 0, 2), MAE: 1.0019, RMSE: 1.1543
#
# Training ARIMA for Student 475
# ARIMA model for Student 475 saved to model/arima\arima_student_475.pkl
# Best ARIMA params: (2, 0, 0), MAE: 1.2197, RMSE: 1.4741
#
# Training ARIMA for Student 476
# ARIMA model for Student 476 saved to model/arima\arima_student_476.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.0656, RMSE: 1.2608
#
# Training ARIMA for Student 477
# ARIMA model for Student 477 saved to model/arima\arima_student_477.pkl
# Best ARIMA params: (1, 2, 2), MAE: 1.4762, RMSE: 1.9581
#
# Training ARIMA for Student 478
# ARIMA model for Student 478 saved to model/arima\arima_student_478.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.4869, RMSE: 1.5628
#
# Training ARIMA for Student 479
# ARIMA model for Student 479 saved to model/arima\arima_student_479.pkl
# Best ARIMA params: (2, 0, 1), MAE: 0.8906, RMSE: 1.0662
#
# Training ARIMA for Student 480
# ARIMA model for Student 480 saved to model/arima\arima_student_480.pkl
# Best ARIMA params: (0, 1, 2), MAE: 1.1409, RMSE: 1.3971
#
# Training ARIMA for Student 481
# ARIMA model for Student 481 saved to model/arima\arima_student_481.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.7799, RMSE: 1.0085
#
# Training ARIMA for Student 482
# ARIMA model for Student 482 saved to model/arima\arima_student_482.pkl
# Best ARIMA params: (1, 0, 1), MAE: 0.9869, RMSE: 1.1805
#
# Training ARIMA for Student 483
# ARIMA model for Student 483 saved to model/arima\arima_student_483.pkl
# Best ARIMA params: (1, 0, 2), MAE: 0.6470, RMSE: 0.9958
#
# Training ARIMA for Student 484
# ARIMA model for Student 484 saved to model/arima\arima_student_484.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.5297, RMSE: 1.5665
#
# Training ARIMA for Student 485
# ARIMA model for Student 485 saved to model/arima\arima_student_485.pkl
# Best ARIMA params: (0, 2, 1), MAE: 0.9946, RMSE: 1.1941
#
# Training ARIMA for Student 486
# ARIMA model for Student 486 saved to model/arima\arima_student_486.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.1678, RMSE: 1.4044
#
# Training ARIMA for Student 487
# ARIMA model for Student 487 saved to model/arima\arima_student_487.pkl
# Best ARIMA params: (0, 1, 2), MAE: 1.2850, RMSE: 1.4785
#
# Training ARIMA for Student 488
# ARIMA model for Student 488 saved to model/arima\arima_student_488.pkl
# Best ARIMA params: (0, 1, 2), MAE: 1.5820, RMSE: 1.7162
#
# Training ARIMA for Student 489
# ARIMA model for Student 489 saved to model/arima\arima_student_489.pkl
# Best ARIMA params: (1, 2, 0), MAE: 1.4743, RMSE: 1.6249
#
# Training ARIMA for Student 490
# ARIMA model for Student 490 saved to model/arima\arima_student_490.pkl
# Best ARIMA params: (0, 0, 0), MAE: 1.5189, RMSE: 1.6231
#
# Training ARIMA for Student 491
# ARIMA model for Student 491 saved to model/arima\arima_student_491.pkl
# Best ARIMA params: (1, 0, 0), MAE: 0.4815, RMSE: 0.6539
#
# Training ARIMA for Student 492
# ARIMA model for Student 492 saved to model/arima\arima_student_492.pkl
# Best ARIMA params: (0, 2, 2), MAE: 0.9349, RMSE: 1.1490
#
# Training ARIMA for Student 493
# ARIMA model for Student 493 saved to model/arima\arima_student_493.pkl
# Best ARIMA params: (2, 2, 0), MAE: 0.9566, RMSE: 1.2291
#
# Training ARIMA for Student 494
# ARIMA model for Student 494 saved to model/arima\arima_student_494.pkl
# Best ARIMA params: (1, 1, 0), MAE: 0.8131, RMSE: 1.0003
#
# Training ARIMA for Student 495
# ARIMA model for Student 495 saved to model/arima\arima_student_495.pkl
# Best ARIMA params: (0, 0, 2), MAE: 1.0705, RMSE: 1.1656
#
# Training ARIMA for Student 496
# ARIMA model for Student 496 saved to model/arima\arima_student_496.pkl
# Best ARIMA params: (1, 0, 2), MAE: 1.1860, RMSE: 1.3334
#
# Training ARIMA for Student 497
# ARIMA model for Student 497 saved to model/arima\arima_student_497.pkl
# Best ARIMA params: (2, 0, 0), MAE: 0.7586, RMSE: 0.9442
#
# Training ARIMA for Student 498
# ARIMA model for Student 498 saved to model/arima\arima_student_498.pkl
# Best ARIMA params: (1, 0, 1), MAE: 1.1816, RMSE: 1.3045
#
# Training ARIMA for Student 499
# ARIMA model for Student 499 saved to model/arima\arima_student_499.pkl
# Best ARIMA params: (0, 2, 2), MAE: 0.7813, RMSE: 0.9821
#
# Training ARIMA for Student 500
# ARIMA model for Student 500 saved to model/arima\arima_student_500.pkl
# Best ARIMA params: (2, 0, 1), MAE: 1.4376, RMSE: 1.4763

# %%
import pandas as pd
import numpy as np
import os
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
import warnings
warnings.filterwarnings("ignore")

# Fungsi untuk memuat dan memproses data
def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    data['Date'] = pd.to_datetime(data['Date'])
    data['Risk Level'] = data['Risk Level'].map({'Low': 0, 'Medium': 1, 'High': 2})
    data = data.dropna()
    
    numerical_features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    scaler = MinMaxScaler()
    data[numerical_features] = scaler.fit_transform(data[numerical_features])
    
    return data, scaler

# Fungsi untuk membagi data berdasarkan waktu
def split_data_by_time(student_data, train_days=24):
    student_data = student_data.sort_values('Date')
    unique_dates = student_data['Date'].unique()
    train_dates = unique_dates[:train_days]
    test_dates = unique_dates[train_days:]
    train_data = student_data[student_data['Date'].isin(train_dates)]
    test_data = student_data[student_data['Date'].isin(test_dates)]
    return train_data, test_data

# Fungsi untuk uji stasioneritas
def adf_test(series):
    result = adfuller(series.dropna())
    return result[1] < 0.05  # True jika stasioner

# Fungsi untuk melatih ARIMA dan menghasilkan prediksi untuk test set
def train_arima_for_lstm(student_data, student_id):
    train_data, test_data = split_data_by_time(student_data)
    
    best_mae = float('inf')
    best_model_fit = None
    
    if adf_test(train_data['Stress Level (GSR)']):
        for p in range(3):
            for d in range(2):
                for q in range(3):
                    try:
                        arima_model = ARIMA(train_data['Stress Level (GSR)'], order=(p, d, q))
                        arima_fit = arima_model.fit()
                        arima_pred = arima_fit.forecast(steps=len(test_data))
                        mae = mean_absolute_error(test_data['Stress Level (GSR)'], arima_pred)
                        if mae < best_mae:
                            best_mae = mae
                            best_model_fit = arima_fit
                    except:
                        continue
    
    arima_forecast = best_model_fit.forecast(steps=len(test_data)) if best_model_fit else np.zeros(len(test_data))
    return np.array(arima_forecast)  # Konversi ke NumPy array

# Model LSTM
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.bn = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.4)
        self.risk_head = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim // 2, num_classes)
        )
        self.fc_stress = nn.Linear(hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        out, (h_n, _) = self.lstm(x)
        out = h_n[-1]
        out = self.bn(out)
        out = self.dropout(out)
        risk_logits = self.risk_head(out)
        stress = self.sigmoid(self.fc_stress(out))
        return risk_logits, stress.squeeze(1)

# Fungsi untuk melatih dan menyimpan model LSTM
def train_lstm(student_data, student_id, device, model_dir="model/lstm"):
    train_data, test_data = split_data_by_time(student_data)
    
    # Pastikan direktori model ada
    os.makedirs(model_dir, exist_ok=True)
    
    # Fitur dan target
    features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    target_cols = ['Risk Level', 'Stress Level (GSR)']
    
    # Persiapkan data
    X_train = train_data[features].values.reshape(-1, 1, len(features))
    X_test = test_data[features].values.reshape(-1, 1, len(features))
    y_train = train_data[target_cols].values
    
    # Dapatkan prediksi ARIMA untuk test set
    arima_forecast = train_arima_for_lstm(student_data, student_id)
    
    # Augmentasi data dengan prediksi ARIMA
    X_train_aug = np.concatenate((X_train, np.zeros((len(train_data), 1, 1))), axis=2)
    X_test_aug = np.concatenate((X_test, arima_forecast.reshape(-1, 1, 1)), axis=2)
    
    # Konversi ke tensor
    X_train_tensor = torch.tensor(X_train_aug, dtype=torch.float32).to(device)
    y_train_risk = torch.tensor(y_train[:, 0], dtype=torch.long).to(device)
    y_train_stress = torch.tensor(y_train[:, 1], dtype=torch.float32).to(device)
    
    # Inisialisasi model
    model = LSTMModel(input_dim=X_train_aug.shape[2], hidden_dim=64, num_classes=3).to(device)
    loss_risk = nn.CrossEntropyLoss()
    loss_stress = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    
    # Pelatihan
    for epoch in range(300):
        model.train()
        optimizer.zero_grad()
        risk_logits, stress_pred = model(X_train_tensor)
        loss1 = loss_risk(risk_logits, y_train_risk)
        loss2 = loss_stress(stress_pred, y_train_stress)
        loss = 1.5 * loss1 + 1.0 * loss2
        loss.backward()
        optimizer.step()
        
        if (epoch + 1) % 50 == 0:
            print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
    
    # Simpan model
    model_path = os.path.join(model_dir, f"lstm_student_{student_id}.pth")
    torch.save(model.state_dict(), model_path)
    print(f"LSTM model for Student {student_id} saved to {model_path}")
    
    return model

# Fungsi utama
def main():
    data, _ = load_and_preprocess_data('student_monnitoring_data.csv')
    user_groups = data.groupby('Student ID')
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Proses hanya 5 mahasiswa sebagai contoh
    for i, (student_id, student_data) in enumerate(user_groups):
        # if i >= 5:
        #     break
        print(f"\nTraining LSTM for Student {student_id}")
        train_lstm(student_data, student_id, device)

# %%
if __name__ == "__main__":
    main()
# Out:
# Training LSTM for Student 1
# Epoch 50, Loss: 0.6189
# Epoch 100, Loss: 0.4655
# Epoch 150, Loss: 0.2854
# Epoch 200, Loss: 0.5071
# Epoch 250, Loss: 0.2427
# Epoch 300, Loss: 0.1311
# LSTM model for Student 1 saved to model/lstm\lstm_student_1.pth
#
# Training LSTM for Student 2
# Epoch 50, Loss: 0.6935
# Epoch 100, Loss: 0.4845
# Epoch 150, Loss: 0.2654
# Epoch 200, Loss: 0.2345
# Epoch 250, Loss: 0.2019
# Epoch 300, Loss: 0.2388
# LSTM model for Student 2 saved to model/lstm\lstm_student_2.pth
#
# Training LSTM for Student 3
# Epoch 50, Loss: 0.6070
# Epoch 100, Loss: 0.3335
# Epoch 150, Loss: 0.2524
# Epoch 200, Loss: 0.1911
# Epoch 250, Loss: 0.1353
# Epoch 300, Loss: 0.0636
# LSTM model for Student 3 saved to model/lstm\lstm_student_3.pth
#
# Training LSTM for Student 4
# Epoch 50, Loss: 0.9294
# Epoch 100, Loss: 0.6679
# Epoch 150, Loss: 0.4912
# Epoch 200, Loss: 0.4347
# Epoch 250, Loss: 0.4121
# Epoch 300, Loss: 0.2643
# LSTM model for Student 4 saved to model/lstm\lstm_student_4.pth
#
# Training LSTM for Student 5
# Epoch 50, Loss: 0.7407
# Epoch 100, Loss: 0.5188
# Epoch 150, Loss: 0.3703
# Epoch 200, Loss: 0.2964
# Epoch 250, Loss: 0.2426
# Epoch 300, Loss: 0.2252
# LSTM model for Student 5 saved to model/lstm\lstm_student_5.pth
#
# Training LSTM for Student 6
# Epoch 50, Loss: 0.9679
# Epoch 100, Loss: 0.6470
# Epoch 150, Loss: 0.6230
# Epoch 200, Loss: 0.4895
# Epoch 250, Loss: 0.4298
# Epoch 300, Loss: 0.3089
# LSTM model for Student 6 saved to model/lstm\lstm_student_6.pth
#
# Training LSTM for Student 7
# Epoch 50, Loss: 0.8703
# Epoch 100, Loss: 0.6079
# Epoch 150, Loss: 0.4580
# Epoch 200, Loss: 0.3088
# Epoch 250, Loss: 0.3257
# Epoch 300, Loss: 0.2678
# LSTM model for Student 7 saved to model/lstm\lstm_student_7.pth
#
# Training LSTM for Student 8
# Epoch 50, Loss: 0.9729
# Epoch 100, Loss: 0.6617
# Epoch 150, Loss: 0.4660
# Epoch 200, Loss: 0.3926
# Epoch 250, Loss: 0.5330
# Epoch 300, Loss: 0.3678
# LSTM model for Student 8 saved to model/lstm\lstm_student_8.pth
#
# Training LSTM for Student 9
# Epoch 50, Loss: 0.8467
# Epoch 100, Loss: 0.5972
# Epoch 150, Loss: 0.5443
# Epoch 200, Loss: 0.3913
# Epoch 250, Loss: 0.2481
# Epoch 300, Loss: 0.2421
# LSTM model for Student 9 saved to model/lstm\lstm_student_9.pth
#
# Training LSTM for Student 10
# Epoch 50, Loss: 0.6322
# Epoch 100, Loss: 0.5345
# Epoch 150, Loss: 0.3311
# Epoch 200, Loss: 0.3508
# Epoch 250, Loss: 0.2845
# Epoch 300, Loss: 0.3436
# LSTM model for Student 10 saved to model/lstm\lstm_student_10.pth
#
# Training LSTM for Student 11
# Epoch 50, Loss: 1.0037
# Epoch 100, Loss: 0.8567
# Epoch 150, Loss: 0.6407
# Epoch 200, Loss: 0.5156
# Epoch 250, Loss: 0.4814
# Epoch 300, Loss: 0.3056
# LSTM model for Student 11 saved to model/lstm\lstm_student_11.pth
#
# Training LSTM for Student 12
# Epoch 50, Loss: 0.4737
# Epoch 100, Loss: 0.3471
# Epoch 150, Loss: 0.2020
# Epoch 200, Loss: 0.1513
# Epoch 250, Loss: 0.1453
# Epoch 300, Loss: 0.1765
# LSTM model for Student 12 saved to model/lstm\lstm_student_12.pth
#
# Training LSTM for Student 13
# Epoch 50, Loss: 0.7851
# Epoch 100, Loss: 0.5273
# Epoch 150, Loss: 0.3782
# Epoch 200, Loss: 0.2399
# Epoch 250, Loss: 0.2012
# Epoch 300, Loss: 0.1827
# LSTM model for Student 13 saved to model/lstm\lstm_student_13.pth
#
# Training LSTM for Student 14
# Epoch 50, Loss: 0.3985
# Epoch 100, Loss: 0.2695
# Epoch 150, Loss: 0.1193
# Epoch 200, Loss: 0.0943
# Epoch 250, Loss: 0.0288
# Epoch 300, Loss: 0.0384
# LSTM model for Student 14 saved to model/lstm\lstm_student_14.pth
#
# Training LSTM for Student 15
# Epoch 50, Loss: 0.6871
# Epoch 100, Loss: 0.3719
# Epoch 150, Loss: 0.2302
# Epoch 200, Loss: 0.1950
# Epoch 250, Loss: 0.1293
# Epoch 300, Loss: 0.1127
# LSTM model for Student 15 saved to model/lstm\lstm_student_15.pth
#
# Training LSTM for Student 16
# Epoch 50, Loss: 1.1178
# Epoch 100, Loss: 0.8706
# Epoch 150, Loss: 0.8980
# Epoch 200, Loss: 0.7465
# Epoch 250, Loss: 0.6267
# Epoch 300, Loss: 0.5678
# LSTM model for Student 16 saved to model/lstm\lstm_student_16.pth
#
# Training LSTM for Student 17
# Epoch 50, Loss: 0.9361
# Epoch 100, Loss: 0.7601
# Epoch 150, Loss: 0.6512
# Epoch 200, Loss: 0.4669
# Epoch 250, Loss: 0.4752
# Epoch 300, Loss: 0.4358
# LSTM model for Student 17 saved to model/lstm\lstm_student_17.pth
#
# Training LSTM for Student 18
# Epoch 50, Loss: 0.8122
# Epoch 100, Loss: 0.4727
# Epoch 150, Loss: 0.5576
# Epoch 200, Loss: 0.2716
# Epoch 250, Loss: 0.3230
# Epoch 300, Loss: 0.2911
# LSTM model for Student 18 saved to model/lstm\lstm_student_18.pth
#
# Training LSTM for Student 19
# Epoch 50, Loss: 0.7972
# Epoch 100, Loss: 0.5205
# Epoch 150, Loss: 0.3378
# Epoch 200, Loss: 0.3101
# Epoch 250, Loss: 0.3136
# Epoch 300, Loss: 0.1784
# LSTM model for Student 19 saved to model/lstm\lstm_student_19.pth
#
# Training LSTM for Student 20
# Epoch 50, Loss: 0.5999
# Epoch 100, Loss: 0.3466
# Epoch 150, Loss: 0.5277
# Epoch 200, Loss: 0.2938
# Epoch 250, Loss: 0.2121
# Epoch 300, Loss: 0.3211
# LSTM model for Student 20 saved to model/lstm\lstm_student_20.pth
#
# Training LSTM for Student 21
# Epoch 50, Loss: 0.6592
# Epoch 100, Loss: 0.5129
# Epoch 150, Loss: 0.3753
# Epoch 200, Loss: 0.3390
# Epoch 250, Loss: 0.2196
# Epoch 300, Loss: 0.2167
# LSTM model for Student 21 saved to model/lstm\lstm_student_21.pth
#
# Training LSTM for Student 22
# Epoch 50, Loss: 0.8937
# Epoch 100, Loss: 0.6413
# Epoch 150, Loss: 0.4856
# Epoch 200, Loss: 0.5770
# Epoch 250, Loss: 0.3443
# Epoch 300, Loss: 0.2647
# LSTM model for Student 22 saved to model/lstm\lstm_student_22.pth
#
# Training LSTM for Student 23
# Epoch 50, Loss: 0.4825
# Epoch 100, Loss: 0.1729
# Epoch 150, Loss: 0.1403
# Epoch 200, Loss: 0.1548
# Epoch 250, Loss: 0.1047
# Epoch 300, Loss: 0.0384
# LSTM model for Student 23 saved to model/lstm\lstm_student_23.pth
#
# Training LSTM for Student 24
# Epoch 50, Loss: 0.7663
# Epoch 100, Loss: 0.3382
# Epoch 150, Loss: 0.2113
# Epoch 200, Loss: 0.0909
# Epoch 250, Loss: 0.0817
# Epoch 300, Loss: 0.1100
# LSTM model for Student 24 saved to model/lstm\lstm_student_24.pth
#
# Training LSTM for Student 25
# Epoch 50, Loss: 0.8189
# Epoch 100, Loss: 0.5989
# Epoch 150, Loss: 0.5590
# Epoch 200, Loss: 0.5203
# Epoch 250, Loss: 0.4257
# Epoch 300, Loss: 0.3878
# LSTM model for Student 25 saved to model/lstm\lstm_student_25.pth
#
# Training LSTM for Student 26
# Epoch 50, Loss: 1.0021
# Epoch 100, Loss: 0.6858
# Epoch 150, Loss: 0.7470
# Epoch 200, Loss: 0.3587
# Epoch 250, Loss: 0.4947
# Epoch 300, Loss: 0.3019
# LSTM model for Student 26 saved to model/lstm\lstm_student_26.pth
#
# Training LSTM for Student 27
# Epoch 50, Loss: 1.0017
# Epoch 100, Loss: 0.5800
# Epoch 150, Loss: 0.5347
# Epoch 200, Loss: 0.4665
# Epoch 250, Loss: 0.4385
# Epoch 300, Loss: 0.3466
# LSTM model for Student 27 saved to model/lstm\lstm_student_27.pth
#
# Training LSTM for Student 28
# Epoch 50, Loss: 1.0555
# Epoch 100, Loss: 0.5143
# Epoch 150, Loss: 0.4274
# Epoch 200, Loss: 0.3204
# Epoch 250, Loss: 0.3237
# Epoch 300, Loss: 0.4776
# LSTM model for Student 28 saved to model/lstm\lstm_student_28.pth
#
# Training LSTM for Student 29
# Epoch 50, Loss: 0.5678
# Epoch 100, Loss: 0.3416
# Epoch 150, Loss: 0.3060
# Epoch 200, Loss: 0.3264
# Epoch 250, Loss: 0.1333
# Epoch 300, Loss: 0.2489
# LSTM model for Student 29 saved to model/lstm\lstm_student_29.pth
#
# Training LSTM for Student 30
# Epoch 50, Loss: 0.9030
# Epoch 100, Loss: 0.7074
# Epoch 150, Loss: 0.5571
# Epoch 200, Loss: 0.6922
# Epoch 250, Loss: 0.4472
# Epoch 300, Loss: 0.4510
# LSTM model for Student 30 saved to model/lstm\lstm_student_30.pth
#
# Training LSTM for Student 31
# Epoch 50, Loss: 0.7461
# Epoch 100, Loss: 0.3337
# Epoch 150, Loss: 0.2167
# Epoch 200, Loss: 0.1260
# Epoch 250, Loss: 0.2363
# Epoch 300, Loss: 0.1646
# LSTM model for Student 31 saved to model/lstm\lstm_student_31.pth
#
# Training LSTM for Student 32
# Epoch 50, Loss: 0.8813
# Epoch 100, Loss: 0.6851
# Epoch 150, Loss: 0.4821
# Epoch 200, Loss: 0.3866
# Epoch 250, Loss: 0.2794
# Epoch 300, Loss: 0.3117
# LSTM model for Student 32 saved to model/lstm\lstm_student_32.pth
#
# Training LSTM for Student 33
# Epoch 50, Loss: 0.8422
# Epoch 100, Loss: 0.5117
# Epoch 150, Loss: 0.3349
# Epoch 200, Loss: 0.3135
# Epoch 250, Loss: 0.2294
# Epoch 300, Loss: 0.1330
# LSTM model for Student 33 saved to model/lstm\lstm_student_33.pth
#
# Training LSTM for Student 34
# Epoch 50, Loss: 0.7199
# Epoch 100, Loss: 0.4109
# Epoch 150, Loss: 0.3846
# Epoch 200, Loss: 0.1787
# Epoch 250, Loss: 0.2080
# Epoch 300, Loss: 0.1355
# LSTM model for Student 34 saved to model/lstm\lstm_student_34.pth
#
# Training LSTM for Student 35
# Epoch 50, Loss: 0.6754
# Epoch 100, Loss: 0.3864
# Epoch 150, Loss: 0.2745
# Epoch 200, Loss: 0.2400
# Epoch 250, Loss: 0.2126
# Epoch 300, Loss: 0.1843
# LSTM model for Student 35 saved to model/lstm\lstm_student_35.pth
#
# Training LSTM for Student 36
# Epoch 50, Loss: 0.7374
# Epoch 100, Loss: 0.4366
# Epoch 150, Loss: 0.3450
# Epoch 200, Loss: 0.3826
# Epoch 250, Loss: 0.3456
# Epoch 300, Loss: 0.2236
# LSTM model for Student 36 saved to model/lstm\lstm_student_36.pth
#
# Training LSTM for Student 37
# Epoch 50, Loss: 0.7715
# Epoch 100, Loss: 0.5369
# Epoch 150, Loss: 0.4812
# Epoch 200, Loss: 0.2173
# Epoch 250, Loss: 0.2230
# Epoch 300, Loss: 0.1804
# LSTM model for Student 37 saved to model/lstm\lstm_student_37.pth
#
# Training LSTM for Student 38
# Epoch 50, Loss: 0.9158
# Epoch 100, Loss: 0.5534
# Epoch 150, Loss: 0.4911
# Epoch 200, Loss: 0.4894
# Epoch 250, Loss: 0.5957
# Epoch 300, Loss: 0.4208
# LSTM model for Student 38 saved to model/lstm\lstm_student_38.pth
#
# Training LSTM for Student 39
# Epoch 50, Loss: 0.7450
# Epoch 100, Loss: 0.5596
# Epoch 150, Loss: 0.3812
# Epoch 200, Loss: 0.4601
# Epoch 250, Loss: 0.3458
# Epoch 300, Loss: 0.3134
# LSTM model for Student 39 saved to model/lstm\lstm_student_39.pth
#
# Training LSTM for Student 40
# Epoch 50, Loss: 0.7207
# Epoch 100, Loss: 0.4852
# Epoch 150, Loss: 0.3744
# Epoch 200, Loss: 0.4299
# Epoch 250, Loss: 0.2627
# Epoch 300, Loss: 0.2133
# LSTM model for Student 40 saved to model/lstm\lstm_student_40.pth
#
# Training LSTM for Student 41
# Epoch 50, Loss: 0.6966
# Epoch 100, Loss: 0.4149
# Epoch 150, Loss: 0.3566
# Epoch 200, Loss: 0.3629
# Epoch 250, Loss: 0.1780
# Epoch 300, Loss: 0.3321
# LSTM model for Student 41 saved to model/lstm\lstm_student_41.pth
#
# Training LSTM for Student 42
# Epoch 50, Loss: 0.5560
# Epoch 100, Loss: 0.4405
# Epoch 150, Loss: 0.3070
# Epoch 200, Loss: 0.2373
# Epoch 250, Loss: 0.1674
# Epoch 300, Loss: 0.2769
# LSTM model for Student 42 saved to model/lstm\lstm_student_42.pth
#
# Training LSTM for Student 43
# Epoch 50, Loss: 0.8984
# Epoch 100, Loss: 0.5924
# Epoch 150, Loss: 0.5198
# Epoch 200, Loss: 0.5463
# Epoch 250, Loss: 0.3065
# Epoch 300, Loss: 0.3876
# LSTM model for Student 43 saved to model/lstm\lstm_student_43.pth
#
# Training LSTM for Student 44
# Epoch 50, Loss: 0.8951
# Epoch 100, Loss: 0.7397
# Epoch 150, Loss: 0.5160
# Epoch 200, Loss: 0.5135
# Epoch 250, Loss: 0.4379
# Epoch 300, Loss: 0.4794
# LSTM model for Student 44 saved to model/lstm\lstm_student_44.pth
#
# Training LSTM for Student 45
# Epoch 50, Loss: 0.9005
# Epoch 100, Loss: 0.6014
# Epoch 150, Loss: 0.5479
# Epoch 200, Loss: 0.6336
# Epoch 250, Loss: 0.4406
# Epoch 300, Loss: 0.4228
# LSTM model for Student 45 saved to model/lstm\lstm_student_45.pth
#
# Training LSTM for Student 46
# Epoch 50, Loss: 0.9558
# Epoch 100, Loss: 0.5733
# Epoch 150, Loss: 0.6637
# Epoch 200, Loss: 0.6273
# Epoch 250, Loss: 0.4227
# Epoch 300, Loss: 0.3505
# LSTM model for Student 46 saved to model/lstm\lstm_student_46.pth
#
# Training LSTM for Student 47
# Epoch 50, Loss: 0.6375
# Epoch 100, Loss: 0.3940
# Epoch 150, Loss: 0.2722
# Epoch 200, Loss: 0.2410
# Epoch 250, Loss: 0.1689
# Epoch 300, Loss: 0.0996
# LSTM model for Student 47 saved to model/lstm\lstm_student_47.pth
#
# Training LSTM for Student 48
# Epoch 50, Loss: 0.8205
# Epoch 100, Loss: 0.5367
# Epoch 150, Loss: 0.4573
# Epoch 200, Loss: 0.3291
# Epoch 250, Loss: 0.2675
# Epoch 300, Loss: 0.3640
# LSTM model for Student 48 saved to model/lstm\lstm_student_48.pth
#
# Training LSTM for Student 49
# Epoch 50, Loss: 0.8130
# Epoch 100, Loss: 0.5465
# Epoch 150, Loss: 0.5821
# Epoch 200, Loss: 0.4711
# Epoch 250, Loss: 0.4197
# Epoch 300, Loss: 0.2571
# LSTM model for Student 49 saved to model/lstm\lstm_student_49.pth
#
# Training LSTM for Student 50
# Epoch 50, Loss: 0.5887
# Epoch 100, Loss: 0.5100
# Epoch 150, Loss: 0.3210
# Epoch 200, Loss: 0.1404
# Epoch 250, Loss: 0.1124
# Epoch 300, Loss: 0.1549
# LSTM model for Student 50 saved to model/lstm\lstm_student_50.pth
#
# Training LSTM for Student 51
# Epoch 50, Loss: 0.6419
# Epoch 100, Loss: 0.3104
# Epoch 150, Loss: 0.1977
# Epoch 200, Loss: 0.2204
# Epoch 250, Loss: 0.1527
# Epoch 300, Loss: 0.1069
# LSTM model for Student 51 saved to model/lstm\lstm_student_51.pth
#
# Training LSTM for Student 52
# Epoch 50, Loss: 0.8994
# Epoch 100, Loss: 0.6788
# Epoch 150, Loss: 0.5366
# Epoch 200, Loss: 0.4601
# Epoch 250, Loss: 0.2551
# Epoch 300, Loss: 0.2402
# LSTM model for Student 52 saved to model/lstm\lstm_student_52.pth
#
# Training LSTM for Student 53
# Epoch 50, Loss: 1.0599
# Epoch 100, Loss: 0.6999
# Epoch 150, Loss: 0.6076
# Epoch 200, Loss: 0.5252
# Epoch 250, Loss: 0.4383
# Epoch 300, Loss: 0.5077
# LSTM model for Student 53 saved to model/lstm\lstm_student_53.pth
#
# Training LSTM for Student 54
# Epoch 50, Loss: 0.7680
# Epoch 100, Loss: 0.4874
# Epoch 150, Loss: 0.3672
# Epoch 200, Loss: 0.3560
# Epoch 250, Loss: 0.2154
# Epoch 300, Loss: 0.1866
# LSTM model for Student 54 saved to model/lstm\lstm_student_54.pth
#
# Training LSTM for Student 55
# Epoch 50, Loss: 0.9352
# Epoch 100, Loss: 0.6547
# Epoch 150, Loss: 0.3561
# Epoch 200, Loss: 0.2766
# Epoch 250, Loss: 0.4534
# Epoch 300, Loss: 0.3141
# LSTM model for Student 55 saved to model/lstm\lstm_student_55.pth
#
# Training LSTM for Student 56
# Epoch 50, Loss: 1.0950
# Epoch 100, Loss: 0.7387
# Epoch 150, Loss: 0.6490
# Epoch 200, Loss: 0.5072
# Epoch 250, Loss: 0.6181
# Epoch 300, Loss: 0.3640
# LSTM model for Student 56 saved to model/lstm\lstm_student_56.pth
#
# Training LSTM for Student 57
# Epoch 50, Loss: 0.5301
# Epoch 100, Loss: 0.2323
# Epoch 150, Loss: 0.1496
# Epoch 200, Loss: 0.1544
# Epoch 250, Loss: 0.1317
# Epoch 300, Loss: 0.0735
# LSTM model for Student 57 saved to model/lstm\lstm_student_57.pth
#
# Training LSTM for Student 58
# Epoch 50, Loss: 0.6262
# Epoch 100, Loss: 0.4293
# Epoch 150, Loss: 0.3541
# Epoch 200, Loss: 0.2750
# Epoch 250, Loss: 0.2370
# Epoch 300, Loss: 0.2179
# LSTM model for Student 58 saved to model/lstm\lstm_student_58.pth
#
# Training LSTM for Student 59
# Epoch 50, Loss: 0.6111
# Epoch 100, Loss: 0.5247
# Epoch 150, Loss: 0.3299
# Epoch 200, Loss: 0.2803
# Epoch 250, Loss: 0.2503
# Epoch 300, Loss: 0.2772
# LSTM model for Student 59 saved to model/lstm\lstm_student_59.pth
#
# Training LSTM for Student 60
# Epoch 50, Loss: 0.8894
# Epoch 100, Loss: 0.4425
# Epoch 150, Loss: 0.4038
# Epoch 200, Loss: 0.3136
# Epoch 250, Loss: 0.3032
# Epoch 300, Loss: 0.3258
# LSTM model for Student 60 saved to model/lstm\lstm_student_60.pth
#
# Training LSTM for Student 61
# Epoch 50, Loss: 0.7240
# Epoch 100, Loss: 0.4793
# Epoch 150, Loss: 0.3716
# Epoch 200, Loss: 0.1705
# Epoch 250, Loss: 0.0811
# Epoch 300, Loss: 0.1433
# LSTM model for Student 61 saved to model/lstm\lstm_student_61.pth
#
# Training LSTM for Student 62
# Epoch 50, Loss: 0.9197
# Epoch 100, Loss: 0.6608
# Epoch 150, Loss: 0.5383
# Epoch 200, Loss: 0.3422
# Epoch 250, Loss: 0.2111
# Epoch 300, Loss: 0.1831
# LSTM model for Student 62 saved to model/lstm\lstm_student_62.pth
#
# Training LSTM for Student 63
# Epoch 50, Loss: 0.7483
# Epoch 100, Loss: 0.5005
# Epoch 150, Loss: 0.4046
# Epoch 200, Loss: 0.3248
# Epoch 250, Loss: 0.3127
# Epoch 300, Loss: 0.2316
# LSTM model for Student 63 saved to model/lstm\lstm_student_63.pth
#
# Training LSTM for Student 64
# Epoch 50, Loss: 0.7153
# Epoch 100, Loss: 0.5150
# Epoch 150, Loss: 0.3885
# Epoch 200, Loss: 0.3593
# Epoch 250, Loss: 0.1210
# Epoch 300, Loss: 0.1153
# LSTM model for Student 64 saved to model/lstm\lstm_student_64.pth
#
# Training LSTM for Student 65
# Epoch 50, Loss: 0.7960
# Epoch 100, Loss: 0.5175
# Epoch 150, Loss: 0.3690
# Epoch 200, Loss: 0.3343
# Epoch 250, Loss: 0.2720
# Epoch 300, Loss: 0.2680
# LSTM model for Student 65 saved to model/lstm\lstm_student_65.pth
#
# Training LSTM for Student 66
# Epoch 50, Loss: 0.7142
# Epoch 100, Loss: 0.5137
# Epoch 150, Loss: 0.3713
# Epoch 200, Loss: 0.4059
# Epoch 250, Loss: 0.2353
# Epoch 300, Loss: 0.3031
# LSTM model for Student 66 saved to model/lstm\lstm_student_66.pth
#
# Training LSTM for Student 67
# Epoch 50, Loss: 0.8354
# Epoch 100, Loss: 0.6352
# Epoch 150, Loss: 0.6104
# Epoch 200, Loss: 0.4625
# Epoch 250, Loss: 0.3317
# Epoch 300, Loss: 0.4084
# LSTM model for Student 67 saved to model/lstm\lstm_student_67.pth
#
# Training LSTM for Student 68
# Epoch 50, Loss: 0.8744
# Epoch 100, Loss: 0.6536
# Epoch 150, Loss: 0.4885
# Epoch 200, Loss: 0.2569
# Epoch 250, Loss: 0.1933
# Epoch 300, Loss: 0.2292
# LSTM model for Student 68 saved to model/lstm\lstm_student_68.pth
#
# Training LSTM for Student 69
# Epoch 50, Loss: 0.6483
# Epoch 100, Loss: 0.2631
# Epoch 150, Loss: 0.2399
# Epoch 200, Loss: 0.1769
# Epoch 250, Loss: 0.1057
# Epoch 300, Loss: 0.1299
# LSTM model for Student 69 saved to model/lstm\lstm_student_69.pth
#
# Training LSTM for Student 70
# Epoch 50, Loss: 0.8795
# Epoch 100, Loss: 0.5952
# Epoch 150, Loss: 0.4840
# Epoch 200, Loss: 0.4711
# Epoch 250, Loss: 0.4053
# Epoch 300, Loss: 0.3092
# LSTM model for Student 70 saved to model/lstm\lstm_student_70.pth
#
# Training LSTM for Student 71
# Epoch 50, Loss: 0.9510
# Epoch 100, Loss: 0.8665
# Epoch 150, Loss: 0.6858
# Epoch 200, Loss: 0.5516
# Epoch 250, Loss: 0.5591
# Epoch 300, Loss: 0.3313
# LSTM model for Student 71 saved to model/lstm\lstm_student_71.pth
#
# Training LSTM for Student 72
# Epoch 50, Loss: 0.9659
# Epoch 100, Loss: 0.8095
# Epoch 150, Loss: 0.8985
# Epoch 200, Loss: 0.5776
# Epoch 250, Loss: 0.5282
# Epoch 300, Loss: 0.5039
# LSTM model for Student 72 saved to model/lstm\lstm_student_72.pth
#
# Training LSTM for Student 73
# Epoch 50, Loss: 1.0422
# Epoch 100, Loss: 0.7233
# Epoch 150, Loss: 0.8457
# Epoch 200, Loss: 0.6099
# Epoch 250, Loss: 0.4685
# Epoch 300, Loss: 0.3005
# LSTM model for Student 73 saved to model/lstm\lstm_student_73.pth
#
# Training LSTM for Student 74
# Epoch 50, Loss: 0.7510
# Epoch 100, Loss: 0.4007
# Epoch 150, Loss: 0.2484
# Epoch 200, Loss: 0.1806
# Epoch 250, Loss: 0.1558
# Epoch 300, Loss: 0.2012
# LSTM model for Student 74 saved to model/lstm\lstm_student_74.pth
#
# Training LSTM for Student 75
# Epoch 50, Loss: 1.0989
# Epoch 100, Loss: 0.9466
# Epoch 150, Loss: 0.6107
# Epoch 200, Loss: 0.5110
# Epoch 250, Loss: 0.4847
# Epoch 300, Loss: 0.4469
# LSTM model for Student 75 saved to model/lstm\lstm_student_75.pth
#
# Training LSTM for Student 76
# Epoch 50, Loss: 0.9388
# Epoch 100, Loss: 0.5252
# Epoch 150, Loss: 0.5130
# Epoch 200, Loss: 0.3586
# Epoch 250, Loss: 0.2248
# Epoch 300, Loss: 0.2556
# LSTM model for Student 76 saved to model/lstm\lstm_student_76.pth
#
# Training LSTM for Student 77
# Epoch 50, Loss: 0.9667
# Epoch 100, Loss: 0.7220
# Epoch 150, Loss: 0.6783
# Epoch 200, Loss: 0.5142
# Epoch 250, Loss: 0.3752
# Epoch 300, Loss: 0.4057
# LSTM model for Student 77 saved to model/lstm\lstm_student_77.pth
#
# Training LSTM for Student 78
# Epoch 50, Loss: 0.9811
# Epoch 100, Loss: 0.6340
# Epoch 150, Loss: 0.5630
# Epoch 200, Loss: 0.4664
# Epoch 250, Loss: 0.3413
# Epoch 300, Loss: 0.3001
# LSTM model for Student 78 saved to model/lstm\lstm_student_78.pth
#
# Training LSTM for Student 79
# Epoch 50, Loss: 0.7956
# Epoch 100, Loss: 0.4621
# Epoch 150, Loss: 0.3636
# Epoch 200, Loss: 0.2993
# Epoch 250, Loss: 0.2750
# Epoch 300, Loss: 0.1300
# LSTM model for Student 79 saved to model/lstm\lstm_student_79.pth
#
# Training LSTM for Student 80
# Epoch 50, Loss: 1.0361
# Epoch 100, Loss: 0.7956
# Epoch 150, Loss: 0.9893
# Epoch 200, Loss: 0.8579
# Epoch 250, Loss: 0.6828
# Epoch 300, Loss: 0.5733
# LSTM model for Student 80 saved to model/lstm\lstm_student_80.pth
#
# Training LSTM for Student 81
# Epoch 50, Loss: 0.8535
# Epoch 100, Loss: 0.5205
# Epoch 150, Loss: 0.3057
# Epoch 200, Loss: 0.1979
# Epoch 250, Loss: 0.2063
# Epoch 300, Loss: 0.1421
# LSTM model for Student 81 saved to model/lstm\lstm_student_81.pth
#
# Training LSTM for Student 82
# Epoch 50, Loss: 0.5707
# Epoch 100, Loss: 0.2712
# Epoch 150, Loss: 0.3782
# Epoch 200, Loss: 0.2778
# Epoch 250, Loss: 0.3241
# Epoch 300, Loss: 0.1645
# LSTM model for Student 82 saved to model/lstm\lstm_student_82.pth
#
# Training LSTM for Student 83
# Epoch 50, Loss: 0.8769
# Epoch 100, Loss: 0.5860
# Epoch 150, Loss: 0.4281
# Epoch 200, Loss: 0.2899
# Epoch 250, Loss: 0.1698
# Epoch 300, Loss: 0.2208
# LSTM model for Student 83 saved to model/lstm\lstm_student_83.pth
#
# Training LSTM for Student 84
# Epoch 50, Loss: 0.7679
# Epoch 100, Loss: 0.6145
# Epoch 150, Loss: 0.4640
# Epoch 200, Loss: 0.4547
# Epoch 250, Loss: 0.3653
# Epoch 300, Loss: 0.2819
# LSTM model for Student 84 saved to model/lstm\lstm_student_84.pth
#
# Training LSTM for Student 85
# Epoch 50, Loss: 1.0228
# Epoch 100, Loss: 0.7407
# Epoch 150, Loss: 0.6079
# Epoch 200, Loss: 0.5311
# Epoch 250, Loss: 0.5440
# Epoch 300, Loss: 0.3518
# LSTM model for Student 85 saved to model/lstm\lstm_student_85.pth
#
# Training LSTM for Student 86
# Epoch 50, Loss: 0.8777
# Epoch 100, Loss: 0.6182
# Epoch 150, Loss: 0.5167
# Epoch 200, Loss: 0.4011
# Epoch 250, Loss: 0.2533
# Epoch 300, Loss: 0.3526
# LSTM model for Student 86 saved to model/lstm\lstm_student_86.pth
#
# Training LSTM for Student 87
# Epoch 50, Loss: 0.7595
# Epoch 100, Loss: 0.5093
# Epoch 150, Loss: 0.5211
# Epoch 200, Loss: 0.3987
# Epoch 250, Loss: 0.3728
# Epoch 300, Loss: 0.5047
# LSTM model for Student 87 saved to model/lstm\lstm_student_87.pth
#
# Training LSTM for Student 88
# Epoch 50, Loss: 0.7255
# Epoch 100, Loss: 0.5989
# Epoch 150, Loss: 0.4139
# Epoch 200, Loss: 0.3922
# Epoch 250, Loss: 0.3078
# Epoch 300, Loss: 0.3942
# LSTM model for Student 88 saved to model/lstm\lstm_student_88.pth
#
# Training LSTM for Student 89
# Epoch 50, Loss: 0.8135
# Epoch 100, Loss: 0.5775
# Epoch 150, Loss: 0.3004
# Epoch 200, Loss: 0.1596
# Epoch 250, Loss: 0.0828
# Epoch 300, Loss: 0.1209
# LSTM model for Student 89 saved to model/lstm\lstm_student_89.pth
#
# Training LSTM for Student 90
# Epoch 50, Loss: 0.9641
# Epoch 100, Loss: 0.7048
# Epoch 150, Loss: 0.4895
# Epoch 200, Loss: 0.4859
# Epoch 250, Loss: 0.2265
# Epoch 300, Loss: 0.2800
# LSTM model for Student 90 saved to model/lstm\lstm_student_90.pth
#
# Training LSTM for Student 91
# Epoch 50, Loss: 0.5196
# Epoch 100, Loss: 0.1453
# Epoch 150, Loss: 0.0429
# Epoch 200, Loss: 0.0753
# Epoch 250, Loss: 0.1609
# Epoch 300, Loss: 0.0652
# LSTM model for Student 91 saved to model/lstm\lstm_student_91.pth
#
# Training LSTM for Student 92
# Epoch 50, Loss: 0.6205
# Epoch 100, Loss: 0.2601
# Epoch 150, Loss: 0.2873
# Epoch 200, Loss: 0.2685
# Epoch 250, Loss: 0.2316
# Epoch 300, Loss: 0.0772
# LSTM model for Student 92 saved to model/lstm\lstm_student_92.pth
#
# Training LSTM for Student 93
# Epoch 50, Loss: 0.4392
# Epoch 100, Loss: 0.1468
# Epoch 150, Loss: 0.0551
# Epoch 200, Loss: 0.0632
# Epoch 250, Loss: 0.0391
# Epoch 300, Loss: 0.0424
# LSTM model for Student 93 saved to model/lstm\lstm_student_93.pth
#
# Training LSTM for Student 94
# Epoch 50, Loss: 0.7647
# Epoch 100, Loss: 0.4476
# Epoch 150, Loss: 0.4856
# Epoch 200, Loss: 0.3320
# Epoch 250, Loss: 0.3888
# Epoch 300, Loss: 0.3418
# LSTM model for Student 94 saved to model/lstm\lstm_student_94.pth
#
# Training LSTM for Student 95
# Epoch 50, Loss: 0.9628
# Epoch 100, Loss: 0.6278
# Epoch 150, Loss: 0.5251
# Epoch 200, Loss: 0.5313
# Epoch 250, Loss: 0.5635
# Epoch 300, Loss: 0.4378
# LSTM model for Student 95 saved to model/lstm\lstm_student_95.pth
#
# Training LSTM for Student 96
# Epoch 50, Loss: 0.9592
# Epoch 100, Loss: 0.6633
# Epoch 150, Loss: 0.5730
# Epoch 200, Loss: 0.4379
# Epoch 250, Loss: 0.3553
# Epoch 300, Loss: 0.3528
# LSTM model for Student 96 saved to model/lstm\lstm_student_96.pth
#
# Training LSTM for Student 97
# Epoch 50, Loss: 0.9868
# Epoch 100, Loss: 0.7257
# Epoch 150, Loss: 0.6346
# Epoch 200, Loss: 0.7821
# Epoch 250, Loss: 0.6086
# Epoch 300, Loss: 0.4837
# LSTM model for Student 97 saved to model/lstm\lstm_student_97.pth
#
# Training LSTM for Student 98
# Epoch 50, Loss: 0.9316
# Epoch 100, Loss: 0.5693
# Epoch 150, Loss: 0.5688
# Epoch 200, Loss: 0.4439
# Epoch 250, Loss: 0.3336
# Epoch 300, Loss: 0.2901
# LSTM model for Student 98 saved to model/lstm\lstm_student_98.pth
#
# Training LSTM for Student 99
# Epoch 50, Loss: 0.8575
# Epoch 100, Loss: 0.5675
# Epoch 150, Loss: 0.4863
# Epoch 200, Loss: 0.2927
# Epoch 250, Loss: 0.3083
# Epoch 300, Loss: 0.2445
# LSTM model for Student 99 saved to model/lstm\lstm_student_99.pth
#
# Training LSTM for Student 100
# Epoch 50, Loss: 0.8341
# Epoch 100, Loss: 0.4408
# Epoch 150, Loss: 0.4015
# Epoch 200, Loss: 0.3453
# Epoch 250, Loss: 0.2527
# Epoch 300, Loss: 0.1658
# LSTM model for Student 100 saved to model/lstm\lstm_student_100.pth
#
# Training LSTM for Student 101
# Epoch 50, Loss: 0.9063
# Epoch 100, Loss: 0.6360
# Epoch 150, Loss: 0.6555
# Epoch 200, Loss: 0.4895
# Epoch 250, Loss: 0.4688
# Epoch 300, Loss: 0.4364
# LSTM model for Student 101 saved to model/lstm\lstm_student_101.pth
#
# Training LSTM for Student 102
# Epoch 50, Loss: 0.8217
# Epoch 100, Loss: 0.6835
# Epoch 150, Loss: 0.6988
# Epoch 200, Loss: 0.4596
# Epoch 250, Loss: 0.4350
# Epoch 300, Loss: 0.4852
# LSTM model for Student 102 saved to model/lstm\lstm_student_102.pth
#
# Training LSTM for Student 103
# Epoch 50, Loss: 0.9441
# Epoch 100, Loss: 0.7340
# Epoch 150, Loss: 0.6291
# Epoch 200, Loss: 0.7271
# Epoch 250, Loss: 0.5772
# Epoch 300, Loss: 0.3814
# LSTM model for Student 103 saved to model/lstm\lstm_student_103.pth
#
# Training LSTM for Student 104
# Epoch 50, Loss: 0.9307
# Epoch 100, Loss: 0.7299
# Epoch 150, Loss: 0.5468
# Epoch 200, Loss: 0.6536
# Epoch 250, Loss: 0.4199
# Epoch 300, Loss: 0.3917
# LSTM model for Student 104 saved to model/lstm\lstm_student_104.pth
#
# Training LSTM for Student 105
# Epoch 50, Loss: 0.9241
# Epoch 100, Loss: 0.7486
# Epoch 150, Loss: 0.5552
# Epoch 200, Loss: 0.5425
# Epoch 250, Loss: 0.4693
# Epoch 300, Loss: 0.3673
# LSTM model for Student 105 saved to model/lstm\lstm_student_105.pth
#
# Training LSTM for Student 106
# Epoch 50, Loss: 0.9712
# Epoch 100, Loss: 0.8845
# Epoch 150, Loss: 0.6784
# Epoch 200, Loss: 0.6736
# Epoch 250, Loss: 0.4674
# Epoch 300, Loss: 0.3710
# LSTM model for Student 106 saved to model/lstm\lstm_student_106.pth
#
# Training LSTM for Student 107
# Epoch 50, Loss: 0.9734
# Epoch 100, Loss: 0.6089
# Epoch 150, Loss: 0.6337
# Epoch 200, Loss: 0.4240
# Epoch 250, Loss: 0.3419
# Epoch 300, Loss: 0.3776
# LSTM model for Student 107 saved to model/lstm\lstm_student_107.pth
#
# Training LSTM for Student 108
# Epoch 50, Loss: 1.1995
# Epoch 100, Loss: 0.7582
# Epoch 150, Loss: 0.5437
# Epoch 200, Loss: 0.3811
# Epoch 250, Loss: 0.5392
# Epoch 300, Loss: 0.3377
# LSTM model for Student 108 saved to model/lstm\lstm_student_108.pth
#
# Training LSTM for Student 109
# Epoch 50, Loss: 0.8532
# Epoch 100, Loss: 0.5285
# Epoch 150, Loss: 0.3292
# Epoch 200, Loss: 0.3199
# Epoch 250, Loss: 0.1303
# Epoch 300, Loss: 0.1439
# LSTM model for Student 109 saved to model/lstm\lstm_student_109.pth
#
# Training LSTM for Student 110
# Epoch 50, Loss: 0.8848
# Epoch 100, Loss: 0.5059
# Epoch 150, Loss: 0.4871
# Epoch 200, Loss: 0.3482
# Epoch 250, Loss: 0.2557
# Epoch 300, Loss: 0.2659
# LSTM model for Student 110 saved to model/lstm\lstm_student_110.pth
#
# Training LSTM for Student 111
# Epoch 50, Loss: 1.0442
# Epoch 100, Loss: 0.7251
# Epoch 150, Loss: 0.5454
# Epoch 200, Loss: 0.2948
# Epoch 250, Loss: 0.3388
# Epoch 300, Loss: 0.2573
# LSTM model for Student 111 saved to model/lstm\lstm_student_111.pth
#
# Training LSTM for Student 112
# Epoch 50, Loss: 0.8297
# Epoch 100, Loss: 0.6003
# Epoch 150, Loss: 0.3822
# Epoch 200, Loss: 0.2811
# Epoch 250, Loss: 0.3998
# Epoch 300, Loss: 0.3721
# LSTM model for Student 112 saved to model/lstm\lstm_student_112.pth
#
# Training LSTM for Student 113
# Epoch 50, Loss: 0.8117
# Epoch 100, Loss: 0.6146
# Epoch 150, Loss: 0.5280
# Epoch 200, Loss: 0.5301
# Epoch 250, Loss: 0.5902
# Epoch 300, Loss: 0.3751
# LSTM model for Student 113 saved to model/lstm\lstm_student_113.pth
#
# Training LSTM for Student 114
# Epoch 50, Loss: 0.5752
# Epoch 100, Loss: 0.4354
# Epoch 150, Loss: 0.3243
# Epoch 200, Loss: 0.3261
# Epoch 250, Loss: 0.2336
# Epoch 300, Loss: 0.2347
# LSTM model for Student 114 saved to model/lstm\lstm_student_114.pth
#
# Training LSTM for Student 115
# Epoch 50, Loss: 1.0829
# Epoch 100, Loss: 0.7913
# Epoch 150, Loss: 0.5077
# Epoch 200, Loss: 0.7531
# Epoch 250, Loss: 0.3297
# Epoch 300, Loss: 0.3336
# LSTM model for Student 115 saved to model/lstm\lstm_student_115.pth
#
# Training LSTM for Student 116
# Epoch 50, Loss: 0.8117
# Epoch 100, Loss: 0.4327
# Epoch 150, Loss: 0.3813
# Epoch 200, Loss: 0.2243
# Epoch 250, Loss: 0.2250
# Epoch 300, Loss: 0.1275
# LSTM model for Student 116 saved to model/lstm\lstm_student_116.pth
#
# Training LSTM for Student 117
# Epoch 50, Loss: 0.6827
# Epoch 100, Loss: 0.5142
# Epoch 150, Loss: 0.3562
# Epoch 200, Loss: 0.2920
# Epoch 250, Loss: 0.2491
# Epoch 300, Loss: 0.3048
# LSTM model for Student 117 saved to model/lstm\lstm_student_117.pth
#
# Training LSTM for Student 118
# Epoch 50, Loss: 0.9148
# Epoch 100, Loss: 0.8585
# Epoch 150, Loss: 0.6185
# Epoch 200, Loss: 0.4894
# Epoch 250, Loss: 0.4785
# Epoch 300, Loss: 0.3684
# LSTM model for Student 118 saved to model/lstm\lstm_student_118.pth
#
# Training LSTM for Student 119
# Epoch 50, Loss: 0.7235
# Epoch 100, Loss: 0.5210
# Epoch 150, Loss: 0.2399
# Epoch 200, Loss: 0.1969
# Epoch 250, Loss: 0.2126
# Epoch 300, Loss: 0.2006
# LSTM model for Student 119 saved to model/lstm\lstm_student_119.pth
#
# Training LSTM for Student 120
# Epoch 50, Loss: 0.6338
# Epoch 100, Loss: 0.4533
# Epoch 150, Loss: 0.3433
# Epoch 200, Loss: 0.1684
# Epoch 250, Loss: 0.1844
# Epoch 300, Loss: 0.1607
# LSTM model for Student 120 saved to model/lstm\lstm_student_120.pth
#
# Training LSTM for Student 121
# Epoch 50, Loss: 0.7879
# Epoch 100, Loss: 0.3786
# Epoch 150, Loss: 0.3095
# Epoch 200, Loss: 0.2521
# Epoch 250, Loss: 0.1601
# Epoch 300, Loss: 0.2137
# LSTM model for Student 121 saved to model/lstm\lstm_student_121.pth
#
# Training LSTM for Student 122
# Epoch 50, Loss: 0.9835
# Epoch 100, Loss: 0.6981
# Epoch 150, Loss: 0.4127
# Epoch 200, Loss: 0.4653
# Epoch 250, Loss: 0.3988
# Epoch 300, Loss: 0.2846
# LSTM model for Student 122 saved to model/lstm\lstm_student_122.pth
#
# Training LSTM for Student 123
# Epoch 50, Loss: 0.8780
# Epoch 100, Loss: 0.8827
# Epoch 150, Loss: 0.5434
# Epoch 200, Loss: 0.4843
# Epoch 250, Loss: 0.5730
# Epoch 300, Loss: 0.4173
# LSTM model for Student 123 saved to model/lstm\lstm_student_123.pth
#
# Training LSTM for Student 124
# Epoch 50, Loss: 0.5709
# Epoch 100, Loss: 0.3776
# Epoch 150, Loss: 0.2256
# Epoch 200, Loss: 0.2004
# Epoch 250, Loss: 0.0572
# Epoch 300, Loss: 0.0769
# LSTM model for Student 124 saved to model/lstm\lstm_student_124.pth
#
# Training LSTM for Student 125
# Epoch 50, Loss: 0.8188
# Epoch 100, Loss: 0.3986
# Epoch 150, Loss: 0.2779
# Epoch 200, Loss: 0.2215
# Epoch 250, Loss: 0.1710
# Epoch 300, Loss: 0.1863
# LSTM model for Student 125 saved to model/lstm\lstm_student_125.pth
#
# Training LSTM for Student 126
# Epoch 50, Loss: 0.7816
# Epoch 100, Loss: 0.5075
# Epoch 150, Loss: 0.5438
# Epoch 200, Loss: 0.3990
# Epoch 250, Loss: 0.4245
# Epoch 300, Loss: 0.2871
# LSTM model for Student 126 saved to model/lstm\lstm_student_126.pth
#
# Training LSTM for Student 127
# Epoch 50, Loss: 0.7749
# Epoch 100, Loss: 0.6766
# Epoch 150, Loss: 0.5366
# Epoch 200, Loss: 0.4994
# Epoch 250, Loss: 0.3835
# Epoch 300, Loss: 0.2324
# LSTM model for Student 127 saved to model/lstm\lstm_student_127.pth
#
# Training LSTM for Student 128
# Epoch 50, Loss: 0.8853
# Epoch 100, Loss: 0.4556
# Epoch 150, Loss: 0.3380
# Epoch 200, Loss: 0.2939
# Epoch 250, Loss: 0.2589
# Epoch 300, Loss: 0.4046
# LSTM model for Student 128 saved to model/lstm\lstm_student_128.pth
#
# Training LSTM for Student 129
# Epoch 50, Loss: 0.9428
# Epoch 100, Loss: 0.7373
# Epoch 150, Loss: 0.5188
# Epoch 200, Loss: 0.4962
# Epoch 250, Loss: 0.3900
# Epoch 300, Loss: 0.4393
# LSTM model for Student 129 saved to model/lstm\lstm_student_129.pth
#
# Training LSTM for Student 130
# Epoch 50, Loss: 1.0393
# Epoch 100, Loss: 0.9470
# Epoch 150, Loss: 0.7875
# Epoch 200, Loss: 0.6751
# Epoch 250, Loss: 0.5401
# Epoch 300, Loss: 0.6196
# LSTM model for Student 130 saved to model/lstm\lstm_student_130.pth
#
# Training LSTM for Student 131
# Epoch 50, Loss: 0.9806
# Epoch 100, Loss: 0.6524
# Epoch 150, Loss: 0.6105
# Epoch 200, Loss: 0.5114
# Epoch 250, Loss: 0.3163
# Epoch 300, Loss: 0.4859
# LSTM model for Student 131 saved to model/lstm\lstm_student_131.pth
#
# Training LSTM for Student 132
# Epoch 50, Loss: 0.9232
# Epoch 100, Loss: 0.5312
# Epoch 150, Loss: 0.4637
# Epoch 200, Loss: 0.3681
# Epoch 250, Loss: 0.3732
# Epoch 300, Loss: 0.2450
# LSTM model for Student 132 saved to model/lstm\lstm_student_132.pth
#
# Training LSTM for Student 133
# Epoch 50, Loss: 1.1833
# Epoch 100, Loss: 0.8143
# Epoch 150, Loss: 0.7311
# Epoch 200, Loss: 0.4902
# Epoch 250, Loss: 0.4238
# Epoch 300, Loss: 0.4559
# LSTM model for Student 133 saved to model/lstm\lstm_student_133.pth
#
# Training LSTM for Student 134
# Epoch 50, Loss: 0.7923
# Epoch 100, Loss: 0.5892
# Epoch 150, Loss: 0.4292
# Epoch 200, Loss: 0.4631
# Epoch 250, Loss: 0.3938
# Epoch 300, Loss: 0.2594
# LSTM model for Student 134 saved to model/lstm\lstm_student_134.pth
#
# Training LSTM for Student 135
# Epoch 50, Loss: 0.8240
# Epoch 100, Loss: 0.6214
# Epoch 150, Loss: 0.3901
# Epoch 200, Loss: 0.3426
# Epoch 250, Loss: 0.2977
# Epoch 300, Loss: 0.3177
# LSTM model for Student 135 saved to model/lstm\lstm_student_135.pth
#
# Training LSTM for Student 136
# Epoch 50, Loss: 0.6742
# Epoch 100, Loss: 0.5496
# Epoch 150, Loss: 0.3816
# Epoch 200, Loss: 0.2909
# Epoch 250, Loss: 0.3633
# Epoch 300, Loss: 0.2078
# LSTM model for Student 136 saved to model/lstm\lstm_student_136.pth
#
# Training LSTM for Student 137
# Epoch 50, Loss: 0.8548
# Epoch 100, Loss: 0.6794
# Epoch 150, Loss: 0.5190
# Epoch 200, Loss: 0.3469
# Epoch 250, Loss: 0.3454
# Epoch 300, Loss: 0.2481
# LSTM model for Student 137 saved to model/lstm\lstm_student_137.pth
#
# Training LSTM for Student 138
# Epoch 50, Loss: 0.8193
# Epoch 100, Loss: 0.8168
# Epoch 150, Loss: 0.6568
# Epoch 200, Loss: 0.4684
# Epoch 250, Loss: 0.4665
# Epoch 300, Loss: 0.3429
# LSTM model for Student 138 saved to model/lstm\lstm_student_138.pth
#
# Training LSTM for Student 139
# Epoch 50, Loss: 0.9220
# Epoch 100, Loss: 0.7377
# Epoch 150, Loss: 0.6595
# Epoch 200, Loss: 0.4990
# Epoch 250, Loss: 0.3051
# Epoch 300, Loss: 0.3234
# LSTM model for Student 139 saved to model/lstm\lstm_student_139.pth
#
# Training LSTM for Student 140
# Epoch 50, Loss: 0.9737
# Epoch 100, Loss: 0.5150
# Epoch 150, Loss: 0.3263
# Epoch 200, Loss: 0.2445
# Epoch 250, Loss: 0.1359
# Epoch 300, Loss: 0.0798
# LSTM model for Student 140 saved to model/lstm\lstm_student_140.pth
#
# Training LSTM for Student 141
# Epoch 50, Loss: 0.7420
# Epoch 100, Loss: 0.4565
# Epoch 150, Loss: 0.3374
# Epoch 200, Loss: 0.2152
# Epoch 250, Loss: 0.1504
# Epoch 300, Loss: 0.1082
# LSTM model for Student 141 saved to model/lstm\lstm_student_141.pth
#
# Training LSTM for Student 142
# Epoch 50, Loss: 1.3081
# Epoch 100, Loss: 0.8886
# Epoch 150, Loss: 0.5776
# Epoch 200, Loss: 0.5049
# Epoch 250, Loss: 0.3673
# Epoch 300, Loss: 0.2616
# LSTM model for Student 142 saved to model/lstm\lstm_student_142.pth
#
# Training LSTM for Student 143
# Epoch 50, Loss: 0.8801
# Epoch 100, Loss: 0.5708
# Epoch 150, Loss: 0.3388
# Epoch 200, Loss: 0.4318
# Epoch 250, Loss: 0.4050
# Epoch 300, Loss: 0.1744
# LSTM model for Student 143 saved to model/lstm\lstm_student_143.pth
#
# Training LSTM for Student 144
# Epoch 50, Loss: 0.7719
# Epoch 100, Loss: 0.4380
# Epoch 150, Loss: 0.5010
# Epoch 200, Loss: 0.3258
# Epoch 250, Loss: 0.3517
# Epoch 300, Loss: 0.1785
# LSTM model for Student 144 saved to model/lstm\lstm_student_144.pth
#
# Training LSTM for Student 145
# Epoch 50, Loss: 0.7787
# Epoch 100, Loss: 0.4963
# Epoch 150, Loss: 0.4155
# Epoch 200, Loss: 0.2777
# Epoch 250, Loss: 0.2541
# Epoch 300, Loss: 0.3008
# LSTM model for Student 145 saved to model/lstm\lstm_student_145.pth
#
# Training LSTM for Student 146
# Epoch 50, Loss: 0.9069
# Epoch 100, Loss: 0.5896
# Epoch 150, Loss: 0.3871
# Epoch 200, Loss: 0.3351
# Epoch 250, Loss: 0.2568
# Epoch 300, Loss: 0.1680
# LSTM model for Student 146 saved to model/lstm\lstm_student_146.pth
#
# Training LSTM for Student 147
# Epoch 50, Loss: 0.6048
# Epoch 100, Loss: 0.3793
# Epoch 150, Loss: 0.1797
# Epoch 200, Loss: 0.1784
# Epoch 250, Loss: 0.1508
# Epoch 300, Loss: 0.1628
# LSTM model for Student 147 saved to model/lstm\lstm_student_147.pth
#
# Training LSTM for Student 148
# Epoch 50, Loss: 0.8432
# Epoch 100, Loss: 0.7039
# Epoch 150, Loss: 0.6476
# Epoch 200, Loss: 0.6559
# Epoch 250, Loss: 0.2929
# Epoch 300, Loss: 0.4191
# LSTM model for Student 148 saved to model/lstm\lstm_student_148.pth
#
# Training LSTM for Student 149
# Epoch 50, Loss: 0.9064
# Epoch 100, Loss: 0.5788
# Epoch 150, Loss: 0.4859
# Epoch 200, Loss: 0.3344
# Epoch 250, Loss: 0.2331
# Epoch 300, Loss: 0.1516
# LSTM model for Student 149 saved to model/lstm\lstm_student_149.pth
#
# Training LSTM for Student 150
# Epoch 50, Loss: 1.1040
# Epoch 100, Loss: 0.7652
# Epoch 150, Loss: 0.6939
# Epoch 200, Loss: 0.6347
# Epoch 250, Loss: 0.7738
# Epoch 300, Loss: 0.5610
# LSTM model for Student 150 saved to model/lstm\lstm_student_150.pth
#
# Training LSTM for Student 151
# Epoch 50, Loss: 1.2415
# Epoch 100, Loss: 1.0234
# Epoch 150, Loss: 0.9552
# Epoch 200, Loss: 0.8814
# Epoch 250, Loss: 0.7371
# Epoch 300, Loss: 0.7272
# LSTM model for Student 151 saved to model/lstm\lstm_student_151.pth
#
# Training LSTM for Student 152
# Epoch 50, Loss: 0.7501
# Epoch 100, Loss: 0.5328
# Epoch 150, Loss: 0.3689
# Epoch 200, Loss: 0.5480
# Epoch 250, Loss: 0.2885
# Epoch 300, Loss: 0.2424
# LSTM model for Student 152 saved to model/lstm\lstm_student_152.pth
#
# Training LSTM for Student 153
# Epoch 50, Loss: 1.1089
# Epoch 100, Loss: 1.0123
# Epoch 150, Loss: 0.6065
# Epoch 200, Loss: 0.5574
# Epoch 250, Loss: 0.4684
# Epoch 300, Loss: 0.4511
# LSTM model for Student 153 saved to model/lstm\lstm_student_153.pth
#
# Training LSTM for Student 154
# Epoch 50, Loss: 1.0759
# Epoch 100, Loss: 0.9073
# Epoch 150, Loss: 0.8284
# Epoch 200, Loss: 0.6232
# Epoch 250, Loss: 0.6333
# Epoch 300, Loss: 0.5730
# LSTM model for Student 154 saved to model/lstm\lstm_student_154.pth
#
# Training LSTM for Student 155
# Epoch 50, Loss: 0.9179
# Epoch 100, Loss: 0.4164
# Epoch 150, Loss: 0.2765
# Epoch 200, Loss: 0.2714
# Epoch 250, Loss: 0.1753
# Epoch 300, Loss: 0.0974
# LSTM model for Student 155 saved to model/lstm\lstm_student_155.pth
#
# Training LSTM for Student 156
# Epoch 50, Loss: 0.5333
# Epoch 100, Loss: 0.3798
# Epoch 150, Loss: 0.2830
# Epoch 200, Loss: 0.2724
# Epoch 250, Loss: 0.1645
# Epoch 300, Loss: 0.1028
# LSTM model for Student 156 saved to model/lstm\lstm_student_156.pth
#
# Training LSTM for Student 157
# Epoch 50, Loss: 0.9950
# Epoch 100, Loss: 0.7153
# Epoch 150, Loss: 0.5323
# Epoch 200, Loss: 0.4884
# Epoch 250, Loss: 0.4416
# Epoch 300, Loss: 0.3911
# LSTM model for Student 157 saved to model/lstm\lstm_student_157.pth
#
# Training LSTM for Student 158
# Epoch 50, Loss: 0.8508
# Epoch 100, Loss: 0.6878
# Epoch 150, Loss: 0.7360
# Epoch 200, Loss: 0.4218
# Epoch 250, Loss: 0.1861
# Epoch 300, Loss: 0.2007
# LSTM model for Student 158 saved to model/lstm\lstm_student_158.pth
#
# Training LSTM for Student 159
# Epoch 50, Loss: 0.8814
# Epoch 100, Loss: 0.7160
# Epoch 150, Loss: 0.5858
# Epoch 200, Loss: 0.6456
# Epoch 250, Loss: 0.3749
# Epoch 300, Loss: 0.4360
# LSTM model for Student 159 saved to model/lstm\lstm_student_159.pth
#
# Training LSTM for Student 160
# Epoch 50, Loss: 0.7527
# Epoch 100, Loss: 0.4062
# Epoch 150, Loss: 0.4169
# Epoch 200, Loss: 0.2582
# Epoch 250, Loss: 0.2117
# Epoch 300, Loss: 0.1561
# LSTM model for Student 160 saved to model/lstm\lstm_student_160.pth
#
# Training LSTM for Student 161
# Epoch 50, Loss: 0.9461
# Epoch 100, Loss: 0.7292
# Epoch 150, Loss: 0.4285
# Epoch 200, Loss: 0.4455
# Epoch 250, Loss: 0.3867
# Epoch 300, Loss: 0.3007
# LSTM model for Student 161 saved to model/lstm\lstm_student_161.pth
#
# Training LSTM for Student 162
# Epoch 50, Loss: 0.8090
# Epoch 100, Loss: 0.4891
# Epoch 150, Loss: 0.4712
# Epoch 200, Loss: 0.2985
# Epoch 250, Loss: 0.3371
# Epoch 300, Loss: 0.2417
# LSTM model for Student 162 saved to model/lstm\lstm_student_162.pth
#
# Training LSTM for Student 163
# Epoch 50, Loss: 0.9263
# Epoch 100, Loss: 0.5716
# Epoch 150, Loss: 0.3599
# Epoch 200, Loss: 0.2014
# Epoch 250, Loss: 0.2784
# Epoch 300, Loss: 0.2847
# LSTM model for Student 163 saved to model/lstm\lstm_student_163.pth
#
# Training LSTM for Student 164
# Epoch 50, Loss: 0.9780
# Epoch 100, Loss: 0.7324
# Epoch 150, Loss: 0.5566
# Epoch 200, Loss: 0.5055
# Epoch 250, Loss: 0.6662
# Epoch 300, Loss: 0.3386
# LSTM model for Student 164 saved to model/lstm\lstm_student_164.pth
#
# Training LSTM for Student 165
# Epoch 50, Loss: 0.7780
# Epoch 100, Loss: 0.4502
# Epoch 150, Loss: 0.3750
# Epoch 200, Loss: 0.1956
# Epoch 250, Loss: 0.1452
# Epoch 300, Loss: 0.1821
# LSTM model for Student 165 saved to model/lstm\lstm_student_165.pth
#
# Training LSTM for Student 166
# Epoch 50, Loss: 0.7281
# Epoch 100, Loss: 0.4311
# Epoch 150, Loss: 0.2829
# Epoch 200, Loss: 0.3087
# Epoch 250, Loss: 0.2504
# Epoch 300, Loss: 0.1588
# LSTM model for Student 166 saved to model/lstm\lstm_student_166.pth
#
# Training LSTM for Student 167
# Epoch 50, Loss: 0.9345
# Epoch 100, Loss: 0.7397
# Epoch 150, Loss: 0.5057
# Epoch 200, Loss: 0.3544
# Epoch 250, Loss: 0.3984
# Epoch 300, Loss: 0.3276
# LSTM model for Student 167 saved to model/lstm\lstm_student_167.pth
#
# Training LSTM for Student 168
# Epoch 50, Loss: 0.8111
# Epoch 100, Loss: 0.5814
# Epoch 150, Loss: 0.4042
# Epoch 200, Loss: 0.3438
# Epoch 250, Loss: 0.2397
# Epoch 300, Loss: 0.2769
# LSTM model for Student 168 saved to model/lstm\lstm_student_168.pth
#
# Training LSTM for Student 169
# Epoch 50, Loss: 0.7985
# Epoch 100, Loss: 0.6158
# Epoch 150, Loss: 0.4707
# Epoch 200, Loss: 0.3324
# Epoch 250, Loss: 0.4028
# Epoch 300, Loss: 0.2306
# LSTM model for Student 169 saved to model/lstm\lstm_student_169.pth
#
# Training LSTM for Student 170
# Epoch 50, Loss: 0.9533
# Epoch 100, Loss: 0.8060
# Epoch 150, Loss: 0.6235
# Epoch 200, Loss: 0.7476
# Epoch 250, Loss: 0.5556
# Epoch 300, Loss: 0.5792
# LSTM model for Student 170 saved to model/lstm\lstm_student_170.pth
#
# Training LSTM for Student 171
# Epoch 50, Loss: 0.7700
# Epoch 100, Loss: 0.5595
# Epoch 150, Loss: 0.3768
# Epoch 200, Loss: 0.2903
# Epoch 250, Loss: 0.3079
# Epoch 300, Loss: 0.1884
# LSTM model for Student 171 saved to model/lstm\lstm_student_171.pth
#
# Training LSTM for Student 172
# Epoch 50, Loss: 0.6848
# Epoch 100, Loss: 0.5433
# Epoch 150, Loss: 0.3305
# Epoch 200, Loss: 0.3216
# Epoch 250, Loss: 0.1554
# Epoch 300, Loss: 0.1535
# LSTM model for Student 172 saved to model/lstm\lstm_student_172.pth
#
# Training LSTM for Student 173
# Epoch 50, Loss: 0.8148
# Epoch 100, Loss: 0.6144
# Epoch 150, Loss: 0.6908
# Epoch 200, Loss: 0.5513
# Epoch 250, Loss: 0.5326
# Epoch 300, Loss: 0.4522
# LSTM model for Student 173 saved to model/lstm\lstm_student_173.pth
#
# Training LSTM for Student 174
# Epoch 50, Loss: 0.7359
# Epoch 100, Loss: 0.5498
# Epoch 150, Loss: 0.4164
# Epoch 200, Loss: 0.4517
# Epoch 250, Loss: 0.1697
# Epoch 300, Loss: 0.2168
# LSTM model for Student 174 saved to model/lstm\lstm_student_174.pth
#
# Training LSTM for Student 175
# Epoch 50, Loss: 0.8226
# Epoch 100, Loss: 0.5803
# Epoch 150, Loss: 0.5532
# Epoch 200, Loss: 0.5120
# Epoch 250, Loss: 0.3169
# Epoch 300, Loss: 0.2459
# LSTM model for Student 175 saved to model/lstm\lstm_student_175.pth
#
# Training LSTM for Student 176
# Epoch 50, Loss: 0.8547
# Epoch 100, Loss: 0.7199
# Epoch 150, Loss: 0.6384
# Epoch 200, Loss: 0.5114
# Epoch 250, Loss: 0.5877
# Epoch 300, Loss: 0.6508
# LSTM model for Student 176 saved to model/lstm\lstm_student_176.pth
#
# Training LSTM for Student 177
# Epoch 50, Loss: 0.9704
# Epoch 100, Loss: 0.7254
# Epoch 150, Loss: 0.6444
# Epoch 200, Loss: 0.4115
# Epoch 250, Loss: 0.4274
# Epoch 300, Loss: 0.3630
# LSTM model for Student 177 saved to model/lstm\lstm_student_177.pth
#
# Training LSTM for Student 178
# Epoch 50, Loss: 0.7841
# Epoch 100, Loss: 0.6784
# Epoch 150, Loss: 0.4290
# Epoch 200, Loss: 0.3175
# Epoch 250, Loss: 0.2325
# Epoch 300, Loss: 0.1350
# LSTM model for Student 178 saved to model/lstm\lstm_student_178.pth
#
# Training LSTM for Student 179
# Epoch 50, Loss: 0.6078
# Epoch 100, Loss: 0.3995
# Epoch 150, Loss: 0.2856
# Epoch 200, Loss: 0.2119
# Epoch 250, Loss: 0.1724
# Epoch 300, Loss: 0.2317
# LSTM model for Student 179 saved to model/lstm\lstm_student_179.pth
#
# Training LSTM for Student 180
# Epoch 50, Loss: 0.8390
# Epoch 100, Loss: 0.4694
# Epoch 150, Loss: 0.2689
# Epoch 200, Loss: 0.4981
# Epoch 250, Loss: 0.3530
# Epoch 300, Loss: 0.2473
# LSTM model for Student 180 saved to model/lstm\lstm_student_180.pth
#
# Training LSTM for Student 181
# Epoch 50, Loss: 0.8374
# Epoch 100, Loss: 0.5384
# Epoch 150, Loss: 0.4296
# Epoch 200, Loss: 0.2532
# Epoch 250, Loss: 0.2514
# Epoch 300, Loss: 0.3142
# LSTM model for Student 181 saved to model/lstm\lstm_student_181.pth
#
# Training LSTM for Student 182
# Epoch 50, Loss: 0.8384
# Epoch 100, Loss: 0.5108
# Epoch 150, Loss: 0.4108
# Epoch 200, Loss: 0.3026
# Epoch 250, Loss: 0.2339
# Epoch 300, Loss: 0.3154
# LSTM model for Student 182 saved to model/lstm\lstm_student_182.pth
#
# Training LSTM for Student 183
# Epoch 50, Loss: 0.6907
# Epoch 100, Loss: 0.2611
# Epoch 150, Loss: 0.3847
# Epoch 200, Loss: 0.1348
# Epoch 250, Loss: 0.1671
# Epoch 300, Loss: 0.2090
# LSTM model for Student 183 saved to model/lstm\lstm_student_183.pth
#
# Training LSTM for Student 184
# Epoch 50, Loss: 0.7821
# Epoch 100, Loss: 0.4090
# Epoch 150, Loss: 0.3841
# Epoch 200, Loss: 0.2365
# Epoch 250, Loss: 0.1891
# Epoch 300, Loss: 0.1979
# LSTM model for Student 184 saved to model/lstm\lstm_student_184.pth
#
# Training LSTM for Student 185
# Epoch 50, Loss: 0.8924
# Epoch 100, Loss: 0.6812
# Epoch 150, Loss: 0.5489
# Epoch 200, Loss: 0.6105
# Epoch 250, Loss: 0.5387
# Epoch 300, Loss: 0.4842
# LSTM model for Student 185 saved to model/lstm\lstm_student_185.pth
#
# Training LSTM for Student 186
# Epoch 50, Loss: 0.9124
# Epoch 100, Loss: 0.5460
# Epoch 150, Loss: 0.4557
# Epoch 200, Loss: 0.3642
# Epoch 250, Loss: 0.4059
# Epoch 300, Loss: 0.2254
# LSTM model for Student 186 saved to model/lstm\lstm_student_186.pth
#
# Training LSTM for Student 187
# Epoch 50, Loss: 0.7273
# Epoch 100, Loss: 0.5083
# Epoch 150, Loss: 0.4321
# Epoch 200, Loss: 0.3917
# Epoch 250, Loss: 0.1922
# Epoch 300, Loss: 0.1475
# LSTM model for Student 187 saved to model/lstm\lstm_student_187.pth
#
# Training LSTM for Student 188
# Epoch 50, Loss: 1.0058
# Epoch 100, Loss: 0.7252
# Epoch 150, Loss: 0.5650
# Epoch 200, Loss: 0.4066
# Epoch 250, Loss: 0.3568
# Epoch 300, Loss: 0.4407
# LSTM model for Student 188 saved to model/lstm\lstm_student_188.pth
#
# Training LSTM for Student 189
# Epoch 50, Loss: 1.0594
# Epoch 100, Loss: 0.7749
# Epoch 150, Loss: 0.4289
# Epoch 200, Loss: 0.5810
# Epoch 250, Loss: 0.3733
# Epoch 300, Loss: 0.3120
# LSTM model for Student 189 saved to model/lstm\lstm_student_189.pth
#
# Training LSTM for Student 190
# Epoch 50, Loss: 0.9302
# Epoch 100, Loss: 0.6364
# Epoch 150, Loss: 0.5845
# Epoch 200, Loss: 0.3228
# Epoch 250, Loss: 0.3936
# Epoch 300, Loss: 0.2287
# LSTM model for Student 190 saved to model/lstm\lstm_student_190.pth
#
# Training LSTM for Student 191
# Epoch 50, Loss: 0.9060
# Epoch 100, Loss: 0.5982
# Epoch 150, Loss: 0.5574
# Epoch 200, Loss: 0.2412
# Epoch 250, Loss: 0.5581
# Epoch 300, Loss: 0.2712
# LSTM model for Student 191 saved to model/lstm\lstm_student_191.pth
#
# Training LSTM for Student 192
# Epoch 50, Loss: 0.8550
# Epoch 100, Loss: 0.6328
# Epoch 150, Loss: 0.4548
# Epoch 200, Loss: 0.5377
# Epoch 250, Loss: 0.3389
# Epoch 300, Loss: 0.2715
# LSTM model for Student 192 saved to model/lstm\lstm_student_192.pth
#
# Training LSTM for Student 193
# Epoch 50, Loss: 0.8292
# Epoch 100, Loss: 0.4596
# Epoch 150, Loss: 0.2451
# Epoch 200, Loss: 0.1994
# Epoch 250, Loss: 0.1256
# Epoch 300, Loss: 0.1358
# LSTM model for Student 193 saved to model/lstm\lstm_student_193.pth
#
# Training LSTM for Student 194
# Epoch 50, Loss: 0.9716
# Epoch 100, Loss: 0.7242
# Epoch 150, Loss: 0.7256
# Epoch 200, Loss: 0.5647
# Epoch 250, Loss: 0.5069
# Epoch 300, Loss: 0.3922
# LSTM model for Student 194 saved to model/lstm\lstm_student_194.pth
#
# Training LSTM for Student 195
# Epoch 50, Loss: 0.7144
# Epoch 100, Loss: 0.6110
# Epoch 150, Loss: 0.4498
# Epoch 200, Loss: 0.3767
# Epoch 250, Loss: 0.3238
# Epoch 300, Loss: 0.3907
# LSTM model for Student 195 saved to model/lstm\lstm_student_195.pth
#
# Training LSTM for Student 196
# Epoch 50, Loss: 0.8003
# Epoch 100, Loss: 0.3435
# Epoch 150, Loss: 0.2816
# Epoch 200, Loss: 0.2744
# Epoch 250, Loss: 0.1652
# Epoch 300, Loss: 0.1185
# LSTM model for Student 196 saved to model/lstm\lstm_student_196.pth
#
# Training LSTM for Student 197
# Epoch 50, Loss: 0.4372
# Epoch 100, Loss: 0.2062
# Epoch 150, Loss: 0.1311
# Epoch 200, Loss: 0.2531
# Epoch 250, Loss: 0.1084
# Epoch 300, Loss: 0.0573
# LSTM model for Student 197 saved to model/lstm\lstm_student_197.pth
#
# Training LSTM for Student 198
# Epoch 50, Loss: 0.9552
# Epoch 100, Loss: 0.5610
# Epoch 150, Loss: 0.6801
# Epoch 200, Loss: 0.5211
# Epoch 250, Loss: 0.3115
# Epoch 300, Loss: 0.4225
# LSTM model for Student 198 saved to model/lstm\lstm_student_198.pth
#
# Training LSTM for Student 199
# Epoch 50, Loss: 0.7395
# Epoch 100, Loss: 0.3776
# Epoch 150, Loss: 0.3290
# Epoch 200, Loss: 0.3141
# Epoch 250, Loss: 0.2283
# Epoch 300, Loss: 0.2261
# LSTM model for Student 199 saved to model/lstm\lstm_student_199.pth
#
# Training LSTM for Student 200
# Epoch 50, Loss: 0.7269
# Epoch 100, Loss: 0.5651
# Epoch 150, Loss: 0.6353
# Epoch 200, Loss: 0.3238
# Epoch 250, Loss: 0.3029
# ...
#
# Training LSTM for Student 435
# Epoch 50, Loss: 0.7134
# Epoch 100, Loss: 0.4297
# Epoch 150, Loss: 0.3158
# Epoch 200, Loss: 0.2091
# Epoch 250, Loss: 0.1575
# Epoch 300, Loss: 0.0882
# LSTM model for Student 435 saved to model/lstm\lstm_student_435.pth
#
# Training LSTM for Student 436
# Epoch 50, Loss: 0.6317
# Epoch 100, Loss: 0.2820
# Epoch 150, Loss: 0.1795
# Epoch 200, Loss: 0.1025
# Epoch 250, Loss: 0.1026
# Epoch 300, Loss: 0.0599
# LSTM model for Student 436 saved to model/lstm\lstm_student_436.pth
#
# Training LSTM for Student 437
# Epoch 50, Loss: 0.6207
# Epoch 100, Loss: 0.2946
# Epoch 150, Loss: 0.1795
# Epoch 200, Loss: 0.1403
# Epoch 250, Loss: 0.0508
# Epoch 300, Loss: 0.0836
# LSTM model for Student 437 saved to model/lstm\lstm_student_437.pth
#
# Training LSTM for Student 438
# Epoch 50, Loss: 0.9803
# Epoch 100, Loss: 0.6959
# Epoch 150, Loss: 0.5746
# Epoch 200, Loss: 0.6407
# Epoch 250, Loss: 0.2947
# Epoch 300, Loss: 0.4913
# LSTM model for Student 438 saved to model/lstm\lstm_student_438.pth
#
# Training LSTM for Student 439
# Epoch 50, Loss: 0.7820
# Epoch 100, Loss: 0.8084
# Epoch 150, Loss: 0.5784
# Epoch 200, Loss: 0.4237
# Epoch 250, Loss: 0.4262
# Epoch 300, Loss: 0.3432
# LSTM model for Student 439 saved to model/lstm\lstm_student_439.pth
#
# Training LSTM for Student 440
# Epoch 50, Loss: 0.9042
# Epoch 100, Loss: 0.5985
# Epoch 150, Loss: 0.3332
# Epoch 200, Loss: 0.4559
# Epoch 250, Loss: 0.3164
# Epoch 300, Loss: 0.2962
# LSTM model for Student 440 saved to model/lstm\lstm_student_440.pth
#
# Training LSTM for Student 441
# Epoch 50, Loss: 0.7174
# Epoch 100, Loss: 0.5044
# Epoch 150, Loss: 0.2659
# Epoch 200, Loss: 0.2947
# Epoch 250, Loss: 0.3151
# Epoch 300, Loss: 0.1590
# LSTM model for Student 441 saved to model/lstm\lstm_student_441.pth
#
# Training LSTM for Student 442
# Epoch 50, Loss: 0.6831
# Epoch 100, Loss: 0.3539
# Epoch 150, Loss: 0.3075
# Epoch 200, Loss: 0.2741
# Epoch 250, Loss: 0.1580
# Epoch 300, Loss: 0.1663
# LSTM model for Student 442 saved to model/lstm\lstm_student_442.pth
#
# Training LSTM for Student 443
# Epoch 50, Loss: 1.0089
# Epoch 100, Loss: 0.7039
# Epoch 150, Loss: 0.4885
# Epoch 200, Loss: 0.4189
# Epoch 250, Loss: 0.2300
# Epoch 300, Loss: 0.3482
# LSTM model for Student 443 saved to model/lstm\lstm_student_443.pth
#
# Training LSTM for Student 444
# Epoch 50, Loss: 0.8929
# Epoch 100, Loss: 0.5792
# Epoch 150, Loss: 0.4728
# Epoch 200, Loss: 0.3857
# Epoch 250, Loss: 0.3708
# Epoch 300, Loss: 0.2022
# LSTM model for Student 444 saved to model/lstm\lstm_student_444.pth
#
# Training LSTM for Student 445
# Epoch 50, Loss: 1.0927
# Epoch 100, Loss: 0.8584
# Epoch 150, Loss: 0.7362
# Epoch 200, Loss: 0.6447
# Epoch 250, Loss: 0.4997
# Epoch 300, Loss: 0.4920
# LSTM model for Student 445 saved to model/lstm\lstm_student_445.pth
#
# Training LSTM for Student 446
# Epoch 50, Loss: 0.9512
# Epoch 100, Loss: 0.6658
# Epoch 150, Loss: 0.6270
# Epoch 200, Loss: 0.4227
# Epoch 250, Loss: 0.3570
# Epoch 300, Loss: 0.2232
# LSTM model for Student 446 saved to model/lstm\lstm_student_446.pth
#
# Training LSTM for Student 447
# Epoch 50, Loss: 0.6876
# Epoch 100, Loss: 0.5640
# Epoch 150, Loss: 0.4475
# Epoch 200, Loss: 0.3874
# Epoch 250, Loss: 0.3417
# Epoch 300, Loss: 0.2450
# LSTM model for Student 447 saved to model/lstm\lstm_student_447.pth
#
# Training LSTM for Student 448
# Epoch 50, Loss: 0.9548
# Epoch 100, Loss: 0.8007
# Epoch 150, Loss: 0.4964
# Epoch 200, Loss: 0.6314
# Epoch 250, Loss: 0.4588
# Epoch 300, Loss: 0.3565
# LSTM model for Student 448 saved to model/lstm\lstm_student_448.pth
#
# Training LSTM for Student 449
# Epoch 50, Loss: 0.9960
# Epoch 100, Loss: 0.7636
# Epoch 150, Loss: 0.7496
# Epoch 200, Loss: 0.6759
# Epoch 250, Loss: 0.6477
# Epoch 300, Loss: 0.3987
# LSTM model for Student 449 saved to model/lstm\lstm_student_449.pth
#
# Training LSTM for Student 450
# Epoch 50, Loss: 0.5736
# Epoch 100, Loss: 0.3106
# Epoch 150, Loss: 0.3083
# Epoch 200, Loss: 0.1108
# Epoch 250, Loss: 0.0959
# Epoch 300, Loss: 0.0614
# LSTM model for Student 450 saved to model/lstm\lstm_student_450.pth
#
# Training LSTM for Student 451
# Epoch 50, Loss: 0.8015
# Epoch 100, Loss: 0.5379
# Epoch 150, Loss: 0.5146
# Epoch 200, Loss: 0.3428
# Epoch 250, Loss: 0.3420
# Epoch 300, Loss: 0.3086
# LSTM model for Student 451 saved to model/lstm\lstm_student_451.pth
#
# Training LSTM for Student 452
# Epoch 50, Loss: 0.8243
# Epoch 100, Loss: 0.5382
# Epoch 150, Loss: 0.4291
# Epoch 200, Loss: 0.3732
# Epoch 250, Loss: 0.3069
# Epoch 300, Loss: 0.2265
# LSTM model for Student 452 saved to model/lstm\lstm_student_452.pth
#
# Training LSTM for Student 453
# Epoch 50, Loss: 0.7060
# Epoch 100, Loss: 0.5248
# Epoch 150, Loss: 0.4247
# Epoch 200, Loss: 0.2951
# Epoch 250, Loss: 0.2569
# Epoch 300, Loss: 0.2068
# LSTM model for Student 453 saved to model/lstm\lstm_student_453.pth
#
# Training LSTM for Student 454
# Epoch 50, Loss: 0.6616
# Epoch 100, Loss: 0.3109
# Epoch 150, Loss: 0.2844
# Epoch 200, Loss: 0.2575
# Epoch 250, Loss: 0.2473
# Epoch 300, Loss: 0.1774
# LSTM model for Student 454 saved to model/lstm\lstm_student_454.pth
#
# Training LSTM for Student 455
# Epoch 50, Loss: 0.5009
# Epoch 100, Loss: 0.2669
# Epoch 150, Loss: 0.3204
# Epoch 200, Loss: 0.1215
# Epoch 250, Loss: 0.1056
# Epoch 300, Loss: 0.2017
# LSTM model for Student 455 saved to model/lstm\lstm_student_455.pth
#
# Training LSTM for Student 456
# Epoch 50, Loss: 0.7390
# Epoch 100, Loss: 0.5872
# Epoch 150, Loss: 0.4109
# Epoch 200, Loss: 0.2706
# Epoch 250, Loss: 0.2444
# Epoch 300, Loss: 0.4041
# LSTM model for Student 456 saved to model/lstm\lstm_student_456.pth
#
# Training LSTM for Student 457
# Epoch 50, Loss: 0.8244
# Epoch 100, Loss: 0.5892
# Epoch 150, Loss: 0.3542
# Epoch 200, Loss: 0.2135
# Epoch 250, Loss: 0.2953
# Epoch 300, Loss: 0.1202
# LSTM model for Student 457 saved to model/lstm\lstm_student_457.pth
#
# Training LSTM for Student 458
# Epoch 50, Loss: 0.5557
# Epoch 100, Loss: 0.3198
# Epoch 150, Loss: 0.1565
# Epoch 200, Loss: 0.2232
# Epoch 250, Loss: 0.2070
# Epoch 300, Loss: 0.1223
# LSTM model for Student 458 saved to model/lstm\lstm_student_458.pth
#
# Training LSTM for Student 459
# Epoch 50, Loss: 0.8100
# Epoch 100, Loss: 0.5255
# Epoch 150, Loss: 0.5146
# Epoch 200, Loss: 0.2449
# Epoch 250, Loss: 0.4099
# Epoch 300, Loss: 0.2846
# LSTM model for Student 459 saved to model/lstm\lstm_student_459.pth
#
# Training LSTM for Student 460
# Epoch 50, Loss: 0.9393
# Epoch 100, Loss: 0.7807
# Epoch 150, Loss: 0.5663
# Epoch 200, Loss: 0.4741
# Epoch 250, Loss: 0.4641
# Epoch 300, Loss: 0.4158
# LSTM model for Student 460 saved to model/lstm\lstm_student_460.pth
#
# Training LSTM for Student 461
# Epoch 50, Loss: 0.6347
# Epoch 100, Loss: 0.5387
# Epoch 150, Loss: 0.5005
# Epoch 200, Loss: 0.2356
# Epoch 250, Loss: 0.2090
# Epoch 300, Loss: 0.2007
# LSTM model for Student 461 saved to model/lstm\lstm_student_461.pth
#
# Training LSTM for Student 462
# Epoch 50, Loss: 0.9445
# Epoch 100, Loss: 0.5811
# Epoch 150, Loss: 0.4450
# Epoch 200, Loss: 0.5042
# Epoch 250, Loss: 0.3732
# Epoch 300, Loss: 0.1856
# LSTM model for Student 462 saved to model/lstm\lstm_student_462.pth
#
# Training LSTM for Student 463
# Epoch 50, Loss: 1.1396
# Epoch 100, Loss: 0.8408
# Epoch 150, Loss: 0.6444
# Epoch 200, Loss: 0.3754
# Epoch 250, Loss: 0.3399
# Epoch 300, Loss: 0.3456
# LSTM model for Student 463 saved to model/lstm\lstm_student_463.pth
#
# Training LSTM for Student 464
# Epoch 50, Loss: 1.0290
# Epoch 100, Loss: 0.6910
# Epoch 150, Loss: 0.6279
# Epoch 200, Loss: 0.7255
# Epoch 250, Loss: 0.5557
# Epoch 300, Loss: 0.3652
# LSTM model for Student 464 saved to model/lstm\lstm_student_464.pth
#
# Training LSTM for Student 465
# Epoch 50, Loss: 0.7503
# Epoch 100, Loss: 0.5082
# Epoch 150, Loss: 0.4262
# Epoch 200, Loss: 0.2360
# Epoch 250, Loss: 0.3729
# Epoch 300, Loss: 0.2291
# LSTM model for Student 465 saved to model/lstm\lstm_student_465.pth
#
# Training LSTM for Student 466
# Epoch 50, Loss: 0.9668
# Epoch 100, Loss: 0.6352
# Epoch 150, Loss: 0.6004
# Epoch 200, Loss: 0.3277
# Epoch 250, Loss: 0.3078
# Epoch 300, Loss: 0.2507
# LSTM model for Student 466 saved to model/lstm\lstm_student_466.pth
#
# Training LSTM for Student 467
# Epoch 50, Loss: 0.7317
# Epoch 100, Loss: 0.3981
# Epoch 150, Loss: 0.3393
# Epoch 200, Loss: 0.4083
# Epoch 250, Loss: 0.2215
# Epoch 300, Loss: 0.2590
# LSTM model for Student 467 saved to model/lstm\lstm_student_467.pth
#
# Training LSTM for Student 468
# Epoch 50, Loss: 0.5456
# Epoch 100, Loss: 0.3296
# Epoch 150, Loss: 0.2494
# Epoch 200, Loss: 0.2188
# Epoch 250, Loss: 0.1423
# Epoch 300, Loss: 0.1453
# LSTM model for Student 468 saved to model/lstm\lstm_student_468.pth
#
# Training LSTM for Student 469
# Epoch 50, Loss: 0.9059
# Epoch 100, Loss: 0.4174
# Epoch 150, Loss: 0.5357
# Epoch 200, Loss: 0.3591
# Epoch 250, Loss: 0.2597
# Epoch 300, Loss: 0.2851
# LSTM model for Student 469 saved to model/lstm\lstm_student_469.pth
#
# Training LSTM for Student 470
# Epoch 50, Loss: 0.7699
# Epoch 100, Loss: 0.6417
# Epoch 150, Loss: 0.6097
# Epoch 200, Loss: 0.4674
# Epoch 250, Loss: 0.3106
# Epoch 300, Loss: 0.4087
# LSTM model for Student 470 saved to model/lstm\lstm_student_470.pth
#
# Training LSTM for Student 471
# Epoch 50, Loss: 0.9593
# Epoch 100, Loss: 0.6401
# Epoch 150, Loss: 0.6029
# Epoch 200, Loss: 0.4288
# Epoch 250, Loss: 0.5760
# Epoch 300, Loss: 0.3291
# LSTM model for Student 471 saved to model/lstm\lstm_student_471.pth
#
# Training LSTM for Student 472
# Epoch 50, Loss: 1.0129
# Epoch 100, Loss: 0.6228
# Epoch 150, Loss: 0.5121
# Epoch 200, Loss: 0.4469
# Epoch 250, Loss: 0.4390
# Epoch 300, Loss: 0.3167
# LSTM model for Student 472 saved to model/lstm\lstm_student_472.pth
#
# Training LSTM for Student 473
# Epoch 50, Loss: 0.5747
# Epoch 100, Loss: 0.4498
# Epoch 150, Loss: 0.3630
# Epoch 200, Loss: 0.2763
# Epoch 250, Loss: 0.2207
# Epoch 300, Loss: 0.1407
# LSTM model for Student 473 saved to model/lstm\lstm_student_473.pth
#
# Training LSTM for Student 474
# Epoch 50, Loss: 0.7001
# Epoch 100, Loss: 0.5419
# Epoch 150, Loss: 0.3416
# Epoch 200, Loss: 0.3555
# Epoch 250, Loss: 0.2149
# Epoch 300, Loss: 0.1567
# LSTM model for Student 474 saved to model/lstm\lstm_student_474.pth
#
# Training LSTM for Student 475
# Epoch 50, Loss: 1.0352
# Epoch 100, Loss: 0.9656
# Epoch 150, Loss: 0.9562
# Epoch 200, Loss: 0.6799
# Epoch 250, Loss: 0.5725
# Epoch 300, Loss: 0.7080
# LSTM model for Student 475 saved to model/lstm\lstm_student_475.pth
#
# Training LSTM for Student 476
# Epoch 50, Loss: 1.0434
# Epoch 100, Loss: 0.8247
# Epoch 150, Loss: 0.7795
# Epoch 200, Loss: 0.6202
# Epoch 250, Loss: 0.5592
# Epoch 300, Loss: 0.4968
# LSTM model for Student 476 saved to model/lstm\lstm_student_476.pth
#
# Training LSTM for Student 477
# Epoch 50, Loss: 0.8795
# Epoch 100, Loss: 0.5738
# Epoch 150, Loss: 0.3572
# Epoch 200, Loss: 0.2695
# Epoch 250, Loss: 0.3572
# Epoch 300, Loss: 0.2069
# LSTM model for Student 477 saved to model/lstm\lstm_student_477.pth
#
# Training LSTM for Student 478
# Epoch 50, Loss: 0.6765
# Epoch 100, Loss: 0.6093
# Epoch 150, Loss: 0.4457
# Epoch 200, Loss: 0.3274
# Epoch 250, Loss: 0.3172
# Epoch 300, Loss: 0.2167
# LSTM model for Student 478 saved to model/lstm\lstm_student_478.pth
#
# Training LSTM for Student 479
# Epoch 50, Loss: 0.5537
# Epoch 100, Loss: 0.2679
# Epoch 150, Loss: 0.2505
# Epoch 200, Loss: 0.1279
# Epoch 250, Loss: 0.1235
# Epoch 300, Loss: 0.1013
# LSTM model for Student 479 saved to model/lstm\lstm_student_479.pth
#
# Training LSTM for Student 480
# Epoch 50, Loss: 1.0617
# Epoch 100, Loss: 0.7899
# Epoch 150, Loss: 0.6578
# Epoch 200, Loss: 0.5078
# Epoch 250, Loss: 0.4452
# Epoch 300, Loss: 0.4405
# LSTM model for Student 480 saved to model/lstm\lstm_student_480.pth
#
# Training LSTM for Student 481
# Epoch 50, Loss: 1.0056
# Epoch 100, Loss: 0.7501
# Epoch 150, Loss: 0.6089
# Epoch 200, Loss: 0.5064
# Epoch 250, Loss: 0.5623
# Epoch 300, Loss: 0.4475
# LSTM model for Student 481 saved to model/lstm\lstm_student_481.pth
#
# Training LSTM for Student 482
# Epoch 50, Loss: 0.7197
# Epoch 100, Loss: 0.5887
# Epoch 150, Loss: 0.3863
# Epoch 200, Loss: 0.4053
# Epoch 250, Loss: 0.3309
# Epoch 300, Loss: 0.2590
# LSTM model for Student 482 saved to model/lstm\lstm_student_482.pth
#
# Training LSTM for Student 483
# Epoch 50, Loss: 0.9831
# Epoch 100, Loss: 0.5855
# Epoch 150, Loss: 0.4066
# Epoch 200, Loss: 0.2756
# Epoch 250, Loss: 0.2588
# Epoch 300, Loss: 0.2371
# LSTM model for Student 483 saved to model/lstm\lstm_student_483.pth
#
# Training LSTM for Student 484
# Epoch 50, Loss: 0.8242
# Epoch 100, Loss: 0.4394
# Epoch 150, Loss: 0.3634
# Epoch 200, Loss: 0.3837
# Epoch 250, Loss: 0.3051
# Epoch 300, Loss: 0.1512
# LSTM model for Student 484 saved to model/lstm\lstm_student_484.pth
#
# Training LSTM for Student 485
# Epoch 50, Loss: 1.0522
# Epoch 100, Loss: 0.7594
# Epoch 150, Loss: 0.6804
# Epoch 200, Loss: 0.5641
# Epoch 250, Loss: 0.4930
# Epoch 300, Loss: 0.3810
# LSTM model for Student 485 saved to model/lstm\lstm_student_485.pth
#
# Training LSTM for Student 486
# Epoch 50, Loss: 0.9311
# Epoch 100, Loss: 0.5136
# Epoch 150, Loss: 0.4851
# Epoch 200, Loss: 0.4015
# Epoch 250, Loss: 0.1908
# Epoch 300, Loss: 0.1362
# LSTM model for Student 486 saved to model/lstm\lstm_student_486.pth
#
# Training LSTM for Student 487
# Epoch 50, Loss: 0.9394
# Epoch 100, Loss: 0.7346
# Epoch 150, Loss: 0.6062
# Epoch 200, Loss: 0.5133
# Epoch 250, Loss: 0.5565
# Epoch 300, Loss: 0.4589
# LSTM model for Student 487 saved to model/lstm\lstm_student_487.pth
#
# Training LSTM for Student 488
# Epoch 50, Loss: 0.6495
# Epoch 100, Loss: 0.4706
# Epoch 150, Loss: 0.3801
# Epoch 200, Loss: 0.1484
# Epoch 250, Loss: 0.1735
# Epoch 300, Loss: 0.1209
# LSTM model for Student 488 saved to model/lstm\lstm_student_488.pth
#
# Training LSTM for Student 489
# Epoch 50, Loss: 0.6840
# Epoch 100, Loss: 0.5146
# Epoch 150, Loss: 0.2398
# Epoch 200, Loss: 0.2421
# Epoch 250, Loss: 0.1802
# Epoch 300, Loss: 0.1058
# LSTM model for Student 489 saved to model/lstm\lstm_student_489.pth
#
# Training LSTM for Student 490
# Epoch 50, Loss: 0.7800
# Epoch 100, Loss: 0.2471
# Epoch 150, Loss: 0.1893
# Epoch 200, Loss: 0.2227
# Epoch 250, Loss: 0.0795
# Epoch 300, Loss: 0.0845
# LSTM model for Student 490 saved to model/lstm\lstm_student_490.pth
#
# Training LSTM for Student 491
# Epoch 50, Loss: 0.9956
# Epoch 100, Loss: 0.6858
# Epoch 150, Loss: 0.4032
# Epoch 200, Loss: 0.5347
# Epoch 250, Loss: 0.3492
# Epoch 300, Loss: 0.3463
# LSTM model for Student 491 saved to model/lstm\lstm_student_491.pth
#
# Training LSTM for Student 492
# Epoch 50, Loss: 0.7343
# Epoch 100, Loss: 0.5156
# Epoch 150, Loss: 0.2935
# Epoch 200, Loss: 0.1675
# Epoch 250, Loss: 0.4104
# Epoch 300, Loss: 0.2975
# LSTM model for Student 492 saved to model/lstm\lstm_student_492.pth
#
# Training LSTM for Student 493
# Epoch 50, Loss: 0.7207
# Epoch 100, Loss: 0.6435
# Epoch 150, Loss: 0.5227
# Epoch 200, Loss: 0.3153
# Epoch 250, Loss: 0.3591
# Epoch 300, Loss: 0.2544
# LSTM model for Student 493 saved to model/lstm\lstm_student_493.pth
#
# Training LSTM for Student 494
# Epoch 50, Loss: 0.9873
# Epoch 100, Loss: 0.5791
# Epoch 150, Loss: 0.3956
# Epoch 200, Loss: 0.3305
# Epoch 250, Loss: 0.3771
# Epoch 300, Loss: 0.4297
# LSTM model for Student 494 saved to model/lstm\lstm_student_494.pth
#
# Training LSTM for Student 495
# Epoch 50, Loss: 1.0104
# Epoch 100, Loss: 0.7869
# Epoch 150, Loss: 0.7025
# Epoch 200, Loss: 0.5839
# Epoch 250, Loss: 0.3974
# Epoch 300, Loss: 0.4939
# LSTM model for Student 495 saved to model/lstm\lstm_student_495.pth
#
# Training LSTM for Student 496
# Epoch 50, Loss: 0.8228
# Epoch 100, Loss: 0.7005
# Epoch 150, Loss: 0.5347
# Epoch 200, Loss: 0.5258
# Epoch 250, Loss: 0.5227
# Epoch 300, Loss: 0.4038
# LSTM model for Student 496 saved to model/lstm\lstm_student_496.pth
#
# Training LSTM for Student 497
# Epoch 50, Loss: 0.7476
# Epoch 100, Loss: 0.3651
# Epoch 150, Loss: 0.2691
# Epoch 200, Loss: 0.2750
# Epoch 250, Loss: 0.2236
# Epoch 300, Loss: 0.1336
# LSTM model for Student 497 saved to model/lstm\lstm_student_497.pth
#
# Training LSTM for Student 498
# Epoch 50, Loss: 0.7633
# Epoch 100, Loss: 0.3213
# Epoch 150, Loss: 0.2624
# Epoch 200, Loss: 0.2149
# Epoch 250, Loss: 0.1508
# Epoch 300, Loss: 0.1027
# LSTM model for Student 498 saved to model/lstm\lstm_student_498.pth
#
# Training LSTM for Student 499
# Epoch 50, Loss: 0.5753
# Epoch 100, Loss: 0.2957
# Epoch 150, Loss: 0.2291
# Epoch 200, Loss: 0.1414
# Epoch 250, Loss: 0.0749
# Epoch 300, Loss: 0.0794
# LSTM model for Student 499 saved to model/lstm\lstm_student_499.pth
#
# Training LSTM for Student 500
# Epoch 50, Loss: 0.7180
# Epoch 100, Loss: 0.2989
# Epoch 150, Loss: 0.2425
# Epoch 200, Loss: 0.1052
# Epoch 250, Loss: 0.0834
# Epoch 300, Loss: 0.1859
# LSTM model for Student 500 saved to model/lstm\lstm_student_500.pth

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# Fungsi untuk menghitung MAPE
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero = y_true != 0
    return np.mean(np.abs((y_true[non_zero] - y_pred[non_zero]) / y_true[non_zero])) * 100

# Fungsi untuk memuat dan memproses data
def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    data['Date'] = pd.to_datetime(data['Date'])
    data['Risk Level'] = data['Risk Level'].map({'Low': 0, 'Medium': 1, 'High': 2})
    data = data.dropna()
    
    numerical_features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    scaler = MinMaxScaler()
    data[numerical_features] = scaler.fit_transform(data[numerical_features])
    
    return data, scaler

# Fungsi untuk membagi data berdasarkan waktu
def split_data_by_time(student_data, train_days=24):
    student_data = student_data.sort_values('Date')
    unique_dates = student_data['Date'].unique()
    train_dates = unique_dates[:train_days]
    test_dates = unique_dates[train_days:]
    train_data = student_data[student_data['Date'].isin(train_dates)]
    test_data = student_data[student_data['Date'].isin(test_dates)]
    return train_data, test_data

# Model LSTM
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.bn = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.4)
        self.risk_head = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim // 2, num_classes)
        )
        self.fc_stress = nn.Linear(hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        out, (h_n, _) = self.lstm(x)
        out = h_n[-1]
        out = self.bn(out)
        out = self.dropout(out)
        risk_logits = self.risk_head(out)
        stress = self.sigmoid(self.fc_stress(out))
        return risk_logits, stress.squeeze(1)

# Fungsi untuk memuat model ARIMA
def load_arima_model(student_id, model_dir="model/arima"):
    model_path = os.path.join(model_dir, f"arima_student_{student_id}.pkl")
    if os.path.exists(model_path):
        with open(model_path, 'rb') as f:
            return pickle.load(f)
    raise FileNotFoundError(f"ARIMA model for Student {student_id} not found at {model_path}")

# Fungsi untuk memuat model LSTM
def load_lstm_model(student_id, input_dim, model_dir="model/lstm"):
    model_path = os.path.join(model_dir, f"lstm_student_{student_id}.pth")
    if os.path.exists(model_path):
        model = LSTMModel(input_dim=input_dim, hidden_dim=64, num_classes=3)
        model.load_state_dict(torch.load(model_path))
        return model
    raise FileNotFoundError(f"LSTM model for Student {student_id} not found at {model_path}")

# Fungsi untuk prediksi hybrid per mahasiswa
def predict_hybrid(student_data, student_id, scaler, device):
    train_data, test_data = split_data_by_time(student_data)
    
    # Fitur dan target
    features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    target_cols = ['Risk Level', 'Stress Level (GSR)']
    
    # Persiapkan data
    X_train = train_data[features].values.reshape(-1, 1, len(features))
    X_test = test_data[features].values.reshape(-1, 1, len(features))
    y_train = train_data[target_cols].values
    y_test = test_data[target_cols].values
    
    # Muat model ARIMA
    arima_model = load_arima_model(student_id)
    arima_forecast = arima_model.forecast(steps=len(test_data))
    
    # Augmentasi data dengan prediksi ARIMA
    X_train_aug = np.concatenate((X_train, np.zeros((len(train_data), 1, 1))), axis=2)
    X_test_aug = np.concatenate((X_test, arima_forecast.values.reshape(-1, 1, 1)), axis=2)
    
    # Konversi ke tensor
    X_train_tensor = torch.tensor(X_train_aug, dtype=torch.float32).to(device)
    X_test_tensor = torch.tensor(X_test_aug, dtype=torch.float32).to(device)
    y_train_risk = torch.tensor(y_train[:, 0], dtype=torch.long).to(device)
    y_train_stress = torch.tensor(y_train[:, 1], dtype=torch.float32).to(device)
    y_test_risk = y_test[:, 0].astype(int)
    y_test_stress = y_test[:, 1]
    
    # Muat model LSTM
    model = load_lstm_model(student_id, input_dim=X_train_aug.shape[2])
    model.to(device)
    model.eval()
    
    # Evaluasi pada test set
    with torch.no_grad():
        test_logits, test_stress = model(X_test_tensor)
        risk_pred_test = torch.argmax(test_logits, dim=1).cpu().numpy()
        stress_pred_test = test_stress.cpu().numpy()
    
    # Metrik evaluasi
    mae_stress = mean_absolute_error(y_test_stress, stress_pred_test)
    rmse_stress = np.sqrt(mean_squared_error(y_test_stress, stress_pred_test))
    mape_stress = mean_absolute_percentage_error(y_test_stress, stress_pred_test)
    mae_risk = mean_absolute_error(y_test_risk, risk_pred_test)
    acc_risk = np.mean(risk_pred_test == y_test_risk)
    
    print(f"\n[Student {student_id}] Evaluation:")
    print(f"MAE Stress: {mae_stress:.4f}, RMSE Stress: {rmse_stress:.4f}, MAPE Stress: {mape_stress:.2f}%")
    print(f"MAE Risk: {mae_risk:.4f}, Accuracy Risk: {acc_risk * 100:.2f}%")
    
    # Prediksi 10 hari ke depan
    n_steps = 5
    window_input = X_test_aug[-n_steps:].copy()
    window_input = torch.tensor(window_input, dtype=torch.float32).to(device)
    future_preds = []
    
    arima_future = arima_model.forecast(steps=10).values
    arima_future = np.clip(arima_future, 0, 1)
    lstm_stress_series = []
    
    with torch.no_grad():
        for day in range(10):
            risk_logits_next, stress_pred_next = model(window_input)
            lstm_stress = stress_pred_next[-1].item()
            lstm_stress_series.append(lstm_stress)
            
            smoothed_stress = np.mean(lstm_stress_series[-3:]) if len(lstm_stress_series) >= 3 else lstm_stress
            alpha = np.clip(0.8 - (day * 0.05), 0.3, 0.8)
            combined_stress = alpha * smoothed_stress + (1 - alpha) * arima_future[day]
            combined_stress = np.clip(combined_stress + np.random.normal(0, 0.02), 0, 1)
            
            risk_level_pred = torch.argmax(risk_logits_next[-1]).item()
            last_input = window_input[-1, 0].cpu().numpy()
            next_features = np.clip(last_input[1:-1] + (np.random.rand(3) - 0.5) * 0.02, 0, 1)
            new_input = np.concatenate([[combined_stress], next_features, [arima_future[day]]])
            new_input_tensor = torch.tensor(new_input, dtype=torch.float32).reshape(1, 1, -1).to(device)
            window_input = torch.cat((window_input[1:], new_input_tensor), dim=0)
            future_preds.append([risk_level_pred, combined_stress])
    
    future_preds = np.array(future_preds)
    
    # Visualisasi
    plt.figure(figsize=(12, 10))
    future_dates = pd.date_range(start=test_data['Date'].iloc[-1] + pd.Timedelta(days=1), periods=10)
    full_data = pd.concat([train_data, test_data])
    
    plt.subplot(2, 1, 1)
    plt.plot(full_data['Date'], full_data['Stress Level (GSR)'], label='Actual Stress', color='blue')
    plt.plot(test_data['Date'], stress_pred_test, label='Predicted Stress (Test)', color='red', linestyle='--')
    plt.plot(future_dates, future_preds[:, 1], label='Forecast Stress', color='purple', linestyle=':')
    plt.title(f"Stress Level - Student {student_id}")
    plt.xlabel('Date')
    plt.ylabel('Stress Level (GSR)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(full_data['Date'], full_data['Risk Level'], label='Actual Risk', color='green')
    plt.plot(test_data['Date'], risk_pred_test, label='Predicted Risk (Test)', color='orange', linestyle='--')
    plt.plot(future_dates, future_preds[:, 0], label='Forecast Risk', color='brown', linestyle=':')
    plt.title(f"Risk Level - Student {student_id}")
    plt.xlabel('Date')
    plt.ylabel('Risk Level')
    plt.yticks([0, 1, 2], ['Low', 'Medium', 'High'])
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(f"student_{student_id}_forecast.png")
    plt.close()

# Fungsi utama
def main():
    data, scaler = load_and_preprocess_data('student_monnitoring_data.csv')
    user_groups = data.groupby('Student ID')
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Proses hanya 5 mahasiswa sebagai contoh
    for i, (student_id, student_data) in enumerate(user_groups):
        # if i >= 5:
        #     break
        print(f"\nProcessing Hybrid for Student {student_id}")
        predict_hybrid(student_data, student_id, scaler, device)

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing Hybrid for Student 1
#
# [Student 1] Evaluation:
# MAE Stress: 0.2471, RMSE Stress: 0.2776, MAPE Stress: 49.03%
# MAE Risk: 0.6667, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 2
#
# [Student 2] Evaluation:
# MAE Stress: 0.0815, RMSE Stress: 0.0849, MAPE Stress: 44.46%
# MAE Risk: 0.8333, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 3
#
# [Student 3] Evaluation:
# MAE Stress: 0.1019, RMSE Stress: 0.1142, MAPE Stress: 41.99%
# MAE Risk: 1.0000, Accuracy Risk: 33.33%
#
# Processing Hybrid for Student 4
#
# [Student 4] Evaluation:
# MAE Stress: 0.1183, RMSE Stress: 0.1446, MAPE Stress: 63.78%
# MAE Risk: 0.1667, Accuracy Risk: 83.33%
#
# Processing Hybrid for Student 5
#
# [Student 5] Evaluation:
# MAE Stress: 0.7113, RMSE Stress: 0.7368, MAPE Stress: 7395.61%
# MAE Risk: 1.0000, Accuracy Risk: 33.33%
#
# Processing Hybrid for Student 6
#
# [Student 6] Evaluation:
# MAE Stress: 0.4496, RMSE Stress: 0.5046, MAPE Stress: 81.49%
# MAE Risk: 0.5000, Accuracy Risk: 66.67%
#
# Processing Hybrid for Student 7
#
# [Student 7] Evaluation:
# MAE Stress: 0.0341, RMSE Stress: 0.0373, MAPE Stress: 7.66%
# MAE Risk: 0.6667, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 8
#
# [Student 8] Evaluation:
# MAE Stress: 0.3382, RMSE Stress: 0.4394, MAPE Stress: 95.42%
# MAE Risk: 1.0000, Accuracy Risk: 0.00%
#
# Processing Hybrid for Student 9
#
# [Student 9] Evaluation:
# MAE Stress: 0.0856, RMSE Stress: 0.0868, MAPE Stress: 50.01%
# MAE Risk: 0.6667, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 10
#
# [Student 10] Evaluation:
# MAE Stress: 0.1770, RMSE Stress: 0.2034, MAPE Stress: 66.87%
# MAE Risk: 0.6667, Accuracy Risk: 66.67%
#
# Processing Hybrid for Student 11
#
# [Student 11] Evaluation:
# MAE Stress: 0.2774, RMSE Stress: 0.3463, MAPE Stress: 79.94%
# MAE Risk: 0.8333, Accuracy Risk: 33.33%
#
# Processing Hybrid for Student
Accuracy Risk: 33.33%
#
# Processing Hybrid for Student 486
#
# [Student 486] Evaluation:
# MAE Stress: 0.0813, RMSE Stress: 0.0905, MAPE Stress: 40.71%
# MAE Risk: 1.0000, Accuracy Risk: 33.33%
#
# Processing Hybrid for Student 487
#
# [Student 487] Evaluation:
# MAE Stress: 0.2566, RMSE Stress: 0.2978, MAPE Stress: 47.06%
# MAE Risk: 0.6667, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 488
#
# [Student 488] Evaluation:
# MAE Stress: 0.2006, RMSE Stress: 0.2351, MAPE Stress: 78.79%
# MAE Risk: 1.0000, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 489
#
# [Student 489] Evaluation:
# MAE Stress: 0.3227, RMSE Stress: 0.4117, MAPE Stress: 739.84%
# MAE Risk: 0.3333, Accuracy Risk: 83.33%
#
# Processing Hybrid for Student 490
#
# [Student 490] Evaluation:
# MAE Stress: 0.2492, RMSE Stress: 0.3162, MAPE Stress: 99.54%
# MAE Risk: 0.0000, Accuracy Risk: 100.00%
#
# Processing Hybrid for Student 491
#
# [Student 491] Evaluation:
# MAE Stress: 0.0296, RMSE Stress: 0.0363, MAPE Stress: 7.44%
# MAE Risk: 0.6667, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 492
#
# [Student 492] Evaluation:
# MAE Stress: 0.2168, RMSE Stress: 0.2330, MAPE Stress: 68.08%
# MAE Risk: 0.5000, Accuracy Risk: 66.67%
#
# Processing Hybrid for Student 493
#
# [Student 493] Evaluation:
# MAE Stress: 0.3687, RMSE Stress: 0.4533, MAPE Stress: 136.76%
# MAE Risk: 0.5000, Accuracy Risk: 66.67%
#
# Processing Hybrid for Student 494
#
# [Student 494] Evaluation:
# MAE Stress: 0.5969, RMSE Stress: 0.6125, MAPE Stress: 293.24%
# MAE Risk: 0.8333, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 495
#
# [Student 495] Evaluation:
# MAE Stress: 0.5667, RMSE Stress: 0.6212, MAPE Stress: 98.56%
# MAE Risk: 1.0000, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 496
#
# [Student 496] Evaluation:
# MAE Stress: 0.2194, RMSE Stress: 0.2612, MAPE Stress: 229.25%
# MAE Risk: 0.5000, Accuracy Risk: 50.00%
#
# Processing Hybrid for Student 497
#
# [Student 497] Evaluation:
# MAE Stress: 0.1667, RMSE Stress: 0.1674, MAPE Stress: 49.39%
# MAE Risk: 1.0000, Accuracy Risk: 33.33%
#
# Processing Hybrid for Student 498
#
# [Student 498] Evaluation:
# MAE Stress: 0.0353, RMSE Stress: 0.0406, MAPE Stress: 30.05%
# MAE Risk: 0.0000, Accuracy Risk: 100.00%
#
# Processing Hybrid for Student 499
#
# [Student 499] Evaluation:
# MAE Stress: 0.5007, RMSE Stress: 0.5045, MAPE Stress: 414.56%
# MAE Risk: 0.5000, Accuracy Risk: 66.67%
#
# Processing Hybrid for Student 500
#
# [Student 500] Evaluation:
# MAE Stress: 0.3391, RMSE Stress: 0.3650, MAPE Stress: 199.08%
# MAE Risk: 1.1667, Accuracy Risk: 33.33%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# Fungsi untuk menghitung MAPE
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero = y_true != 0
    return np.mean(np.abs((y_true[non_zero] - y_pred[non_zero]) / y_true[non_zero])) * 100

# Fungsi untuk memuat dan memproses data
def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    data['Date'] = pd.to_datetime(data['Date'])
    data['Risk Level'] = data['Risk Level'].map({'Low': 0, 'Medium': 1, 'High': 2})
    data = data.dropna()
    
    numerical_features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    scaler = MinMaxScaler()
    data[numerical_features] = scaler.fit_transform(data[numerical_features])
    
    return data, scaler

# Fungsi untuk membagi data berdasarkan waktu
def split_data_by_time(student_data, train_days=24):
    student_data = student_data.sort_values('Date')
    unique_dates = student_data['Date'].unique()
    train_dates = unique_dates[:train_days]
    test_dates = unique_dates[train_days:]
    train_data = student_data[student_data['Date'].isin(train_dates)]
    test_data = student_data[student_data['Date'].isin(test_dates)]
    return train_data, test_data

# Model LSTM
class LSTMModel(nn.Module):
    def _init_(self, input_dim, hidden_dim, num_classes):
        super(LSTMModel, self)._init_()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.bn = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.4)
        self.risk_head = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim // 2, num_classes)
        )
        self.fc_stress = nn.Linear(hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        out, (h_n, _) = self.lstm(x)
        out = h_n[-1]
        out = self.bn(out)
        out = self.dropout(out)
        risk_logits = self.risk_head(out)
        stress = self.sigmoid(self.fc_stress(out))
        return risk_logits, stress.squeeze(1)

# Fungsi untuk memuat model ARIMA
def load_arima_model(student_id, model_dir="model/arima"):
    model_path = os.path.join(model_dir, f"arima_student_{student_id}.pkl")
    if os.path.exists(model_path):
        with open(model_path, 'rb') as f:
            return pickle.load(f)
    raise FileNotFoundError(f"ARIMA model for Student {student_id} not found at {model_path}")

# Fungsi untuk memuat model LSTM
def load_lstm_model(student_id, input_dim, model_dir="model/lstm"):
    model_path = os.path.join(model_dir, f"lstm_student_{student_id}.pth")
    if os.path.exists(model_path):
        model = LSTMModel(input_dim=input_dim, hidden_dim=64, num_classes=3)
        model.load_state_dict(torch.load(model_path))
        return model
    raise FileNotFoundError(f"LSTM model for Student {student_id} not found at {model_path}")

# Fungsi untuk prediksi hybrid per mahasiswa
def predict_hybrid(student_data, student_id, scaler, device):
    train_data, test_data = split_data_by_time(student_data)
    
    # Fitur dan target
    features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    target_cols = ['Risk Level', 'Stress Level (GSR)']
    
    # Persiapkan data
    X_train = train_data[features].values.reshape(-1, 1, len(features))
    X_test = test_data[features].values.reshape(-1, 1, len(features))
    y_train = train_data[target_cols].values
    y_test = test_data[target_cols].values
    
    # Muat model ARIMA
    arima_model = load_arima_model(student_id)
    arima_forecast = arima_model.forecast(steps=len(test_data))
    
    # Augmentasi data dengan prediksi ARIMA
    X_train_aug = np.concatenate((X_train, np.zeros((len(train_data), 1, 1))), axis=2)
    X_test_aug = np.concatenate((X_test, arima_forecast.values.reshape(-1, 1, 1)), axis=2)
    
    # Konversi ke tensor
    X_train_tensor = torch.tensor(X_train_aug, dtype=torch.float32).to(device)
    X_test_tensor = torch.tensor(X_test_aug, dtype=torch.float32).to(device)
    y_train_risk = torch.tensor(y_train[:, 0], dtype=torch.long).to(device)
    y_train_stress = torch.tensor(y_train[:, 1], dtype=torch.float32).to(device)
    y_test_risk = y_test[:, 0].astype(int)
    y_test_stress = y_test[:, 1]
    
    # Muat model LSTM
    model = load_lstm_model(student_id, input_dim=X_train_aug.shape[2])
    model.to(device)
    model.eval()
    
    # Evaluasi pada test set
    with torch.no_grad():
        test_logits, test_stress = model(X_test_tensor)
        risk_pred_test = torch.argmax(test_logits, dim=1).cpu().numpy()
        stress_pred_test = test_stress.cpu().numpy()
    
    # Metrik evaluasi
    mae_stress = mean_absolute_error(y_test_stress, stress_pred_test)
    rmse_stress = np.sqrt(mean_squared_error(y_test_stress, stress_pred_test))
    mape_stress = mean_absolute_percentage_error(y_test_stress, stress_pred_test)
    mae_risk = mean_absolute_error(y_test_risk, risk_pred_test)
    acc_risk = np.mean(risk_pred_test == y_test_risk)
    
    print(f"\n[Student {student_id}] Evaluation:")
    print(f"MAE Stress: {mae_stress:.4f}, RMSE Stress: {rmse_stress:.4f}, MAPE Stress: {mape_stress:.2f}%")
    print(f"MAE Risk: {mae_risk:.4f}, Accuracy Risk: {acc_risk * 100:.2f}%")
    
    # Prediksi 10 hari ke depan
    n_steps = 5
    window_input = X_test_aug[-n_steps:].copy()
    window_input = torch.tensor(window_input, dtype=torch.float32).to(device)
    future_preds = []
    
    arima_future = arima_model.forecast(steps=10).values
    arima_future = np.clip(arima_future, 0, 1)
    lstm_stress_series = []
    
    with torch.no_grad():
        for day in range(10):
            risk_logits_next, stress_pred_next = model(window_input)
            lstm_stress = stress_pred_next[-1].item()
            lstm_stress_series.append(lstm_stress)
            
            smoothed_stress = np.mean(lstm_stress_series[-3:]) if len(lstm_stress_series) >= 3 else lstm_stress
            alpha = np.clip(0.8 - (day * 0.05), 0.3, 0.8)
            combined_stress = alpha * smoothed_stress + (1 - alpha) * arima_future[day]
            combined_stress = np.clip(combined_stress + np.random.normal(0, 0.02), 0, 1)
            
            risk_level_pred = torch.argmax(risk_logits_next[-1]).item()
            last_input = window_input[-1, 0].cpu().numpy()
            next_features = np.clip(last_input[1:-1] + (np.random.rand(3) - 0.5) * 0.02, 0, 1)
            new_input = np.concatenate([[combined_stress], next_features, [arima_future[day]]])
            new_input_tensor = torch.tensor(new_input, dtype=torch.float32).reshape(1, 1, -1).to(device)
            window_input = torch.cat((window_input[1:], new_input_tensor), dim=0)
            future_preds.append([risk_level_pred, combined_stress])
    
    future_preds = np.array(future_preds)
    
    # Persiapan data visualisasi
    future_dates = pd.date_range(start=test_data['Date'].iloc[-1] + pd.Timedelta(days=1), periods=10)
    full_data = pd.concat([train_data, test_data])
    
    plt.figure(figsize=(12, 10))
    
    # -------- Subplot 1: Stress Level --------
    plt.subplot(2, 1, 1)
    plt.plot(full_data['Date'], full_data['Stress Level (GSR)'], label='Actual Stress', color='blue')
    plt.plot(test_data['Date'], stress_pred_test, label='Predicted Stress (Test)', color='red', linestyle='--')
    
    # Garis penyambung dari prediksi terakhir ke forecast pertama (Stress)
    plt.plot(
        [test_data['Date'].iloc[-1], future_dates[0]],
        [stress_pred_test[-1], future_preds[0, 1]],
        color='gray', linestyle='--', alpha=0.6, label='nolegend'
    )
    
    plt.plot(future_dates, future_preds[:, 1], label='Forecast Stress (Next 10 Days)', color='purple', linestyle=':')
    
    plt.title(f"Stress Level Forecast for Student {student_id}")
    plt.xlabel('Date')
    plt.ylabel('Stress Level (GSR)')
    plt.legend()
    plt.grid(True)
    
    # -------- Subplot 2: Risk Level --------
    plt.subplot(2, 1, 2)
    plt.plot(full_data['Date'], full_data['Risk Level'], label='Actual Risk Level', color='green')
    plt.plot(test_data['Date'], risk_pred_test, label='Predicted Risk Level (Test)', color='orange', linestyle='--')
    
    # Garis penyambung dari prediksi terakhir ke forecast pertama (Risk)
    plt.plot(
        [test_data['Date'].iloc[-1], future_dates[0]],
        [risk_pred_test[-1], future_preds[0, 0]],
        color='gray', linestyle='--', alpha=0.6, label='nolegend'
    )
    
    plt.plot(future_dates, future_preds[:, 0], label='Forecast Risk Level (Next 10 Days)', color='brown', linestyle=':')
    
    plt.title(f"Risk Level Forecast for Student {student_id}")
    plt.xlabel('Date')
    plt.ylabel('Risk Level')
    plt.yticks([0, 1, 2], ['Low', 'Medium', 'High'])
    plt.legend()
    plt.grid(True)
    
    # Simpan hasil visualisasi
    plt.tight_layout()
    plt.savefig(f"student_{student_id}_forecast.png")
    plt.close()


# Fungsi utama
def main():
    data, scaler = load_and_preprocess_data('student_monnitoring_data.csv')
    user_groups = data.groupby('Student ID')
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Proses hanya 5 mahasiswa sebagai contoh
    for i, (student_id, student_data) in enumerate(user_groups):
        # if i >= 5:
        #     break
        print(f"\nProcessing Hybrid for Student {student_id}")
        predict_hybrid(student_data, student_id, scaler, device)

# %%
# Hybrid ARIMA-LSTM dengan Output Per Tahap dan Batas 5 Student ID

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero = y_true != 0
    return np.mean(np.abs((y_true[non_zero] - y_pred[non_zero]) / y_true[non_zero])) * 100

def load_and_preprocess_data(file_path):
    data = pd.read_csv(file_path)
    data['Date'] = pd.to_datetime(data['Date'])
    data['Risk Level'] = data['Risk Level'].map({'Low': 0, 'Medium': 1, 'High': 2})
    data = data.dropna()

    # Pilih hanya kolom yang relevan
    selected_columns = ['Student ID', 'Date', 'Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score', 'Risk Level']
    data = data[selected_columns]

    # Normalisasi fitur numerik
    numerical_features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    scaler = MinMaxScaler()
    data[numerical_features] = scaler.fit_transform(data[numerical_features])

    return data, scaler

def split_data_by_time(student_data, train_days=24):
    student_data = student_data.sort_values('Date')
    unique_dates = student_data['Date'].unique()
    train_dates = unique_dates[:train_days]
    test_dates = unique_dates[train_days:]
    train_data = student_data[student_data['Date'].isin(train_dates)]
    test_data = student_data[student_data['Date'].isin(test_dates)]
    return train_data, test_data

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.bn = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.4)
        self.risk_head = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim // 2, num_classes)
        )
        self.fc_stress = nn.Linear(hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out, (h_n, _) = self.lstm(x)
        out = h_n[-1]
        out = self.bn(out)
        out = self.dropout(out)
        risk_logits = self.risk_head(out)
        stress = self.sigmoid(self.fc_stress(out))
        return risk_logits, stress.squeeze(1)

def load_arima_model(student_id, model_dir="model/arima"):
    model_path = os.path.join(model_dir, f"arima_student_{student_id}.pkl")
    if os.path.exists(model_path):
        with open(model_path, 'rb') as f:
            return pickle.load(f)
    raise FileNotFoundError(f"ARIMA model for Student {student_id} not found at {model_path}")

def load_lstm_model(student_id, input_dim, model_dir="model/lstm"):
    model_path = os.path.join(model_dir, f"lstm_student_{student_id}.pth")
    if os.path.exists(model_path):
        model = LSTMModel(input_dim=input_dim, hidden_dim=64, num_classes=3)
        model.load_state_dict(torch.load(model_path))
        return model
    raise FileNotFoundError(f"LSTM model for Student {student_id} not found at {model_path}")

def predict_hybrid_verbose(student_data, student_id, scaler, device):
    train_data, test_data = split_data_by_time(student_data)

    features = ['Stress Level (GSR)', 'Sleep Hours', 'Anxiety Level', 'Mood Score']
    target_cols = ['Risk Level', 'Stress Level (GSR)']

    X_train = train_data[features].values.reshape(-1, 1, len(features))
    X_test = test_data[features].values.reshape(-1, 1, len(features))
    y_train = train_data[target_cols].values
    y_test = test_data[target_cols].values

    arima_model = load_arima_model(student_id)
    arima_forecast = arima_model.forecast(steps=len(test_data))

    print(f"\n[Student {student_id}] ARIMA Forecast:")
    print(arima_forecast)

    X_train_aug = np.concatenate((X_train, np.zeros((len(train_data), 1, 1))), axis=2)
    X_test_aug = np.concatenate((X_test, arima_forecast.values.reshape(-1, 1, 1)), axis=2)

    X_test_tensor = torch.tensor(X_test_aug, dtype=torch.float32).to(device)
    model = load_lstm_model(student_id, input_dim=X_test_aug.shape[2])
    model.to(device)
    model.eval()

    with torch.no_grad():
        test_logits, test_stress = model(X_test_tensor)
        risk_pred_test = torch.argmax(test_logits, dim=1).cpu().numpy()
        stress_pred_test = test_stress.cpu().numpy()

    mae_stress = mean_absolute_error(y_test[:, 1], stress_pred_test)
    rmse_stress = np.sqrt(mean_squared_error(y_test[:, 1], stress_pred_test))
    mape_stress = mean_absolute_percentage_error(y_test[:, 1], stress_pred_test)
    mae_risk = mean_absolute_error(y_test[:, 0], risk_pred_test)
    acc_risk = np.mean(risk_pred_test == y_test[:, 0])

    print(f"\n[Student {student_id}] Evaluation:")
    print(f"MAE Stress: {mae_stress:.4f}, RMSE Stress: {rmse_stress:.4f}, MAPE Stress: {mape_stress:.2f}%")
    print(f"MAE Risk: {mae_risk:.4f}, Accuracy Risk: {acc_risk * 100:.2f}%")

    n_steps = 5
    window_input = X_test_aug[-n_steps:].copy()
    window_input = torch.tensor(window_input, dtype=torch.float32).to(device)
    future_preds = []

    arima_future = arima_model.forecast(steps=10).values
    arima_future = np.clip(arima_future, 0, 1)
    lstm_stress_series = []

    with torch.no_grad():
        for day in range(10):
            risk_logits_next, stress_pred_next = model(window_input)
            lstm_stress = stress_pred_next[-1].item()
            lstm_stress_series.append(lstm_stress)

            smoothed_stress = np.mean(lstm_stress_series[-3:]) if len(lstm_stress_series) >= 3 else lstm_stress
            alpha = np.clip(0.8 - (day * 0.05), 0.3, 0.8)
            combined_stress = alpha * smoothed_stress + (1 - alpha) * arima_future[day]
            combined_stress = np.clip(combined_stress + np.random.normal(0, 0.02), 0, 1)

            risk_level_pred = torch.argmax(risk_logits_next[-1]).item()
            last_input = window_input[-1, 0].cpu().numpy()
            next_features = np.clip(last_input[1:-1] + (np.random.rand(3) - 0.5) * 0.02, 0, 1)
            new_input = np.concatenate([[combined_stress], next_features, [arima_future[day]]])
            new_input_tensor = torch.tensor(new_input, dtype=torch.float32).reshape(1, 1, -1).to(device)
            window_input = torch.cat((window_input[1:], new_input_tensor), dim=0)
            future_preds.append([risk_level_pred, combined_stress])

    future_preds = np.array(future_preds)
    future_dates = pd.date_range(start=test_data['Date'].iloc[-1] + pd.Timedelta(days=1), periods=10)
    return stress_pred_test, risk_pred_test, future_preds, future_dates

def display_prediction_results(student_id, test_data, stress_pred_test, risk_pred_test, future_dates, future_preds):
    print(f"\n[Student {student_id}] Test Set Predictions:")
    df_test_result = test_data.copy()
    df_test_result['Predicted Stress'] = stress_pred_test
    df_test_result['Predicted Risk'] = risk_pred_test
    print(df_test_result[['Date', 'Stress Level (GSR)', 'Predicted Stress', 'Risk Level', 'Predicted Risk']])

    print(f"\n[Student {student_id}] 10-Day Forecast Results:")
    df_future = pd.DataFrame({
        'Date': future_dates,
        'Forecasted Stress': future_preds[:, 1],
        'Forecasted Risk': future_preds[:, 0].astype(int)
    })
    print(df_future)

def main():
    data, scaler = load_and_preprocess_data('student_monnitoring_data.csv')
    user_groups = data.groupby('Student ID')
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    for i, (student_id, student_data) in enumerate(user_groups):
        if i >= 5:
            break
        print(f"\nProcessing Hybrid for Student {student_id}")
        train_data, test_data = split_data_by_time(student_data)

        print(f"\n[Student {student_id}] Train Data Sample:")
        print(train_data.head())

        print(f"\n[Student {student_id}] Test Data Sample:")
        print(test_data.head())

        stress_pred_test, risk_pred_test, future_preds, future_dates = predict_hybrid_verbose(
            student_data, student_id, scaler, device
        )

        display_prediction_results(student_id, test_data, stress_pred_test, risk_pred_test, future_dates, future_preds)

# Jalankan fungsi utama
main()  # Uncomment this line to run
# Out:
# Processing Hybrid for Student 1
#
# [Student 1] Train Data Sample:
#    Student ID       Date  Stress Level (GSR)  Sleep Hours  Anxiety Level  \
# 0           1 2024-12-01            0.093333        0.650       0.555556
# 1           1 2024-12-02            0.148889        0.250       0.555556
# 2           1 2024-12-03            0.902222        0.325       0.333333
# 3           1 2024-12-04            0.571111        1.000       0.111111
# 4           1 2024-12-05            0.762222        0.600       0.888889
#
#    Mood Score  Risk Level
# 0    0.555556           0
# 1    0.111111           1
# 2    0.777778           2
# 3    1.000000           0
# 4    0.333333           2
#
# [Student 1] Test Data Sample:
#     Student ID       Date  Stress Level (GSR)  Sleep Hours  Anxiety Level  \
# 24           1 2024-12-25            0.433333        0.400       0.555556
# 25           1 2024-12-26            0.533333        0.550       1.000000
# 26           1 2024-12-27            0.308889        0.500       1.000000
# 27           1 2024-12-28            0.048889        0.125       0.000000
# 28           1 2024-12-29            0.986667        0.400       0.111111
#
#     Mood Score  Risk Level
# 24    0.666667           0
# 25    1.000000           1
# 26    0.555556           2
# 27    0.777778           0
# 28    0.222222           2
#
# [Student 1] ARIMA Forecast:
# 24    2.670550
# 25    3.007718
# 26    3.007718
# 27    3.007718
# 28    3.007718
# 29    3.007718
# Name: predicted_mean, dtype: float64
#
# [Student 1] Evaluation:
# MAE Stress: 0.2471, RMSE Stress: 0.2776, MAPE Stress: 49.03%
# MAE Risk: 0.6667, Accuracy Risk: 50.00%
#
# [Student 1] Test Set Predictions:
#          Date  Stress Level (GSR)  Predicted Stress  Risk Level  \
# 24 2024-12-25            0.433333          0.168627           0
# 25 2024-12-26            0.533333          0.139127           1
# 26 2024-12-27            0.308889          0.077172           2
# 27 2024-12-28            0.048889          0.037978           0
# 28 2024-12-29            0.986667          0.780188           2
# 29 2024-12-30            0.915556          0.540951           2
#
#     Predicted Risk
# 24               0
# 25               0
# 26               0
# 27               0
# 28               1
# 29               2
#
# [Student 1] 10-Day Forecast Results:
#         Date  Forecasted Stress  Forecasted Risk
student ID       Date  Stress Level (GSR)  Sleep Hours  Anxiety Level  \
# 84           3 2024-12-25            0.486667        1.000       0.000000
# 85           3 2024-12-26            0.724444        0.725       0.000000
# 86           3 2024-12-27            0.475556        0.850       0.666667
# 87           3 2024-12-28            0.813333        0.275       1.000000
# 88           3 2024-12-29            0.020000        0.300       0.222222
#
#     Mood Score  Risk Level
# 84    0.555556           2
# 85    0.222222           2
# 86    0.444444           0
# 87    0.333333           2
# 88    0.333333           0
#
# [Student 3] ARIMA Forecast:
# 24    2.856128
# 25    2.777682
# 26    2.699235
# 27    2.620788
# 28    2.542342
# 29    2.463895
# Name: predicted_mean, dtype: float64
#
# [Student 3] Evaluation:
# MAE Stress: 0.1019, RMSE Stress: 0.1142, MAPE Stress: 41.99%
# MAE Risk: 1.0000, Accuracy Risk: 33.33%
#
# [Student 3] Test Set Predictions:
#          Date  Stress Level (GSR)  Predicted Stress  Risk Level  \
# 84 2024-12-25            0.486667          0.317551           2
# 85 2024-12-26            0.724444          0.645868           2
# 86 2024-12-27            0.475556          0.307381           0
# 87 2024-12-28            0.813333          0.713338           2
# 88 2024-12-29            0.020000          0.050168           0
# 89 2024-12-30            0.828889          0.763617           2
#
#     Predicted Risk
# 84               0
# 85               2
# 86               1
# 87               1
# 88               2
# 89               2
#
# [Student 3] 10-Day Forecast Results:
#         Date  Forecasted Stress  Forecasted Risk
# 0 2024-12-31           0.786968                2
# 1 2025-01-01           0.857789                2
# 2 2025-01-02           0.858994                2
# 3 2025-01-03           0.883044                2
# 4 2025-01-04           0.914171                2
# 5 2025-01-05           0.863395                2
# 6 2025-01-06           0.927170                2
# 7 2025-01-07           0.916767                2
# 8 2025-01-08           0.927647                2
# 9 2025-01-09           0.907816                2
#
# Processing Hybrid for Student 4
#
# [Student 4] Train Data Sample:
#     Student ID       Date  Stress Level (GSR)  Sleep Hours  Anxiety Level  \
# 90           4 2024-12-01            0.953333        0.525       0.555556
# 91           4 2024-12-02            0.737778        0.075       0.444444
# 92           4 2024-12-03            0.293333        0.250       0.333333
# 93           4 2024-12-04            0.037778        0.875       1.000000
# 94           4 2024-12-05            0.271111        0.425       0.666667
#
#     Mood Score  Risk Level
# 90    0.555556           2
# 91    0.555556           2
# 92    0.888889           0
# 93    0.777778           1
# 94    0.888889           2
#
# [Student 4] Test Data Sample:
#      Student ID       Date  Stress Level (GSR)  Sleep Hours  Anxiety Level  \
# 114           4 2024-12-25            0.075556        0.350       0.000000
# 115           4 2024-12-26            0.988889        0.475       0.555556
# 116           4 2024-12-27            0.968889        0.275       0.777778
# 117           4 2024-12-28            0.166667        0.875       0.444444
# 118           4 2024-12-29            0.675556        0.475       0.444444
#
#      Mood Score  Risk Level
# 114    0.111111           1
# 115    0.555556           2
# 116    0.333333           2
# 117    0.555556           0
# 118    0.222222           2
#
# [Student 4] ARIMA Forecast:
# 24    2.813049
# 25    2.977341
# 26    2.938599
# 27    2.889369
# 28    2.852235
# 29    2.826278
# Name: predicted_mean, dtype: float64
# [Student 4] Evaluation:
# MAE Stress: 0.1183, RMSE Stress: 0.1446, MAPE Stress: 63.78%
# MAE Risk: 0.1667, Accuracy Risk: 83.33%
#
# [Student 4] Test Set Predictions:
#           Date  Stress Level (GSR)  Predicted Stress  Risk Level  \
# 114 2024-12-25            0.075556          0.249494           1
